# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Paillasse d'expérimentation
# ---
#
# ## Sujet : Génération CorpusLabel
#
# ---

# %% [markdown]
# ## Initialisation de la paillasse
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd

# %% [markdown]
# ## Observations et environnement
# ---

# %% [markdown]
# ### Chargement du corpus

# %%
corpus_filename = 'tmp/221003-CorpusLabel.csv'

# %%
df_corpus = pd.read_csv(f'data/{corpus_filename}')
df_corpus = df_corpus.convert_dtypes()
# Out:
# /var/folders/n0/92k02lss71s67fxfyc0qn84m0000gn/T/ipykernel_91229/3410691136.py:1: DtypeWarning: Columns (4,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_corpus = pd.read_csv(f'data/{corpus_filename}')

# %%
df_corpus[df_corpus['text'].isna()]
# Out:
#                                                      url  \
# 15912  https://lezarceleurs.blogspot.com/2022/09/blog...
# 25318  https://www.breizh-info.com/2022/09/30/208531/...
# 32384  https://www.dreuz.info/2022/10/elections-de-mi...
# 49040  https://www.francesoir.fr/politique-monde/pres...
# 78508  https://www.lelibrepenseur.org/suede-fin-de-la...
# 79484  https://www.lesalonbeige.fr/ils-voient-dun-mau...
# 80764  https://www.polemia.com/callac-laboratoire-du-...
# 88206  https://www.wikistrike.com/2022/09/11-septembr...
# 88211  https://www.wikistrike.com/2022/09/coupures-el...
#
#                                                    title  \
# 15912                      La spike qui tue et handicape
# 25318    Réunification. Les six « insoumis » de Bretagne
# 32384  Elections américaines de mi-mandat : suivi quo...
# 49040  Présidentielle au Brésil: Bolsonaro talonne Lu...
# 78508  La nomination de Luc Rémont, ex-banquier d’aff...
# 79484  “Ils voient d’un mauvais oeil cette « invasion...
# 80764  Callac, laboratoire du peuplement de la France...
# 88206  11 septembre 2001 : La théorie du « complot pi...
# 88211          Coupures électriques imminentes en France
#
#                                                  article  \
# 15912  https://www.naturalnews.com/2022-09-28-call-to...
# 25318  Dans l’opération que prépare Bretagne réunie, ...
# 32384  Voici le suivi quotidien des élections des mid...
# 49040  L'ex-président de gauche Lula s'est imposé sur...
# 78508  C‘est avec ce genre de décision que vous compr...
# 79484  Arte a diffusé le 24 septembre un documentaire...
# 80764  Par Paul Tormenen, juriste et spécialiste des ...
# 88206  Le 11 septembre pour les nuls
# Est-il vrai que ...
# 88211  Selon Reuters, le gouvernement français s'appr...
#
#                                                      tag abstract  \
# 15912                                                 []     <NA>
# 25318  ['Politique', 'bretagne', 'la france insoumise...     <NA>
# 32384                                                 []     <NA>
# 49040                                                 []     <NA>
# 78508                ['in\nÀ la une, Non-classé, Santé']     <NA>
# 79484                                                 []     <NA>
# 80764                                                 []     <NA>
# 88206                                                 []     <NA>
# 88211                                                 []     <NA>
#
#                                              author  \
# 15912                                          <NA>
# 25318                                          <NA>
# 32384  Publié par  Team 100 jours le 3 octobre 2022
# 49040                 Auteur(s)
# FranceSoir avec AFP
# 78508                                  Par
# Aguellid
# 79484                              Par Michel Janva
# 80764                                          <NA>
# 88206                                          <NA>
# 88211                                          <NA>
#
#                                                     date             date_iso  \
# 15912                                               <NA>                 <NA>
# 25318                    Le
# 										30 septembre 2022  2022-09-30T00:00:00
# 32384       Publié par  Team 100 jours le 3 octobre 2022  2022-10-03T00:00:00
# 49040                  Publié le 03 octobre 2022 - 10:30  2022-10-03T10:30:00
# 78508                                     2 octobre 2022  2022-10-02T00:00:00
# 79484                                     3 octobre 2022  2022-10-03T00:00:00
# 80764                                               <NA>                 <NA>
# 88206  Publié par wikistrike.com
#                     ...  2022-09-29T00:00:00
# 88211  Publié par wikistrike.com
#                     ...  2022-09-29T00:00:00
#
#        site  text  ...  trop_mots  trop_chiffres sophisme  inversion_preuve  \
# 15912  <NA>  <NA>  ...          0              0        0                 0
# 25318  <NA>  <NA>  ...          0              0        0                 0
# 32384  <NA>  <NA>  ...          0              0        0                 0
# 49040  <NA>  <NA>  ...          0              0        0                 0
# 78508  <NA>  <NA>  ...          0              0        0                 0
# 79484  <NA>  <NA>  ...          0              0        0                 0
# 80764  <NA>  <NA>  ...          0              0        0                 0
# 88206  <NA>  <NA>  ...          1              0        0                 0
# 88211  <NA>  <NA>  ...          0              0        0                 0
#
#        inverifiable  propos_raportes  sources_citees  titre_decale  \
# 15912             0                0               0             0
# 25318             0                0               0             0
# 32384             0                0               0             0
# 49040             0                0               0             0
# 78508             0                1               0             0
# 79484             0                0               0             0
# 80764             0                0               0             1
# 88206             0                1               0             0
# 88211             0                1               0             1
#
#        denigrement  cherry_picking
# 15912            0            <NA>
# 25318            0               0
# 32384            0               0
# 49040            0               0
# 78508            0               0
# 79484            0               0
# 80764            0               0
# 88206            0            <NA>
# 88211            0            <NA>
#
# [9 rows x 36 columns]

# %%
df_corpus = df_corpus[df_corpus['text'].notna()]

# %%
df_corpus
# Out:
#                                                      url  \
# 0      https://actu.fr/economie/100-euros-le-phare-15...
# 1      https://actu.fr/economie/a-compter-du-1er-janv...
# 2      https://actu.fr/economie/achats-en-ligne-pourq...
# 3      https://actu.fr/economie/aeronautique-salaries...
# 4      https://actu.fr/economie/aide-exceptionnelle-d...
# ...                                                  ...
# 89176  https://www.wikistrike.com/article-vous-voulez...
# 89177  https://www.wikistrike.com/article-vue-d-ensem...
# 89178  https://www.wikistrike.com/article-william-sha...
# 89179  https://www.wikistrike.com/article-youpi-votre...
# 89180  https://www.wikistrike.com/article-zone-humide...
#
#                                                    title  \
# 0      100 euros le phare, 150 euros le parechoc : en...
# 1      A compter du 1er janvier 2021, le prix du timb...
# 2      Achats en ligne : pourquoi Zara fait désormais...
# 3      Aéronautique : les salariés d'Air France disen...
# 4      Aide exceptionnelle de 150 euros : finalement,...
# ...                                                  ...
# 89176  Vous voulez vous faire peur? Venez voir les ré...
# 89177  Vue d'ensemble des récents tremblements de ter...
# 89178                 William Shakespeare, cocaïnomane ?
# 89179  Youpi, Votre ADN sur la Lune pour 10 000 $, pa...
# 89180  Zone humide : une première cartographie mondia...
#
#                                                  article              tag  \
# 0      Le gérant d’une casse de la périphérie de Caen...  ['#Automobile']
# 1      Le prix des timbres augmente à partir du 1er j...               []
# 2      L’enseigne espagnole Zara fait désormais payer...               []
# 3      Image tirée d’une vidéo d’Air France, le 26 ju...               []
# 4      Les bénéficiaires qui vont toucher l’aide exce...               []
# ...                                                  ...              ...
# 89176  Vous voulez vous faire peur? Venez voir les ré...               []
# 89177  Tremblements de terre - vue d'ensemble        ...               []
# 89178  William Shakespeare, cocaïnomane ?  Comment es...               []
# 89179  Votre ADN sur la Lune pour 10 000 $      Sur K...               []
# 89180  Zone humide : une première cartographie mondia...               []
#
#       abstract                                             author  \
# 0         <NA>   Par Alexandra Segond
# Publié le 8 Juil 22 à 18:05
# 1         <NA>   Par Alexandra Segond
# Publié le 4 Août 20 à 16:26
# 2         <NA>       Par Martin Leduc
# Publié le 24 Mai 22 à 18:21
# 3         <NA>  Par Rédaction Actu
# Publié le 27 Juin 20 à 14:0...
# 4         <NA>     Par Johann Foucault
# Publié le 16 Oct 20 à 8:56
# ...        ...                                                ...
# 89176     <NA>                                               <NA>
# 89177     <NA>                                               <NA>
# 89178     <NA>                                               <NA>
# 89179     <NA>                                               <NA>
# 89180     <NA>                                               <NA>
#
#                                                     date             date_iso  \
# 0       Par Alexandra Segond
# Publié le 8 Juil 22 à 18:05                 <NA>
# 1       Par Alexandra Segond
# Publié le 4 Août 20 à 16:26                 <NA>
# 2           Par Martin Leduc
# Publié le 24 Mai 22 à 18:21  2022-05-24T18:21:00
# 3      Par Rédaction Actu
# Publié le 27 Juin 20 à 14:0...  2020-06-27T14:05:00
# 4         Par Johann Foucault
# Publié le 16 Oct 20 à 8:56                 <NA>
# ...                                                  ...                  ...
# 89176  Publié par wikistrike.com
#                     ...  2012-02-29T00:00:00
# 89177  Publié par wikistrike.over-blog.com
#           ...  2011-04-29T00:00:00
# 89178  Publié par wikistrike.over-blog.com
#           ...  2011-06-30T00:00:00
# 89179  Publié par wikistrike.com
#                     ...  2012-07-20T00:00:00
# 89180  Publié par wikistrike.com
#                     ...  2012-05-11T00:00:00
#
#                      site                                               text  \
# 0                 actu.fr  100 euros le phare, 150 euros le parechoc : en...
# 1                 actu.fr  A compter du 1er janvier 2021, le prix du timb...
# 2                 actu.fr  Achats en ligne : pourquoi Zara fait désormais...
# 3                 actu.fr  Aéronautique : les salariés d'Air France disen...
# 4                 actu.fr  Aide exceptionnelle de 150 euros : finalement,...
# ...                   ...                                                ...
# 89176  www.wikistrike.com  Vous voulez vous faire peur? Venez voir les ré...
# 89177  www.wikistrike.com  Vue d'ensemble des récents tremblements de ter...
# 89178  www.wikistrike.com  William Shakespeare, cocaïnomane ?
# William Sha...
# 89179  www.wikistrike.com  Youpi, Votre ADN sur la Lune pour 10 000 $, pa...
# 89180  www.wikistrike.com  Zone humide : une première cartographie mondia...
#
#        ...  trop_mots  trop_chiffres sophisme  inversion_preuve  inverifiable  \
# 0      ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 1      ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 2      ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 3      ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 4      ...       <NA>           <NA>     <NA>              <NA>          <NA>
# ...    ...        ...            ...      ...               ...           ...
# 89176  ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 89177  ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 89178  ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 89179  ...       <NA>           <NA>     <NA>              <NA>          <NA>
# 89180  ...       <NA>           <NA>     <NA>              <NA>          <NA>
#
#        propos_raportes  sources_citees  titre_decale  denigrement  \
# 0                 <NA>            <NA>          <NA>         <NA>
# 1                 <NA>            <NA>          <NA>         <NA>
# 2                 <NA>            <NA>          <NA>         <NA>
# 3                 <NA>            <NA>          <NA>         <NA>
# 4                 <NA>            <NA>          <NA>         <NA>
# ...                ...             ...           ...          ...
# 89176             <NA>            <NA>          <NA>         <NA>
# 89177             <NA>            <NA>          <NA>         <NA>
# 89178             <NA>            <NA>          <NA>         <NA>
# 89179             <NA>            <NA>          <NA>         <NA>
# 89180             <NA>            <NA>          <NA>         <NA>
#
#        cherry_picking
# 0                <NA>
# 1                <NA>
# 2                <NA>
# 3                <NA>
# 4                <NA>
# ...               ...
# 89176            <NA>
# 89177            <NA>
# 89178            <NA>
# 89179            <NA>
# 89180            <NA>
#
# [89172 rows x 36 columns]

# %%
df_recueil = df_corpus[df_corpus['infox'].notna()]
df_recueil
# Out:
#                                                      url  \
# 3273   https://fr.novopress.info/227346/immigration-c...
# 3283   https://fr.novopress.info/227381/lalgerie-un-p...
# 3289   https://fr.novopress.info/227410/un-president-...
# 3641   https://fr.novopress.info/actualite-politique-...
# 5951         https://fr.sott.net/article/39998-Le-Pentag
# ...                                                  ...
# 88153  https://www.wikistrike.com/2022/08/le-forum-ec...
# 88157  https://www.wikistrike.com/2022/08/le-masque-r...
# 88172  https://www.wikistrike.com/2022/08/les-vaccine...
# 88198  https://www.wikistrike.com/2022/08/washington-...
# 88248  https://www.wikistrike.com/2022/09/les-command...
#
#                                                    title  \
# 3273   Immigration clandestine : répartir ou renvoyer...
# 3283   L’Algérie, un pays jeune gouverné par des viei...
# 3289   Un président réélu : et après ?, par Philippe ...
# 3641   Qui est Alexandre Douguine? Anatomie d’une pen...
# 5951   Le Pentagone organise la victoire de l'Ukraine...
# ...                                                  ...
# 88153  Le Forum économique mondial estime qu’il exist...
# 88157     Le masque réduit les infections COVID de 0,06%
# 88172  Les vaccinés infectés au Covid restent contagi...
# 88198  Washington enverrait des mercenaires afghans c...
# 88248  Les commandos ukrainiens qui ont attaqué la ce...
#
#                                                  article  \
# 3273   Comment faire face à l’immigration clandestine...
# 3283   L’Algérie (46 millions d’habitants en 2022), e...
# 3289   On ne peut pas s’empêcher de penser qu’avec ce...
# 3641   L’assassinat de Daria Douguine a conduit de no...
# 5951   Le festival de l'Eurovision 2022 s'est tenu à ...
# ...                                                  ...
# 88153  Ne trahissant pas sa réputation de méchant d’u...
# 88157  par Collectif Reinfocovid.
# Cet article illustr...
# 88172  Une étude publiée le 21 juin 2022 par le New E...
# 88198  Des spécialistes originaires d'Afghanistan par...
# 88248  (!) Source russe
#
#
# Les quelques unités de l’a...
#
#                                                      tag abstract     author  \
# 3273   ['Étiquettes crise alimentaire, immigration cl...     <NA>  Novopress
# 3283               ['Étiquettes Algérie, Bernard Lugan']     <NA>  Novopress
# 3289   ['Étiquettes Emmanuel Macron, Philippe Bilger,...     <NA>  Novopress
# 3641   ['Étiquettes Alexandre Douguine, Revue Elément...     <NA>  Novopress
# 5951                                                  []     <NA>       <NA>
# ...                                                  ...      ...        ...
# 88153                                                 []     <NA>       <NA>
# 88157                                                 []     <NA>       <NA>
# 88172                                                 []     <NA>       <NA>
# 88198                                                 []     <NA>       <NA>
# 88248                                                 []     <NA>       <NA>
#
#                                                     date             date_iso  \
# 3273                                      1 juillet 2022  2022-07-01T00:00:00
# 3283                                      6 juillet 2022  2022-07-06T00:00:00
# 3289                                      7 juillet 2022  2022-07-07T00:00:00
# 3641                                        29 août 2022  2022-08-29T00:00:00
# 5951                                                <NA>                 <NA>
# ...                                                  ...                  ...
# 88153  Publié par wikistrike.com
#                     ...  2022-08-23T00:00:00
# 88157  Publié par wikistrike.com
#                     ...  2022-08-24T00:00:00
# 88172  Publié par wikistrike.com
#                     ...  2022-08-20T00:00:00
# 88198  Publié par wikistrike.com
#                     ...  2022-08-20T00:00:00
# 88248  Publié par wikistrike.com
#                     ...  2022-09-02T00:00:00
#
#                      site                                               text  \
# 3273    fr.novopress.info  Immigration clandestine : répartir ou renvoyer...
# 3283    fr.novopress.info  L’Algérie, un pays jeune gouverné par des viei...
# 3289    fr.novopress.info  Un président réélu : et après ?, par Philippe ...
# 3641    fr.novopress.info  Qui est Alexandre Douguine? Anatomie d’une pen...
# 5951          fr.sott.net  Le Pentagone organise la victoire de l'Ukraine...
# ...                   ...                                                ...
# 88153  www.wikistrike.com  Le Forum économique mondial estime qu’il exist...
# 88157  www.wikistrike.com  Le masque réduit les infections COVID de 0,06%...
# 88172  www.wikistrike.com  Les vaccinés infectés au Covid restent contagi...
# 88198  www.wikistrike.com  Washington enverrait des mercenaires afghans c...
# 88248  www.wikistrike.com  Les commandos ukrainiens qui ont attaqué la ce...
#
#        ...  trop_chiffres  sophisme inversion_preuve  inverifiable  \
# 3273   ...              0         0                0             0
# 3283   ...              0         0                0             0
# 3289   ...              0         0                0             0
# 3641   ...              0         0                0             0
# 5951   ...              0         0                0             1
# ...    ...            ...       ...              ...           ...
# 88153  ...              0         0                0             0
# 88157  ...              1         0                0             0
# 88172  ...              1         0                0             0
# 88198  ...              0         0                1             1
# 88248  ...              0         0                1             1
#
#        propos_raportes  sources_citees  titre_decale  denigrement  \
# 3273                 0               1             0         <NA>
# 3283                 0               0             0         <NA>
# 3289                 0               0             0         <NA>
# 3641                 0               0             0            0
# 5951                 0               0             1         <NA>
# ...                ...             ...           ...          ...
# 88153                1               1             0            1
# 88157                0               0             0            0
# 88172                1               1             0            1
# 88198                1               0             0            0
# 88248                1               1             0            1
#
#        cherry_picking                                             lemmas
# 3273             <NA>  immigration clandestin répartir ou renvoyer le...
# 3283             <NA>  algérie un pays jeune gouverner par des vieill...
# 3289             <NA>  un présider réélire et après par philippe bilg...
# 3641             <NA>  qui est alexandre douguine anatomie une penser...
# 5951             <NA>  le pentagone organiser la victoire de ukraine ...
# ...               ...                                                ...
# 88153            <NA>  le forum économique mondial estime qu il exist...
# 88157            <NA>  le masque réduire les infection covid de par c...
# 88172            <NA>  les vacciner infecter au covid rester contagie...
# 88198            <NA>  washington envoyer des mercenaire afghan comba...
# 88248            <NA>  les commando ukrainien qui avoir attaquer la c...
#
# [455 rows x 37 columns]

# %% [markdown]
# ## Expérience
# ---

# %% [markdown]
# ### Lemmatization du corpus

# %%
import patat.ml.lex_analyser

# %%
importlib.reload(patat.ml.lex_analyser)
# Out:
# <module 'patat.ml.lex_analyser' from '/Users/fm/Desktop/Work/Patat/patat/ml/lex_analyser.py'>

# %%
lex = patat.ml.lex_analyser.LexAnalyser()

# %%
def lemmatize(text):
    words = lex.get_words(text)
    lemmas = lex.get_lemmas(words)
    return ' '.join(lemmas)

# %%
# %%time
df_corpus['lemmas']=df_corpus['text'].apply(lemmatize)
# Out:
# CPU times: user 16.2 s, sys: 183 ms, total: 16.4 s
# Wall time: 16.4 s

# %%
for index,row in df_corpus.sample(10).iterrows():
    print(f"{row['url']}\n{row['lemmas']}")
# Out:
# https://www.francetvinfo.fr/meteo/meteo-france-2/video-la-meteo-du-mercredi-21-janvier-2015-a-19h55_803487.html
# bulletin météo du mercredi janvier
# https://www.breizh-info.com/2020/10/23/152721/pontmain-53-pelerinage-et-messe-dominicaine-traditionnelle-ce-25-octobre/
# pontmain pèlerinage et messe dominicain traditionnel ce octobre les dominicain de cheméré le roi célébrer ce octobre une messe traditionnel en rite dominicain la basilique notre dame de pontmain en mayenne ce village se trouver la limite de la bretagne et km au nord est il agir accessoirement de la premier fois sembler il depuis où la messe traditionnel est célébrer en la basilique il agir de la fraternité saint vincent ferrier fsvf fonder par le père louis marier de blignières en reconnaître par rome et ériger canoniquement par la commission ecclesia dei en approuver par le saint siège en elle est baser cheméré le roi qui est son seul couver mais dessert aussi la roë avril novembre dimanche et fête messe bas vendredi et samedi et la selle craonnais en hiver avec les même paroissien ses religieux organiser un pèlerinage depuis mégaudais sur la rn route ernée fougère sur la commun de saint pierre des lande le même jour midi ils être saint ellier du maine la messe commencer pontmain il agir au passage un des rare pélérinages qui pas encore été annuler du faire de la crise sanitaire la basilique de pontmain été ériger entre et sur le site une apparition mariale sept enfant le janvier très vite devenir lieu de pèlerinage alors que les troupe allemand qui occuper la france après la défaire de hâter leur départ elle été consacrer basilique mineur en le futur pape jean xxiii époque nonce apostolique mgr roncalli préside le anniversaire de apparition en les an de apparition avoir lieu le janvier église est aussi connaître pour ses magnifique vitrail destiner alléger immense vaisseau néogothique ériger sur des marécage et son impressionnant carillon de cloche tout couler par le fondeur paccard et dont les trois plaire lourd peser et tonne pour ceux qui intéresser au rite dominicain traditionnel on le trouver aussi célébrer dans la région par les dominicain avrillé près angers mais aussi toulouse par des dominicain biformalistes et dans église du saint sacrement seattle user mais aussi depuis par des dominicain américain colombus ohio anchorage alaska louis moulin illustration dr cc breizh info com dépêche libre de copie et de diffusion sou réserve de mention et de lien vers la source origine
# %% [markdown]
# ### Comptage Lemmes pour label infox

# %%
def merge_texts(texts):
    result = ''
    for text in texts:
        result = result + text + '\n'
    return result

# %%
def count_words_label(df,label):
    df = df[df[label].notna()]
    df_texts = pd.pivot_table(df, values='lemmas', index=None, columns=label, aggfunc=merge_texts)
    wc = {}
    word_analysis = {}
    for key in df_texts.keys():
        text = df_texts[key]['lemmas']
        count_colname = label+'_'+str(key)
        wc[key] = lex.count_tokens(lex.get_words(text))
        for word in wc[key]:
            word_dic = word_analysis.get(word,{})
            word_dic[count_colname]=wc[key][word]
            word_analysis[word]=word_dic
    return word_analysis

# %%
df = df_corpus
label = 'infox'
df_count = pd.DataFrame(count_words_label(df_corpus,'infox')).T
df_count = df_count.fillna(0)

# %%
df_count
# Out:
#                   infox_0  infox_1
# immigration          45.0     19.0
# clandestin           69.0      9.0
# répartir              8.0      1.0
# ou                  536.0   1078.0
# renvoyer             18.0      8.0
# ...                   ...      ...
# aiea                  0.0      2.0
# rogov                 0.0      1.0
# dniepropietrovsk      0.0      1.0
# energodar             0.0      1.0
# barge                 0.0      1.0
#
# [23667 rows x 2 columns]

# %%
df_count['word']=df_count.index

# %%
df_count['lemma']=df_count['word'].apply(lex.get_lemma)

# %%
df_count[df_count['lemma']=='clandestin']
# Out:
#             infox_0  infox_1        word       lemma
# clandestin     69.0      9.0  clandestin  clandestin

# %%
df_lemmas = pd.pivot_table(df_count, values=['infox_0','infox_1'], index=None, columns='lemma', aggfunc=sum).T

# %%
df_lemmas['lemma']=df_lemmas.index

# %% [markdown]
# #### Identification des mots à ignorer

# %%
# Mots rares
occ_rare = 3
def is_rare(row):
    return row['infox_0'] < occ_rare and row['infox_1'] < occ_rare

df_rare = df_count[df_count.apply(is_rare,axis=1)]

rare_words = list(df_rare.index)
len(rare_words)
# Out:
# 22749

# %%
### Mots communs

common_size = 100
top_0 = df_count.sort_values('infox_0',ascending=False).head(common_size).index
top_1 = df_count.sort_values('infox_1',ascending=False).head(common_size).index
common_words = []
for word in top_0:
    if word in top_1:
        common_words.append(word)
len(common_words)
# Out:
# 86

# %%
ignore_words = common_words + rare_words
word_vocabulary = [word for word in df_count['lemma'] if word not in ignore_words]
print(f'Vocabulaire = Total mots - mots communs - mots rares = {len(word_vocabulary)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 ignore_words = common_words + rare_words
#       2 word_vocabulary = [word for word in df_count['lemma'] if word not in ignore_words]
#       3 print(f'Vocabulaire = Total mots - mots communs - mots rares = {len(word_vocabulary)}')
#
# NameError: name 'common_words' is not defined

# %% [markdown]
# #### Identification des lemmes à ignorer

# %%
occ_rare = 3
def is_rare(row):
    return row['infox_0'] < occ_rare and row['infox_1'] < occ_rare

df_rare_lemmas = df_lemmas[df_lemmas.apply(is_rare,axis=1)]

rare_lemmas = list(df_rare_lemmas.index)
len(df_rare_lemmas)
# Out:
# 15042

# %%
### Identification des lemmes communs

common_size = 100
top_0 = df_lemmas.sort_values('infox_0',ascending=False).head(common_size).index
top_1 = df_lemmas.sort_values('infox_1',ascending=False).head(common_size).index
common_lemmas = []
for word in top_0:
    if word in top_1:
        common_lemmas.append(word)
len(common_lemmas)

len(common_lemmas)
# Out:
# 84

# %%
ignore_lemmas = common_lemmas + rare_lemmas
lemma_vocabulary = [lemma for lemma in df_lemmas['lemma'] if lemma not in ignore_lemmas]
print(f'Lemmes = Total lemmes - lemmes communs - lemmes rares = {len(lemma_vocabulary)}')
# Out:
# Lemmes = Total lemmes - lemmes communs - lemmes rares = 8478

# %% [markdown]
# ### Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words=ignore_lemmas)
#count_vectorizer = CountVectorizer()

# %%
X = vectorizer.fit_transform(df_recueil['lemmas'])
y = df_recueil['infox']

# %%
X.shape
# Out:
# (455, 8554)

# %%
y.value_counts()
# Out:
# 1    228
# 0    227
# Name: infox, dtype: Int64

# %%
y = y.astype(float)

# %% [markdown]
# ### Construction des Datasets d'entrainement et de test

# %%
import sklearn.model_selection

#X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X,y,train_size=0.8,shuffle=True)
X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X,y)

X_train.shape
# Out:
# (341, 8554)

# %% [markdown]
# ### Entrainement du modele

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

classifier = LogisticRegression(C=100.0, random_state=42, solver='lbfgs', multi_class='ovr', max_iter=1000)
#classifier = LogisticRegression(max_iter=1000)

# Fit the model
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=100.0, max_iter=1000, multi_class='ovr', random_state=42)

# %% [markdown]
# ### Mesure des rmésultats

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print('Matrice de confusion')
print(cnf_matrix)
print(f'Accuracy score {metrics.accuracy_score(y_test, y_pred)*100:.2f}%')
print(f'Recall score {metrics.recall_score(y_test, y_pred)*100:.2f}%')
# Out:
# Matrice de confusion
# [[48 13]
#  [11 42]]
# Accuracy score 78.95%
# Recall score 79.25%

# %% [markdown]
# ### Prédictions sur le corpus

# %%
df_pred = df_corpus

# %%
# %%time
X = vectorizer.transform(df_pred['lemmas'])
# Out:
# CPU times: user 15.3 s, sys: 167 ms, total: 15.5 s
# Wall time: 15.5 s

# %%
# %%time
y = classifier.predict(X)
y_proba = classifier.predict_proba(X)[:,1]
# Out:
# CPU times: user 48.2 ms, sys: 6.34 ms, total: 54.5 ms
# Wall time: 52.7 ms

# %%
df_pred.loc[:,'pred_infox'] = y
df_pred.loc[:,'proba_infox'] = y_proba

# %%
df_pred
# Out:
#                                                      url  \
# 0      https://actu.fr/economie/100-euros-le-phare-15...
# 1      https://actu.fr/economie/a-compter-du-1er-janv...
# 2      https://actu.fr/economie/achats-en-ligne-pourq...
# 3      https://actu.fr/economie/aeronautique-salaries...
# 4      https://actu.fr/economie/aide-exceptionnelle-d...
# ...                                                  ...
# 89176  https://www.wikistrike.com/article-vous-voulez...
# 89177  https://www.wikistrike.com/article-vue-d-ensem...
# 89178  https://www.wikistrike.com/article-william-sha...
# 89179  https://www.wikistrike.com/article-youpi-votre...
# 89180  https://www.wikistrike.com/article-zone-humide...
#
#                                                    title  \
# 0      100 euros le phare, 150 euros le parechoc : en...
# 1      A compter du 1er janvier 2021, le prix du timb...
# 2      Achats en ligne : pourquoi Zara fait désormais...
# 3      Aéronautique : les salariés d'Air France disen...
# 4      Aide exceptionnelle de 150 euros : finalement,...
# ...                                                  ...
# 89176  Vous voulez vous faire peur? Venez voir les ré...
# 89177  Vue d'ensemble des récents tremblements de ter...
# 89178                 William Shakespeare, cocaïnomane ?
# 89179  Youpi, Votre ADN sur la Lune pour 10 000 $, pa...
# 89180  Zone humide : une première cartographie mondia...
#
#                                                  article              tag  \
# 0      Le gérant d’une casse de la périphérie de Caen...  ['#Automobile']
# 1      Le prix des timbres augmente à partir du 1er j...               []
# 2      L’enseigne espagnole Zara fait désormais payer...               []
# 3      Image tirée d’une vidéo d’Air France, le 26 ju...               []
# 4      Les bénéficiaires qui vont toucher l’aide exce...               []
# ...                                                  ...              ...
# 89176  Vous voulez vous faire peur? Venez voir les ré...               []
# 89177  Tremblements de terre - vue d'ensemble        ...               []
# 89178  William Shakespeare, cocaïnomane ?  Comment es...               []
# 89179  Votre ADN sur la Lune pour 10 000 $      Sur K...               []
# 89180  Zone humide : une première cartographie mondia...               []
#
#       abstract                                             author  \
# 0         <NA>   Par Alexandra Segond
# Publié le 8 Juil 22 à 18:05
# 1         <NA>   Par Alexandra Segond
# Publié le 4 Août 20 à 16:26
# 2         <NA>       Par Martin Leduc
# Publié le 24 Mai 22 à 18:21
# 3         <NA>  Par Rédaction Actu
# Publié le 27 Juin 20 à 14:0...
# 4         <NA>     Par Johann Foucault
# Publié le 16 Oct 20 à 8:56
# ...        ...                                                ...
# 89176     <NA>                                               <NA>
# 89177     <NA>                                               <NA>
# 89178     <NA>                                               <NA>
# 89179     <NA>                                               <NA>
# 89180     <NA>                                               <NA>
#
#                                                     date             date_iso  \
# 0       Par Alexandra Segond
# Publié le 8 Juil 22 à 18:05                 <NA>
# 1       Par Alexandra Segond
# Publié le 4 Août 20 à 16:26                 <NA>
# 2           Par Martin Leduc
# Publié le 24 Mai 22 à 18:21  2022-05-24T18:21:00
# 3      Par Rédaction Actu
# Publié le 27 Juin 20 à 14:0...  2020-06-27T14:05:00
# 4         Par Johann Foucault
# Publié le 16 Oct 20 à 8:56                 <NA>
# ...                                                  ...                  ...
# 89176  Publié par wikistrike.com
#                     ...  2012-02-29T00:00:00
# 89177  Publié par wikistrike.over-blog.com
#           ...  2011-04-29T00:00:00
# 89178  Publié par wikistrike.over-blog.com
#           ...  2011-06-30T00:00:00
# 89179  Publié par wikistrike.com
#                     ...  2012-07-20T00:00:00
# 89180  Publié par wikistrike.com
#                     ...  2012-05-11T00:00:00
#
#                      site                                               text  \
# 0                 actu.fr  100 euros le phare, 150 euros le parechoc : en...
# 1                 actu.fr  A compter du 1er janvier 2021, le prix du timb...
# 2                 actu.fr  Achats en ligne : pourquoi Zara fait désormais...
# 3                 actu.fr  Aéronautique : les salariés d'Air France disen...
# 4                 actu.fr  Aide exceptionnelle de 150 euros : finalement,...
# ...                   ...                                                ...
# 89176  www.wikistrike.com  Vous voulez vous faire peur? Venez voir les ré...
# 89177  www.wikistrike.com  Vue d'ensemble des récents tremblements de ter...
# 89178  www.wikistrike.com  William Shakespeare, cocaïnomane ?
# William Sha...
# 89179  www.wikistrike.com  Youpi, Votre ADN sur la Lune pour 10 000 $, pa...
# 89180  www.wikistrike.com  Zone humide : une première cartographie mondia...
#
#        ...  inversion_preuve  inverifiable propos_raportes  sources_citees  \
# 0      ...              <NA>          <NA>            <NA>            <NA>
# 1      ...              <NA>          <NA>            <NA>            <NA>
# 2      ...              <NA>          <NA>            <NA>            <NA>
# 3      ...              <NA>          <NA>            <NA>            <NA>
# 4      ...              <NA>          <NA>            <NA>            <NA>
# ...    ...               ...           ...             ...             ...
# 89176  ...              <NA>          <NA>            <NA>            <NA>
# 89177  ...              <NA>          <NA>            <NA>            <NA>
# 89178  ...              <NA>          <NA>            <NA>            <NA>
# 89179  ...              <NA>          <NA>            <NA>            <NA>
# 89180  ...              <NA>          <NA>            <NA>            <NA>
#
#        titre_decale  denigrement  cherry_picking  \
# 0              <NA>         <NA>            <NA>
# 1              <NA>         <NA>            <NA>
# 2              <NA>         <NA>            <NA>
# 3              <NA>         <NA>            <NA>
# 4              <NA>         <NA>            <NA>
# ...             ...          ...             ...
# 89176          <NA>         <NA>            <NA>
# 89177          <NA>         <NA>            <NA>
# 89178          <NA>         <NA>            <NA>
# 89179          <NA>         <NA>            <NA>
# 89180          <NA>         <NA>            <NA>
#
#                                                   lemmas  pred_infox  \
# 0      euro le phare euro le parechoc en france le su...         0.0
# 1      compter du er janvier le prix du timbre postal...         0.0
# 2      achat en ligne pourquoi zara faire désormais p...         0.0
# 3      aéronautique les salarier air france dire adie...         0.0
# 4      aide exceptionnel de euro finalement les bénéf...         0.0
# ...                                                  ...         ...
# 89176  vous vouler vous faire peur venir voir les rém...         0.0
# 89177  voir ensemble des récent tremblement de terre ...         1.0
# 89178  william shakespeare cocaïnomane william shakes...         1.0
# 89179  youpi votre adn sur la lune pour pas plaire vo...         1.0
# 89180  zone humide une premier cartographie mondial i...         0.0
#
#        proba_infox
# 0         0.189406
# 1         0.135723
# 2         0.280795
# 3         0.234967
# 4         0.318328
# ...            ...
# 89176     0.154543
# 89177     0.649637
# 89178     0.736829
# 89179     0.542294
# 89180     0.408190
#
# [89172 rows x 39 columns]

# %% [markdown]
# ### Mesure et observation des résultats

# %%
import numpy as np

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# %%
sns.displot(df_pred["proba_infox"], binwidth=0.1)

# %% [markdown]
# ## Sauvegarde des résultats
# ---

# %%
filename = '221002-CorpusNewsLabelPred.csv'
df_pred.to_csv(f'data/corpus/{predict_filename}',index=False)

# %% [markdown]
# ## Conclusions
# ---

# %% [markdown]
# - Production Corpus Labelisé avec prédictions : OK

# %% [markdown]
# ## Bricolages
# ---

# %%
df_pred
