# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Paillasse d'expérimentation
# ---
#
# ## Sujet : Bag of Words sur Corpus Labelisé
#
# ---

# %% [markdown]
# ## Initialisation de la paillasse
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd

# %% [markdown]
# ## Observations et environnement
# ---

# %% [markdown]
# ### Chargement du corpus

# %%
corpus_filename = '221001-CorpusNewslabel.csv'
corpus_dtypes = {'title':str,'date': str,'date_iso': str}

# %%
df_corpus = pd.read_csv(f'data/corpus/{corpus_filename}', dtype = corpus_dtypes)
df_corpus = df_corpus.convert_dtypes()

# %%
df_corpus[df_corpus['author'].isna()]
# Out:
#                                                    title  \
# 0            Tous les jeunes, portez la nouvelle (russe)
# 1      Adhésion à la Russie : 93% pour le « oui » dan...
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...
# 4                    Donatello : génie de la Renaissance
# 5      Que reste-il de notre souveraineté ? Le 75ème ...
# ...                                                  ...
# 89157  Zelensky est « une marionnette qui fait inutil...
# 89158  Zélensky : l’arnaque de la contre-offensive uk...
# 89159  Zelensky massacre maintenant des citoyens ukra...
# 89160  Zéro mort du coronavirus : comment expliquer l...
# 89161  Zoom – Francis Cousin : « La grande explosion ...
#
#                                                  article  \
# 0      par Pepe Escobar.
# L’OCS à Samarcande et l’Asse...
# 1      Dans les régions de Zaporijia et de Kherson, 9...
# 2      L’argument principal de la ministre est que le...
# 4      Portrait du sculpteur Donatello (1386-1466), p...
# 5      Que reste-il de notre souveraineté ? Le 75ème ...
# ...                                                  ...
# 89157  Encore un journaliste surpris qu’un colonel am...
# 89158  Le président Zelensky et ses alliés de l’Otan ...
# 89159  ZELENSKY A ORDONNÉ QUE TOUTES LES PERSONNES FU...
# 89160  Le Vietnam est une exception dans le monde : a...
# 89161  Francis Cousin, docteur en philosophie, annonc...
#
#                                                      tag abstract author  \
# 0      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>   <NA>
# 1      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>   <NA>
# 2      ['Mot-clés : censure, jacinda ardern, ONU', 'P...     <NA>   <NA>
# 4      ['Culture', 'Culture & Patrimoine', 'Histoire'...     <NA>   <NA>
# 5      ['Sociétal', 'réfléchir et agir', 'souveraineté']     <NA>   <NA>
# ...                                                  ...      ...    ...
# 89157  ['30 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: ...     <NA>   <NA>
# 89158  ['26 septembre 2022 | \n\t\t\t\t\t\t\t\tCatégo...     <NA>   <NA>
# 89159  ['6 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>   <NA>
# 89160  ['23 avril 2020 | \n\t\t\t\t\t\t\t\tCatégorie:...     <NA>   <NA>
# 89161  ['28 mai 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>   <NA>
#
#                                   date             date_iso  \
# 0                    30 septembre 2022  2022-09-30T00:00:00
# 1                    30 septembre 2022  2022-09-30T00:00:00
# 2                    29 septembre 2022  2022-09-29T00:00:00
# 4      Le
# 										27 septembre 2022  2022-09-27T00:00:00
# 5      Le
# 										27 septembre 2022  2022-09-27T00:00:00
# ...                                ...                  ...
# 89157                             <NA>                 <NA>
# 89158                             <NA>                 <NA>
# 89159                             <NA>                 <NA>
# 89160                             <NA>                 <NA>
# 89161                             <NA>                 <NA>
#
#                               site  \
# 0          reseauinternational.net
# 1          reseauinternational.net
# 2                  lemediaen442.fr
# 4              www.breizh-info.com
# 5              www.breizh-info.com
# ...                            ...
# 89157  www.profession-gendarme.com
# 89158  www.profession-gendarme.com
# 89159  www.profession-gendarme.com
# 89160  www.profession-gendarme.com
# 89161  www.profession-gendarme.com
#
#                                                     text  infox  \
# 0      Tous les jeunes, portez la nouvelle (russe)
# pa...      0
# 1      Adhésion à la Russie : 93% pour le « oui » dan...      0
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...      1
# 4      Donatello : génie de la Renaissance
# Portrait d...   <NA>
# 5      Que reste-il de notre souveraineté ? Le 75ème ...   <NA>
# ...                                                  ...    ...
# 89157  Zelensky est « une marionnette qui fait inutil...   <NA>
# 89158  Zélensky : l’arnaque de la contre-offensive uk...   <NA>
# 89159  Zelensky massacre maintenant des citoyens ukra...   <NA>
# 89160  Zéro mort du coronavirus : comment expliquer l...   <NA>
# 89161  Zoom – Francis Cousin : « La grande explosion ...   <NA>
#
#                                                      url
# 0      https://reseauinternational.net/tous-les-jeune...
# 1      https://reseauinternational.net/adhesion-a-la-...
# 2      https://lemediaen442.fr/onu-le-premier-ministr...
# 4      https://www.breizh-info.com/2022/09/27/208410/...
# 5      https://www.breizh-info.com/2022/09/27/208417/...
# ...                                                  ...
# 89157  https://www.profession-gendarme.com/zelensky-e...
# 89158  https://www.profession-gendarme.com/zelensky-l...
# 89159  https://www.profession-gendarme.com/zelensky-m...
# 89160  https://www.profession-gendarme.com/zero-mort-...
# 89161  https://www.profession-gendarme.com/zoom-franc...
#
# [43147 rows x 11 columns]

# %%
df_corpus[df_corpus['url'].isna()]
# Out:
# Empty DataFrame
# Columns: [title, article, tag, abstract, author, date, date_iso, site, text, infox, url]
# Index: []

# %% [markdown]
# ### Chargement du predicteur

# %%
import pickle

pred_filename = 'data/predictors/220930-cv_lr.pp'
with open(pred_filename,'rb') as file:
    predictor = pickle.load(file) 

predictor
# Out:
# {'descriptor': CountVectorizer(stop_words=['de', 'la', 'le', 'les', 'et', 'des', 'en', 'un',
#                              'du', 'est', 'une', 'que', 'pour', 'dans', 'qui',
#                              'il', 'par', 'sur', 'au', 'pas', 'plus', 'ce', 'ne',
#                              'qu', 'se', 'ont', 'avec', 'sont', 'ou', 'son', ...]),
#  'classifier': LogisticRegression(max_iter=1000),
#  'data': ''}

# %% [markdown]
# ## Expérience
# ---

# %% [markdown]
# ### Entrainement nouveau prédicteur (optionel)

# %% [markdown]
# #### Mots non signifiants

# %%
import patat.ml.lex_analyser

lex = patat.ml.lex_analyser.LexAnalyser()

def merge_texts(texts):
    result = ''
    for text in texts:
        result = result + text + '\n'
    return result

def count_words_label(df,label):
    df_texts = pd.pivot_table(df, values='text', index=None, columns=label, aggfunc=merge_texts)
    wc = {}
    word_analysis = {}
    for key in df_texts.keys():
        text = df_texts[key]['text']
        count_colname = label+'_'+str(key)
        wc[key] = lex.count_tokens(lex.get_words(text))
        for word in wc[key]:
            word_dic = word_analysis.get(word,{})
            word_dic[count_colname]=wc[key][word]
            word_analysis[word]=word_dic
    return word_analysis

df_count = pd.DataFrame(count_words_label(df_corpus,'infox')).T
df_count = df_count.fillna(0)

# %%
df_count.shape
# Out:
# (34202, 2)

# %%
df_count
# Out:
#               infox_0.0  infox_1.0
# tous              188.0      350.0
# les              3883.0     7521.0
# jeunes             31.0       89.0
# portez              2.0        0.0
# la               6101.0     9656.0
# ...                 ...        ...
# refuseniks          0.0        1.0
# sentis              0.0        1.0
# consultée           0.0        1.0
# concernaient        0.0        1.0
# jabbed              0.0        1.0
#
# [34202 rows x 2 columns]

# %% [markdown]
# #### Identification des mots rares

# %%
occ_rare = 3
def is_rare(row):
    return row['infox_0.0'] < occ_rare and row['infox_1.0'] < occ_rare

df_rare = df_count[df_count.apply(is_rare,axis=1)]

rare_words = list(df_rare.index)
len(rare_words)

### Identification des mots communs

common_size = 100
top_0 = df_count.sort_values('infox_0.0',ascending=False).head(common_size).index
top_1 = df_count.sort_values('infox_1.0',ascending=False).head(common_size).index
common_words = []
for word in top_0:
    if word in top_1:
        common_words.append(word)
len(common_words)

common_words

ignore_words = common_words + rare_words

# %%
common_words
# Out:
# ['de',
#  'la',
#  'le',
#  'les',
#  'et',
#  'des',
#  'en',
#  'un',
#  'du',
#  'est',
#  'une',
#  'que',
#  'pour',
#  'dans',
#  'qui',
#  'il',
#  'par',
#  'sur',
#  'au',
#  'pas',
#  'plus',
#  'ce',
#  'ne',
#  'qu',
#  'se',
#  'ont',
#  'avec',
#  'sont',
#  'ou',
#  'son',
#  'été',
#  'nous',
#  'aux',
#  'mais',
#  'comme',
#  'cette',
#  'on',
#  'pays',
#  'elle',
#  'fait',
#  'être',
#  'tout',
#  'ces',
#  'même',
#  'leur',
#  'aussi',
#  'sa',
#  'si',
#  'monde',
#  'ses',
#  'contre',
#  'sans',
#  'bien',
#  'vous',
#  'ils',
#  'faire',
#  'depuis',
#  'je',
#  'russie',
#  'deux',
#  'entre',
#  'après',
#  'avait',
#  'guerre',
#  'non',
#  'ukraine',
#  'autres',
#  'peut',
#  'covid',
#  'était',
#  'selon',
#  'avoir',
#  'ans',
#  'tous',
#  'cela',
#  'où',
#  'alors',
#  'leurs',
#  'encore',
#  'très',
#  'moins',
#  'dont',
#  'états',
#  'autre',
#  'également',
#  'état',
#  'cas',
#  'soit']

# %% [markdown]
# #### Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vectorizer = CountVectorizer(stop_words=ignore_words)
#count_vectorizer = CountVectorizer()

# %%
corpus = df_corpus['text']
X = count_vectorizer.fit_transform(corpus)
y = df_corpus['infox']

# %% [markdown]
# ### Construction des Datasets d'entrainement et de test

# %%
df_train = df_corpus[df_corpus['infox'].notna()]
X_train = X[df_train.index]
y_train = df_train['infox']

# %%
X_train.shape
# Out:
# (445, 404172)

# %% [markdown]
# ### Entrainement du modele

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#lr = LogisticRegression(C=100.0, random_state=1, solver='lbfgs', multi_class='ovr', max_iter=1000)
classifier = LogisticRegression(max_iter=1000)

# Fit the model
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ### Prédictions sur le corpus

# %%
df_pred = df_corpus

# %%
vectorizer = predictor['descriptor']
classifier = predictor['classifier']

# %%
# %%time
X = vectorizer.transform(df_pred['text'])
# Out:
# CPU times: user 15.4 s, sys: 135 ms, total: 15.6 s
# Wall time: 15.6 s

# %%
# %%time
y = classifier.predict(X)
y_proba = classifier.predict_proba(X)[:,1]
# Out:
# CPU times: user 50.8 ms, sys: 30.9 ms, total: 81.7 ms
# Wall time: 79.4 ms

# %%
df_pred.loc[:,'y'] = y
df_pred.loc[:,'y_proba'] = y_proba

# %%
df_pred
# Out:
#                                                    title  \
# 0            Tous les jeunes, portez la nouvelle (russe)
# 1      Adhésion à la Russie : 93% pour le « oui » dan...
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...
# 3      Compostage humain: les “funérailles vertes” ga...
# 4                    Donatello : génie de la Renaissance
# ...                                                  ...
# 89157  Zelensky est « une marionnette qui fait inutil...
# 89158  Zélensky : l’arnaque de la contre-offensive uk...
# 89159  Zelensky massacre maintenant des citoyens ukra...
# 89160  Zéro mort du coronavirus : comment expliquer l...
# 89161  Zoom – Francis Cousin : « La grande explosion ...
#
#                                                  article  \
# 0      par Pepe Escobar.
# L’OCS à Samarcande et l’Asse...
# 1      Dans les régions de Zaporijia et de Kherson, 9...
# 2      L’argument principal de la ministre est que le...
# 3      Aux États-Unis, les différents gouvernements r...
# 4      Portrait du sculpteur Donatello (1386-1466), p...
# ...                                                  ...
# 89157  Encore un journaliste surpris qu’un colonel am...
# 89158  Le président Zelensky et ses alliés de l’Otan ...
# 89159  ZELENSKY A ORDONNÉ QUE TOUTES LES PERSONNES FU...
# 89160  Le Vietnam est une exception dans le monde : a...
# 89161  Francis Cousin, docteur en philosophie, annonc...
#
#                                                      tag abstract  \
# 0      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>
# 1      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>
# 2      ['Mot-clés : censure, jacinda ardern, ONU', 'P...     <NA>
# 3                                                     []     <NA>
# 4      ['Culture', 'Culture & Patrimoine', 'Histoire'...     <NA>
# ...                                                  ...      ...
# 89157  ['30 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: ...     <NA>
# 89158  ['26 septembre 2022 | \n\t\t\t\t\t\t\t\tCatégo...     <NA>
# 89159  ['6 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>
# 89160  ['23 avril 2020 | \n\t\t\t\t\t\t\t\tCatégorie:...     <NA>
# 89161  ['28 mai 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>
#
#                      author                                 date  \
# 0                      <NA>                    30 septembre 2022
# 1                      <NA>                    30 septembre 2022
# 2                      <NA>                    29 septembre 2022
# 3      Auteur(s)
# FranceSoir  Publié le 28 septembre 2022 - 13:15
# 4                      <NA>      Le
# 										27 septembre 2022
# ...                     ...                                  ...
# 89157                  <NA>                                 <NA>
# 89158                  <NA>                                 <NA>
# 89159                  <NA>                                 <NA>
# 89160                  <NA>                                 <NA>
# 89161                  <NA>                                 <NA>
#
#                   date_iso                         site  \
# 0      2022-09-30T00:00:00      reseauinternational.net
# 1      2022-09-30T00:00:00      reseauinternational.net
# 2      2022-09-29T00:00:00              lemediaen442.fr
# 3      2022-09-28T13:15:00            www.francesoir.fr
# 4      2022-09-27T00:00:00          www.breizh-info.com
# ...                    ...                          ...
# 89157                 <NA>  www.profession-gendarme.com
# 89158                 <NA>  www.profession-gendarme.com
# 89159                 <NA>  www.profession-gendarme.com
# 89160                 <NA>  www.profession-gendarme.com
# 89161                 <NA>  www.profession-gendarme.com
#
#                                                     text  infox  \
# 0      Tous les jeunes, portez la nouvelle (russe)
# pa...      0
# 1      Adhésion à la Russie : 93% pour le « oui » dan...      0
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...      1
# 3      Compostage humain: les “funérailles vertes” ga...      0
# 4      Donatello : génie de la Renaissance
# Portrait d...   <NA>
# ...                                                  ...    ...
# 89157  Zelensky est « une marionnette qui fait inutil...   <NA>
# 89158  Zélensky : l’arnaque de la contre-offensive uk...   <NA>
# 89159  Zelensky massacre maintenant des citoyens ukra...   <NA>
# 89160  Zéro mort du coronavirus : comment expliquer l...   <NA>
# 89161  Zoom – Francis Cousin : « La grande explosion ...   <NA>
#
#                                                      url    y   y_proba
# 0      https://reseauinternational.net/tous-les-jeune...  0.0  0.002944
# 1      https://reseauinternational.net/adhesion-a-la-...  0.0  0.012630
# 2      https://lemediaen442.fr/onu-le-premier-ministr...  1.0  0.963768
# 3      https://www.francesoir.fr/societe-environnemen...  0.0  0.007914
# 4      https://www.breizh-info.com/2022/09/27/208410/...  0.0  0.075435
# ...                                                  ...  ...       ...
# 89157  https://www.profession-gendarme.com/zelensky-e...  1.0  0.556761
# 89158  https://www.profession-gendarme.com/zelensky-l...  0.0  0.164531
# 89159  https://www.profession-gendarme.com/zelensky-m...  1.0  0.673791
# 89160  https://www.profession-gendarme.com/zero-mort-...  0.0  0.103192
# 89161  https://www.profession-gendarme.com/zoom-franc...  0.0  0.303205
#
# [89162 rows x 13 columns]

# %% [markdown]
# ### Mesure et observation des résultats

# %%
import numpy as np

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# %%
sns.displot(df_pred["y_proba"], binwidth=0.25)

# %%
df_recueil = df_corpus[df_corpus['infox'].notna()]
y_test = df_recueil['infox']
y_pred = df_recueil['y']

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print('Matrice de confusion')
print(cnf_matrix)
print(f'Accuracy score {metrics.accuracy_score(y_test, y_pred)*100:.2f}%')
print(f'Recall score {metrics.recall_score(y_test, y_pred)*100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 from sklearn import metrics
# ----> 2 cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
#       3 print('Matrice de confusion')
#       4 print(cnf_matrix)
#
# File ~/Desktop/Work/Patat/patat-env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:307, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     222 def confusion_matrix(
#     223     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     224 ):
#     225     """Compute confusion matrix to evaluate the accuracy of a classification.
#     226
#     227     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# File ~/Desktop/Work/Patat/patat-env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of unknown and binary targets

# %%
def size(y):
    return 'S' if y<=0.25 else 'L' if y>=0.75 else 'M'

# %%
df_pred['y_bin']=df_pred['y_proba'].apply(size)

# %%
df_pivot_sites = pd.pivot_table(df_pred[['site','y_bin']],index='site',columns='y_bin',aggfunc=np.count_nonzero)

# %%
df_pivot_sites.fillna(0,inplace=True)

# %%
df_pivot_sites['total']=df_pivot_sites['S']+df_pivot_sites['M']+df_pivot_sites['L']

# %%
df_pivot_sites['S_freq']=df_pivot_sites['S']/df_pivot_sites['total']
df_pivot_sites['L_freq']=df_pivot_sites['L']/df_pivot_sites['total']

# %%
df_pivot_sites
# Out:
# y_bin                             L        M        S    total    S_freq  \
# site
# actu.fr                       174.0   1580.0   4006.0   5760.0  0.695486
# fr.novopress.info             106.0    888.0    530.0   1524.0  0.347769
# fr.sott.net                  1478.0   2710.0   1714.0   5902.0  0.290410
# infodujour.fr                 128.0    278.0    612.0   1018.0  0.601179
# lalettrepatriote.com            2.0      8.0      2.0     12.0  0.166667
# lemediaen442.fr              1076.0   3502.0    740.0   5318.0  0.139150
# lesakerfrancophone.fr         994.0    372.0    390.0   1756.0  0.222096
# lesdeqodeurs.fr               120.0     18.0     38.0    176.0  0.215909
# lesmoutonsrebelles.com        762.0   2612.0   1346.0   4720.0  0.285169
# lesobservateurs.ch            130.0    508.0    290.0    928.0  0.312500
# lezarceleurs.blogspot.com    2560.0   1810.0    584.0   4954.0  0.117885
# reseauinternational.net       824.0    930.0    704.0   2458.0  0.286412
# theconversation.com           246.0    492.0   1364.0   2102.0  0.648906
# www.breizh-info.com           230.0   2178.0  11578.0  13986.0  0.827828
# www.cnews.fr                   76.0   1560.0   1718.0   3354.0  0.512224
# www.dreuz.info               1744.0   3812.0   5220.0  10776.0  0.484410
# www.francesoir.fr            3780.0  14330.0  28000.0  46110.0  0.607244
# www.francetvinfo.fr          1032.0  12108.0  17516.0  30656.0  0.571373
# www.legorafi.fr               300.0   5634.0   3382.0   9316.0  0.363031
# www.lelibrepenseur.org       1612.0   4298.0    968.0   6878.0  0.140739
# www.les-crises.fr               2.0      0.0      8.0     10.0  0.800000
# www.lesalonbeige.fr           106.0   2388.0    932.0   3426.0  0.272037
# www.mondialisation.ca          16.0     38.0     10.0     64.0  0.156250
# www.nouvelordremondial.cc      60.0     70.0     64.0    194.0  0.329897
# www.polemia.com               288.0    368.0    604.0   1260.0  0.479365
# www.profession-gendarme.com  1522.0   3544.0   2528.0   7594.0  0.332894
# www.voltairenet.org            14.0      0.0      4.0     18.0  0.222222
# www.wikistrike.com           1788.0   3492.0   2774.0   8054.0  0.344425
#
# y_bin                          L_freq
# site
# actu.fr                      0.030208
# fr.novopress.info            0.069554
# fr.sott.net                  0.250424
# infodujour.fr                0.125737
# lalettrepatriote.com         0.166667
# lemediaen442.fr              0.202332
# lesakerfrancophone.fr        0.566059
# lesdeqodeurs.fr              0.681818
# lesmoutonsrebelles.com       0.161441
# lesobservateurs.ch           0.140086
# lezarceleurs.blogspot.com    0.516754
# reseauinternational.net      0.335232
# theconversation.com          0.117031
# www.breizh-info.com          0.016445
# www.cnews.fr                 0.022660
# www.dreuz.info               0.161841
# www.francesoir.fr            0.081978
# www.francetvinfo.fr          0.033664
# www.legorafi.fr              0.032203
# www.lelibrepenseur.org       0.234370
# www.les-crises.fr            0.200000
# www.lesalonbeige.fr          0.030940
# www.mondialisation.ca        0.250000
# www.nouvelordremondial.cc    0.309278
# www.polemia.com              0.228571
# www.profession-gendarme.com  0.200421
# www.voltairenet.org          0.777778
# www.wikistrike.com           0.222001

# %% [markdown]
# ## Sauvegarde des résultats
# ---

# %%
predict_filename = '221002-CorpusNewsLabelPred.csv'
df_pred.to_csv(f'data/corpus/{predict_filename}',index=False)

# %% [markdown]
# ## Conclusions
# ---

# %% [markdown]
# - Production Corpus Labelisé avec prédictions : OK

# %% [markdown]
# ## Bricolages
# ---

# %%
df_pred
# Out:
#                                                    title  \
# url_
# 0            Tous les jeunes, portez la nouvelle (russe)
# 1      Adhésion à la Russie : 93% pour le « oui » dan...
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...
# 3      Compostage humain: les “funérailles vertes” ga...
# 4                    Donatello : génie de la Renaissance
# ...                                                  ...
# 89157  Zelensky est « une marionnette qui fait inutil...
# 89158  Zélensky : l’arnaque de la contre-offensive uk...
# 89159  Zelensky massacre maintenant des citoyens ukra...
# 89160  Zéro mort du coronavirus : comment expliquer l...
# 89161  Zoom – Francis Cousin : « La grande explosion ...
#
#                                                  article  \
# url_
# 0      par Pepe Escobar.
# L’OCS à Samarcande et l’Asse...
# 1      Dans les régions de Zaporijia et de Kherson, 9...
# 2      L’argument principal de la ministre est que le...
# 3      Aux États-Unis, les différents gouvernements r...
# 4      Portrait du sculpteur Donatello (1386-1466), p...
# ...                                                  ...
# 89157  Encore un journaliste surpris qu’un colonel am...
# 89158  Le président Zelensky et ses alliés de l’Otan ...
# 89159  ZELENSKY A ORDONNÉ QUE TOUTES LES PERSONNES FU...
# 89160  Le Vietnam est une exception dans le monde : a...
# 89161  Francis Cousin, docteur en philosophie, annonc...
#
#                                                      tag abstract  \
# url_
# 0      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>
# 1      ["Faits d'actu", "Faits d'actu", "Faits d'actu...     <NA>
# 2      ['Mot-clés : censure, jacinda ardern, ONU', 'P...     <NA>
# 3                                                     []     <NA>
# 4      ['Culture', 'Culture & Patrimoine', 'Histoire'...     <NA>
# ...                                                  ...      ...
# 89157  ['30 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: ...     <NA>
# 89158  ['26 septembre 2022 | \n\t\t\t\t\t\t\t\tCatégo...     <NA>
# 89159  ['6 mars 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>
# 89160  ['23 avril 2020 | \n\t\t\t\t\t\t\t\tCatégorie:...     <NA>
# 89161  ['28 mai 2022 | \n\t\t\t\t\t\t\t\tCatégorie: A...     <NA>
#
#                      author                                 date  \
# url_
# 0                      <NA>                    30 septembre 2022
# 1                      <NA>                    30 septembre 2022
# 2                      <NA>                    29 septembre 2022
# 3      Auteur(s)
# FranceSoir  Publié le 28 septembre 2022 - 13:15
# 4                      <NA>      Le
# 										27 septembre 2022
# ...                     ...                                  ...
# 89157                  <NA>                                 <NA>
# 89158                  <NA>                                 <NA>
# 89159                  <NA>                                 <NA>
# 89160                  <NA>                                 <NA>
# 89161                  <NA>                                 <NA>
#
#                   date_iso                         site  \
# url_
# 0      2022-09-30T00:00:00      reseauinternational.net
# 1      2022-09-30T00:00:00      reseauinternational.net
# 2      2022-09-29T00:00:00              lemediaen442.fr
# 3      2022-09-28T13:15:00            www.francesoir.fr
# 4      2022-09-27T00:00:00          www.breizh-info.com
# ...                    ...                          ...
# 89157                 <NA>  www.profession-gendarme.com
# 89158                 <NA>  www.profession-gendarme.com
# 89159                 <NA>  www.profession-gendarme.com
# 89160                 <NA>  www.profession-gendarme.com
# 89161                 <NA>  www.profession-gendarme.com
#
#                                                     text  infox    url    y  \
# url_
# 0      Tous les jeunes, portez la nouvelle (russe)
# pa...      0      0  0.0
# 1      Adhésion à la Russie : 93% pour le « oui » dan...      0      1  0.0
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...      1      2  1.0
# 3      Compostage humain: les “funérailles vertes” ga...      0      3  0.0
# 4      Donatello : génie de la Renaissance
# Portrait d...   <NA>      4  0.0
# ...                                                  ...    ...    ...  ...
# 89157  Zelensky est « une marionnette qui fait inutil...   <NA>  89157  1.0
# 89158  Zélensky : l’arnaque de la contre-offensive uk...   <NA>  89158  0.0
# 89159  Zelensky massacre maintenant des citoyens ukra...   <NA>  89159  1.0
# 89160  Zéro mort du coronavirus : comment expliquer l...   <NA>  89160  0.0
# 89161  Zoom – Francis Cousin : « La grande explosion ...   <NA>  89161  0.0
#
#         y_proba
# url_
# 0      0.002944
# 1      0.012630
# 2      0.963768
# 3      0.007914
# 4      0.075435
# ...         ...
# 89157  0.556761
# 89158  0.164531
# 89159  0.673791
# 89160  0.103192
# 89161  0.303205
#
# [89162 rows x 13 columns]
