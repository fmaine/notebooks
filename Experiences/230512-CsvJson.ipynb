# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Dev CsvJson
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %% [markdown]
# ## Environnement

# %%
random_state = 42

# %%
cd ../..
# Out:
# /Volumes/Geek/Work/Patat

# %%
import ast
import importlib
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## Données

# %%
filename = 'data/prod/230510-OIDS-Label.csv'

# %%
df_label = pd.read_csv(filename)
df_label['paragraphs'] = df_label['paragraphs'].apply(ast.literal_eval)
df_label['abstract'].fillna('',inplace=True)

# %%
df_label['infox'].isna().sum()
# Out:
# 36

# %%
df_label = df_label[df_label['infox'].notna()]

# %% [markdown]
# # Experience
# ---

# %% [markdown]
# ## Developpement

# %%
df_label['tags'] = df_label['tags'].apply(ast.literal_eval)

# %%
import json

# %%
def json_encode_cols(df,columns):
    for col in columns:
        df[col]=df[col].apply(json.dumps)

# %%
json_encode_cols(df_label,['paragraphs','tags'])

# %%
df_label['tags'][0]
# Out:
# '["Actualit\\u00e9sCommunaut\\u00e9"]'

# %%
def json_decode_cols(df,columns):
    for col in columns:
        df[col]=df[col].apply(json.loads)

# %%
json_decode_cols(df_label,['paragraphs','tags'])

# %%
df_label['tags'][0]
# Out:
# ['ActualitésCommunauté']

# %%
import patat.util.pd

# %%
importlib.reload(patat.util.pd)
# Out:
# <module 'patat.util.pd' from '/Volumes/Geek/Work/Patat/patat/util/pd.py'>

# %%
patat.util.pd.df_to_csvjson(df_label,['tags','paragraphs','dfgsdfsxg'],'data/tmp/zz.csv')

# %%
zz = patat.util.pd.df_from_csvjson(['tags','paragraphs','sdfgsdfg'],'data/tmp/zz.csv')

# %%
zz
# Out:
#                                                    url                 site  \
# 0    https://www.alnas.fr/actualite/communaute/lara...         www.alnas.fr
# 1    https://www.alnas.fr/actualite/en-vrac/quel-ar...         www.alnas.fr
# 2    https://www.alnas.fr/actualite/politique/laust...         www.alnas.fr
# 3    https://www.alnas.fr/actualite/communaute/nant...         www.alnas.fr
# 4    https://www.alnas.fr/actualite/en-vrac/la-fran...         www.alnas.fr
# ..                                                 ...                  ...
# 890  https://www.francetvinfo.fr/monde/moyen-orient...  www.francetvinfo.fr
# 891  https://www.wikistrike.com/2021/10/une-grande-...   www.wikistrike.com
# 892  https://www.francetvinfo.fr/replay-radio/c-est...  www.francetvinfo.fr
# 893  https://www.breizh-info.com/2022/01/12/177802/...  www.breizh-info.com
# 894  https://www.francetvinfo.fr/politique/emmanuel...  www.francetvinfo.fr
#
# ...

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %%
patat.util.pd.df_to_csvjson(df_label,['tags','paragraphs'],'data/prod/230512-OIDS-Label.csv')

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# # Bricolages
# ---

# %%
df_label
# Out:
#                                                    url                 site  \
# 0    https://www.alnas.fr/actualite/communaute/lara...         www.alnas.fr
# 1    https://www.alnas.fr/actualite/en-vrac/quel-ar...         www.alnas.fr
# 2    https://www.alnas.fr/actualite/politique/laust...         www.alnas.fr
# 3    https://www.alnas.fr/actualite/communaute/nant...         www.alnas.fr
# 4    https://www.alnas.fr/actualite/en-vrac/la-fran...         www.alnas.fr
# ..                                                 ...                  ...
# 895  https://www.francetvinfo.fr/monde/moyen-orient...  www.francetvinfo.fr
# 896  https://www.wikistrike.com/2021/10/une-grande-...   www.wikistrike.com
# 897  https://www.francetvinfo.fr/replay-radio/c-est...  www.francetvinfo.fr
# 898  https://www.breizh-info.com/2022/01/12/177802/...  www.breizh-info.com
# 899  https://www.francetvinfo.fr/politique/emmanuel...  www.francetvinfo.fr
#
# ...

# %%
e
