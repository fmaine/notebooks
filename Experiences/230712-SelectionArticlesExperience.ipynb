# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Sélection d'articles pour expérience d'annotation
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %% [markdown]
# ## Environnement

# %%
random_state = 17

# %%
cd ../..
# Out:
# /Volumes/Geek/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## Données

# %%
import patat.util.file
filename = 'data/prod/230517-OIDS-Label.pickle'
df_label = patat.util.file.pickle_load(filename)

# %%
df_corpus = patat.util.file.pickle_load('data/prod/Corpus.pickle')

# %%
df_corpus
# Out:
#                                                       url  \
# 0       https://ripostelaique.com/7-h-de-garde-a-vue-p...
# 1       https://ripostelaique.com/gregoire-voynet-laco...
# 2       https://ripostelaique.com/terrorisme-les-ukrai...
# 3       https://ripostelaique.com/le-charognard-sorj-c...
# 4       https://ripostelaique.com/pourris-de-black-blo...
# ...                                                   ...
# 101680  https://www.lelibrepenseur.org/une-histoire-vi...
# 101681              https://www.lelibrepenseur.org/actus/
# 101682  https://www.lelibrepenseur.org/affiche-des-dec...
# 101683         https://www.lelibrepenseur.org/communaute/
# 101684  https://www.lelibrepenseur.org/utilisation-des...
#
#                           site  \
# 0            ripostelaique.com
# 1            ripostelaique.com
# 2            ripostelaique.com
# 3            ripostelaique.com
# 4            ripostelaique.com
# ...                        ...
# 101680  www.lelibrepenseur.org
# 101681  www.lelibrepenseur.org
# 101682  www.lelibrepenseur.org
# 101683  www.lelibrepenseur.org
# 101684  www.lelibrepenseur.org
#
#                                                     title  \
# 0       7 h de garde à vue pour avoir créé le Paillass...
# 1       Grégoire-Voynet-Lacombe : la première ligne qu...
# 2       Terrorisme : les Ukrainiens attaquent un bus s...
# 3       Le charognard Sorj Chalandon a sur les mains l...
# 4       Pourris de Black Blocs homophobes, ils ont amo...
# ...                                                   ...
# 101680              Une histoire vieille comme le monde !
# 101681                                              Actus
# 101682  Affiche des décès et malaises de sportifs de h...
# 101683                                         Communauté
# 101684             Utilisation des cookies sur notre site
#
#                                                   article            author  \
# 0       Lui il a le droit de nous emmerder, de nous co...   Christine Tasin
# 1       Je viens de me rendre compte que pour le Tourn...    Paul Le Poulpe
# 2       Vous ne lirez jamais ceci dans la presse mains...  Valérie Bérenger
# 3       Sorj Chalandon (de son vrai prénom Georges, ce...     Bernard Bayle
# 4       ﻿Un drame épouvantable a eu lieu, ce 1er mai, ...     Pierre Cassen
# ...                                                   ...               ...
# 101680                                                NaN        Par\nAdmin
# 101681                                                NaN         Par\nuser
# 101682                                                NaN               NaN
# 101683                                                NaN               NaN
# 101684                                                NaN               NaN
#
#                    date                         tags  \
# 0          31 mars 2023                   [COLLABOS]
# 1       10 février 2023             [RIPOSTE LAIQUE]
# 2           3 mars 2023  [GUERRE OTAN CONTRE RUSSIE]
# 3           22 mai 2023                     [MEDIAS]
# 4            3 mai 2023         [HUMOUR ET DERISION]
# ...                 ...                          ...
# 101680       4 mai 2010            ['in\nPolitique']
# 101681   7 juillet 2007  ['in\nÀ la une, Politique']
# 101682              NaN                           []
# 101683              NaN                           []
# 101684              NaN                           []
#
#                                                paragraphs  \
# 0       [Lui il a le droit de nous emmerder, de nous c...
# 1       [Je viens de me rendre compte que pour le Tour...
# 2       [Vous ne lirez jamais ceci dans la presse main...
# 3       [Sorj Chalandon (de son vrai prénom Georges, c...
# 4       [﻿, Un drame épouvantable a eu lieu, ce 1er ma...
# ...                                                   ...
# 101680  [Certains veulent des preuves ! Ils ont raison...
# 101681  [Dernière vidéo !, Il était temps, enfin ! Je ...
# 101682  [Alors que nous avons des corps athlétiques, d...
# 101683  [Vous devez avoir l’application Telegram pré-i...
# 101684  [Les cookies sont des fichiers texte qui sont ...
#
#                    date_iso abstract  c_count  p_count
# 0       2023-03-31T00:00:00               NaN      NaN
# 1       2023-02-10T00:00:00               NaN      NaN
# 2       2023-03-03T00:00:00               NaN      NaN
# 3       2023-05-22T00:00:00               NaN      NaN
# 4       2023-05-03T00:00:00               NaN      NaN
# ...                     ...      ...      ...      ...
# 101680  2010-05-04T00:00:00      NaN   7851.0     16.0
# 101681  2007-07-07T00:00:00      NaN   2173.0     12.0
# 101682                  NaN      NaN   2193.0      3.0
# 101683                  NaN      NaN   2926.0      3.0
# 101684                  NaN      NaN   7663.0     16.0
#
# [101200 rows x 12 columns]

# %% [markdown]
# # Experience
# ---

# %% [markdown]
# ## url_h

# %%
import patat.util.text

# %%
df_corpus['url_h']=df_corpus['url'].apply(patat.util.text.compress)

# %%
df_corpus['url_labelizer']="http://localhost:8000/labelize?url_h="+df_corpus['url_h']

# %% [markdown]
# ## Filtrage Corpus

# %%
df_label['url']
# Out:
# 0      https://www.alnas.fr/actualite/communaute/lara...
# 1      https://lesmoutonsrebelles.com/les-reseaux-soc...
# 2      https://lesmoutonsrebelles.com/un-rapport-du-p...
# 3      https://lesmoutonsrebelles.com/un-sondage-defa...
# 4      https://lemediaen442.fr/le-president-ukrainien...
#                              ...
# 901    https://lezarceleurs.blogspot.com/2022/04/des-...
# 902    https://www.francesoir.fr/politique-monde/resu...
# 903    https://www.francetvinfo.fr/meteo/orages/tempe...
# 904    https://www.francetvinfo.fr/sports/directs/dir...
# 905    https://www.dreuz.info/2021/11/le-mensonge-du-...
# Name: url, Length: 904, dtype: object

# %%
df_corpus['keep']=True

# %% [markdown]
# ### Urls déjà annotées

# %%
df_corpus['keep'][df_corpus['url'].isin(df_label['url'])]=False
# Out:
# /var/folders/fr/mhrqmk5n1xs49b7jl3tgs2r00000gn/T/ipykernel_9910/73580012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_corpus['keep'][df_corpus['url'].isin(df_label['url'])]=False

# %% [markdown]
# ### Sites média alternatifs

# %%
df_corpus.value_counts('site')
# Out:
# site
# www.francesoir.fr                    18454
# www.francetvinfo.fr                  14586
# www.breizh-info.com                   5794
# www.dreuz.info                        5143
# lesalonbeige.fr                       4944
# www.legorafi.fr                       4488
# www.wikistrike.com                    3900
# www.profession-gendarme.com           3196
# ripostelaique.com                     3055
# actu.fr                               2874
# www.lelibrepenseur.org                2617
# fr.sott.net                           2602
# lemediaen442.fr                       2203
# lesmoutonsrebelles.com                2174
# lezarceleurs.blogspot.com             2134
# reseauinternational.net               2108
# www.alnas.fr                          2010
# fr.novopress.info                     1575
# www.cnews.fr                          1519
# www.anguillesousroche.com             1458
# www.epochtimes.fr                     1417
# www.preuvesduparanormal.fr            1295
# www.medias-presse.info                1151
# theconversation.com                   1049
# www.la-petite-souris-normande.com     1028
# www.lesalonbeige.fr                    995
# planetes360.fr                         974
# www.bvoltaire.fr                       970
# qactus.fr                              897
# lecourrier-du-soir.com                 888
# lesakerfrancophone.fr                  874
# lalettrepatriote.com                   653
# www.polemia.com                        628
# www.revue-elements.com                 506
# infodujour.fr                          493
# lesobservateurs.ch                     341
# www.nouvelordremondial.cc               97
# lesdeqodeurs.fr                         93
# www.voltairenet.org                     12
# www.les-crises.fr                        5
# Name: count, dtype: int64

# %%
df_corpus['site'].unique()
# Out:
# array(['ripostelaique.com', 'www.la-petite-souris-normande.com',
#        'reseauinternational.net', 'www.epochtimes.fr',
#        'fr.novopress.info', 'planetes360.fr', 'www.revue-elements.com',
#        'qactus.fr', 'lalettrepatriote.com', 'lemediaen442.fr',
#        'lesalonbeige.fr', 'www.alnas.fr', 'www.anguillesousroche.com',
#        'www.bvoltaire.fr', 'lesdeqodeurs.fr', 'lesobservateurs.ch',
#        'lezarceleurs.blogspot.com', 'www.profession-gendarme.com',
#        'www.voltairenet.org', 'www.wikistrike.com', 'www.francesoir.fr',
#        'infodujour.fr', 'lecourrier-du-soir.com', 'lesakerfrancophone.fr',
#        'www.polemia.com', 'www.breizh-info.com', 'www.lelibrepenseur.org',
#        'www.lesalonbeige.fr', 'www.medias-presse.info',
#        'www.preuvesduparanormal.fr', 'www.dreuz.info',
#        'lesmoutonsrebelles.com', 'www.nouvelordremondial.cc',
#        'fr.sott.net', 'www.cnews.fr', 'actu.fr', 'www.francetvinfo.fr',
#        'www.legorafi.fr', 'theconversation.com', 'www.les-crises.fr'],
#       dtype=object)

# %%
prio_sites =[
    'www.francesoir.fr',
'www.breizh-info.com',
'lesmoutonsrebelles.com',
'lemediaen442.fr',
'www.profession-gendarme.com',
'www.dreuz.info',
'www.lelibrepenseur.org',
'www.polemia.com',
'reseauinternational.net',
'lesakerfrancophone.fr',
'lesalonbeige.fr',
'lesobservateurs.ch',
'www.bvoltaire.fr',
'ripostelaique.com',
'lalettrepatriote.com',
'lezarceleurs.blogspot.com',
'lesdeqodeurs.fr',
]

# %%
df_corpus['keep'][~df_corpus['site'].isin(prio_sites)]=False
# Out:
# /var/folders/fr/mhrqmk5n1xs49b7jl3tgs2r00000gn/T/ipykernel_9910/163636834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_corpus['keep'][~df_corpus['site'].isin(prio_sites)]=False

# %%
df_corpus[df_corpus['keep']]
# Out:
#                                                       url  \
# 0       https://ripostelaique.com/7-h-de-garde-a-vue-p...
# 1       https://ripostelaique.com/gregoire-voynet-laco...
# 2       https://ripostelaique.com/terrorisme-les-ukrai...
# 3       https://ripostelaique.com/le-charognard-sorj-c...
# 4       https://ripostelaique.com/pourris-de-black-blo...
# ...                                                   ...
# 101680  https://www.lelibrepenseur.org/une-histoire-vi...
# 101681              https://www.lelibrepenseur.org/actus/
# 101682  https://www.lelibrepenseur.org/affiche-des-dec...
# 101683         https://www.lelibrepenseur.org/communaute/
# 101684  https://www.lelibrepenseur.org/utilisation-des...
#
#                           site  \
# 0            ripostelaique.com
# 1            ripostelaique.com
# 2            ripostelaique.com
# 3            ripostelaique.com
# 4            ripostelaique.com
# ...                        ...
# 101680  www.lelibrepenseur.org
# 101681  www.lelibrepenseur.org
# 101682  www.lelibrepenseur.org
# 101683  www.lelibrepenseur.org
# 101684  www.lelibrepenseur.org
#
#                                                     title  \
# 0       7 h de garde à vue pour avoir créé le Paillass...
# 1       Grégoire-Voynet-Lacombe : la première ligne qu...
# 2       Terrorisme : les Ukrainiens attaquent un bus s...
# 3       Le charognard Sorj Chalandon a sur les mains l...
# 4       Pourris de Black Blocs homophobes, ils ont amo...
# ...                                                   ...
# 101680              Une histoire vieille comme le monde !
# 101681                                              Actus
# 101682  Affiche des décès et malaises de sportifs de h...
# 101683                                         Communauté
# 101684             Utilisation des cookies sur notre site
#
#                                                   article            author  \
# 0       Lui il a le droit de nous emmerder, de nous co...   Christine Tasin
# 1       Je viens de me rendre compte que pour le Tourn...    Paul Le Poulpe
# 2       Vous ne lirez jamais ceci dans la presse mains...  Valérie Bérenger
# 3       Sorj Chalandon (de son vrai prénom Georges, ce...     Bernard Bayle
# 4       ﻿Un drame épouvantable a eu lieu, ce 1er mai, ...     Pierre Cassen
# ...                                                   ...               ...
# 101680                                                NaN        Par\nAdmin
# 101681                                                NaN         Par\nuser
# 101682                                                NaN               NaN
# 101683                                                NaN               NaN
# 101684                                                NaN               NaN
#
#                    date                         tags  \
# 0          31 mars 2023                   [COLLABOS]
# 1       10 février 2023             [RIPOSTE LAIQUE]
# 2           3 mars 2023  [GUERRE OTAN CONTRE RUSSIE]
# 3           22 mai 2023                     [MEDIAS]
# 4            3 mai 2023         [HUMOUR ET DERISION]
# ...                 ...                          ...
# 101680       4 mai 2010            ['in\nPolitique']
# 101681   7 juillet 2007  ['in\nÀ la une, Politique']
# 101682              NaN                           []
# 101683              NaN                           []
# 101684              NaN                           []
#
#                                                paragraphs  \
# 0       [Lui il a le droit de nous emmerder, de nous c...
# 1       [Je viens de me rendre compte que pour le Tour...
# 2       [Vous ne lirez jamais ceci dans la presse main...
# 3       [Sorj Chalandon (de son vrai prénom Georges, c...
# 4       [﻿, Un drame épouvantable a eu lieu, ce 1er ma...
# ...                                                   ...
# 101680  [Certains veulent des preuves ! Ils ont raison...
# 101681  [Dernière vidéo !, Il était temps, enfin ! Je ...
# 101682  [Alors que nous avons des corps athlétiques, d...
# 101683  [Vous devez avoir l’application Telegram pré-i...
# 101684  [Les cookies sont des fichiers texte qui sont ...
#
#                    date_iso abstract  c_count  p_count  \
# 0       2023-03-31T00:00:00               NaN      NaN
# 1       2023-02-10T00:00:00               NaN      NaN
# 2       2023-03-03T00:00:00               NaN      NaN
# 3       2023-05-22T00:00:00               NaN      NaN
# 4       2023-05-03T00:00:00               NaN      NaN
# ...                     ...      ...      ...      ...
# 101680  2010-05-04T00:00:00      NaN   7851.0     16.0
# 101681  2007-07-07T00:00:00      NaN   2173.0     12.0
# 101682                  NaN      NaN   2193.0      3.0
# 101683                  NaN      NaN   2926.0      3.0
# 101684                  NaN      NaN   7663.0     16.0
#
#                                            url_h  \
# 0       776efba8738639036cb0b90edee71c8351a02e60
# 1       a7ebbdd943e73bb917f8a2d413b35d7fd7fe039b
# 2       046b086d61bd51843d411236a08c3933b3837566
# 3       742981bc5027dd0483a82ac89c288d1e7337abdf
# 4       3a929eb6de7a2143f2f98e3742e9918fa474b519
# ...                                          ...
# 101680  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19
# 101681  d4d5a37a8ff545664bea75664c8d8695e70d0941
# 101682  a175027896cf79e76dfad6409694fafacf1919b3
# 101683  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e
# 101684  7c725113f0c9a95c8269c8d7a271d253ae5ede99
#
#                                             url_labelizer  keep
# 0       http://localhost:8000/labelize?url_h=776efba87...  True
# 1       http://localhost:8000/labelize?url_h=a7ebbdd94...  True
# 2       http://localhost:8000/labelize?url_h=046b086d6...  True
# 3       http://localhost:8000/labelize?url_h=742981bc5...  True
# 4       http://localhost:8000/labelize?url_h=3a929eb6d...  True
# ...                                                   ...   ...
# 101680  http://localhost:8000/labelize?url_h=8c7a6ecf4...  True
# 101681  http://localhost:8000/labelize?url_h=d4d5a37a8...  True
# 101682  http://localhost:8000/labelize?url_h=a17502789...  True
# 101683  http://localhost:8000/labelize?url_h=6ba257c7b...  True
# 101684  http://localhost:8000/labelize?url_h=7c725113f...  True
#
# [54845 rows x 15 columns]

# %% [markdown]
# ## Prédiction infox

# %% [markdown]
# ### Construction des textes

# %%
def text_from_row(row):
    result = ''
    title = str(row['title'])
    abstract = str(row['abstract'])
    if title:
        result += title + '\n'
    if abstract:
        result += abstract + '\n'
    for paragraph in row['paragraphs']:
        result += paragraph + '\n'
    return result

# %%
df_corpus['text']=df_corpus.apply(text_from_row,axis=1)

# %%
df_corpus
# Out:
#                                                       url  \
# 0       https://ripostelaique.com/7-h-de-garde-a-vue-p...
# 1       https://ripostelaique.com/gregoire-voynet-laco...
# 2       https://ripostelaique.com/terrorisme-les-ukrai...
# 3       https://ripostelaique.com/le-charognard-sorj-c...
# 4       https://ripostelaique.com/pourris-de-black-blo...
# ...                                                   ...
# 101680  https://www.lelibrepenseur.org/une-histoire-vi...
# 101681              https://www.lelibrepenseur.org/actus/
# 101682  https://www.lelibrepenseur.org/affiche-des-dec...
# 101683         https://www.lelibrepenseur.org/communaute/
# 101684  https://www.lelibrepenseur.org/utilisation-des...
#
#                           site  \
# 0            ripostelaique.com
# 1            ripostelaique.com
# 2            ripostelaique.com
# 3            ripostelaique.com
# 4            ripostelaique.com
# ...                        ...
# 101680  www.lelibrepenseur.org
# 101681  www.lelibrepenseur.org
# 101682  www.lelibrepenseur.org
# 101683  www.lelibrepenseur.org
# 101684  www.lelibrepenseur.org
#
#                                                     title  \
# 0       7 h de garde à vue pour avoir créé le Paillass...
# 1       Grégoire-Voynet-Lacombe : la première ligne qu...
# 2       Terrorisme : les Ukrainiens attaquent un bus s...
# 3       Le charognard Sorj Chalandon a sur les mains l...
# 4       Pourris de Black Blocs homophobes, ils ont amo...
# ...                                                   ...
# 101680              Une histoire vieille comme le monde !
# 101681                                              Actus
# 101682  Affiche des décès et malaises de sportifs de h...
# 101683                                         Communauté
# 101684             Utilisation des cookies sur notre site
#
#                                                   article            author  \
# 0       Lui il a le droit de nous emmerder, de nous co...   Christine Tasin
# 1       Je viens de me rendre compte que pour le Tourn...    Paul Le Poulpe
# 2       Vous ne lirez jamais ceci dans la presse mains...  Valérie Bérenger
# 3       Sorj Chalandon (de son vrai prénom Georges, ce...     Bernard Bayle
# 4       ﻿Un drame épouvantable a eu lieu, ce 1er mai, ...     Pierre Cassen
# ...                                                   ...               ...
# 101680                                                NaN        Par\nAdmin
# 101681                                                NaN         Par\nuser
# 101682                                                NaN               NaN
# 101683                                                NaN               NaN
# 101684                                                NaN               NaN
#
#                    date                         tags  \
# 0          31 mars 2023                   [COLLABOS]
# 1       10 février 2023             [RIPOSTE LAIQUE]
# 2           3 mars 2023  [GUERRE OTAN CONTRE RUSSIE]
# 3           22 mai 2023                     [MEDIAS]
# 4            3 mai 2023         [HUMOUR ET DERISION]
# ...                 ...                          ...
# 101680       4 mai 2010            ['in\nPolitique']
# 101681   7 juillet 2007  ['in\nÀ la une, Politique']
# 101682              NaN                           []
# 101683              NaN                           []
# 101684              NaN                           []
#
#                                                paragraphs  \
# 0       [Lui il a le droit de nous emmerder, de nous c...
# 1       [Je viens de me rendre compte que pour le Tour...
# 2       [Vous ne lirez jamais ceci dans la presse main...
# 3       [Sorj Chalandon (de son vrai prénom Georges, c...
# 4       [﻿, Un drame épouvantable a eu lieu, ce 1er ma...
# ...                                                   ...
# 101680  [Certains veulent des preuves ! Ils ont raison...
# 101681  [Dernière vidéo !, Il était temps, enfin ! Je ...
# 101682  [Alors que nous avons des corps athlétiques, d...
# 101683  [Vous devez avoir l’application Telegram pré-i...
# 101684  [Les cookies sont des fichiers texte qui sont ...
#
#                    date_iso abstract  c_count  p_count  \
# 0       2023-03-31T00:00:00               NaN      NaN
# 1       2023-02-10T00:00:00               NaN      NaN
# 2       2023-03-03T00:00:00               NaN      NaN
# 3       2023-05-22T00:00:00               NaN      NaN
# 4       2023-05-03T00:00:00               NaN      NaN
# ...                     ...      ...      ...      ...
# 101680  2010-05-04T00:00:00      NaN   7851.0     16.0
# 101681  2007-07-07T00:00:00      NaN   2173.0     12.0
# 101682                  NaN      NaN   2193.0      3.0
# 101683                  NaN      NaN   2926.0      3.0
# 101684                  NaN      NaN   7663.0     16.0
#
#                                            url_h  \
# 0       776efba8738639036cb0b90edee71c8351a02e60
# 1       a7ebbdd943e73bb917f8a2d413b35d7fd7fe039b
# 2       046b086d61bd51843d411236a08c3933b3837566
# 3       742981bc5027dd0483a82ac89c288d1e7337abdf
# 4       3a929eb6de7a2143f2f98e3742e9918fa474b519
# ...                                          ...
# 101680  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19
# 101681  d4d5a37a8ff545664bea75664c8d8695e70d0941
# 101682  a175027896cf79e76dfad6409694fafacf1919b3
# 101683  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e
# 101684  7c725113f0c9a95c8269c8d7a271d253ae5ede99
#
#                                             url_labelizer  keep  \
# 0       http://localhost:8000/labelize?url_h=776efba87...  True
# 1       http://localhost:8000/labelize?url_h=a7ebbdd94...  True
# 2       http://localhost:8000/labelize?url_h=046b086d6...  True
# 3       http://localhost:8000/labelize?url_h=742981bc5...  True
# 4       http://localhost:8000/labelize?url_h=3a929eb6d...  True
# ...                                                   ...   ...
# 101680  http://localhost:8000/labelize?url_h=8c7a6ecf4...  True
# 101681  http://localhost:8000/labelize?url_h=d4d5a37a8...  True
# 101682  http://localhost:8000/labelize?url_h=a17502789...  True
# 101683  http://localhost:8000/labelize?url_h=6ba257c7b...  True
# 101684  http://localhost:8000/labelize?url_h=7c725113f...  True
#
#                                                      text
# 0       7 h de garde à vue pour avoir créé le Paillass...
# 1       Grégoire-Voynet-Lacombe : la première ligne qu...
# 2       Terrorisme : les Ukrainiens attaquent un bus s...
# 3       Le charognard Sorj Chalandon a sur les mains l...
# 4       Pourris de Black Blocs homophobes, ils ont amo...
# ...                                                   ...
# 101680  Une histoire vieille comme le monde !\nnan\nCe...
# 101681  Actus\nnan\nDernière vidéo !\nIl était temps, ...
# 101682  Affiche des décès et malaises de sportifs de h...
# 101683  Communauté\nnan\nVous devez avoir l’applicatio...
# 101684  Utilisation des cookies sur notre site\nnan\nL...
#
# [101200 rows x 16 columns]

# %%
df_corpus['c_count']=df_corpus['text'].apply(len)

# %%
df_corpus = df_corpus[df_corpus['c_count']>500]

# %% [markdown]
# ### Prédictions

# %%
import patat.util.file

# %%
predictor = patat.util.file.pickle_load('data/prod/230705-PredInfox.pkl')

# %%
X = df_corpus['text'].values

# %%
X[1]
# Out:
# 'Grégoire-Voynet-Lacombe : la première ligne qu’il nous faut\nJe viens de me rendre compte que pour le Tournoi des 6 nations féminin, ou trans c’est selon, on a une super première ligne.\nEn pilier droit, elle te tient la mêlée, c’est un roc, on a Olivia Pachyderme. Pour la bouger faut au moins deux tracto-pelles et encore ! La Olivia il lui faut plus d’un mensonge pour l’impressionner, c’est une bête de guerre !\nLa future sumo Olivia Grégoire prise en flagrant délit de mensonge – Riposte Laique\nElle t’écrase du regard !\nEn talonneur, Karine Sumo-Lacombe, elle n’a pas la même morphologie, elle est plus râblée, mais elle est parfaite pour le poste. C’est une artiste, sa spécialité c’est la gratte, tout ce qui traîne elle le récupère, elle ne laisse rien à l’adversaire, c’est une goulue, une vraie gagneuse. Elle te transforme une planche pourrie en lingot d’or !\nIl manquait le pilier gauche et hier, la révélation ! Elle était tombée dans les toilettes sèches de l’histoire et grâce à une fantastique audition devant le comité de sélection elle a réalisé son grand retour.\nLa Voynette a pris du volume, contrairement à la ville de Paris, elle s’est densifiée. Lors de son intervention elle n’a pas été prise au dépourvu, elle a su faire pivoter la mêlée adverse en lui embrouillant la tête.\nSon art rhétorique est du niveau du Vérantanplan, face aux membres du comité elle était en fusion, elle les aplatit avec son métal inconnu, sans avoir besoin de recourir au géranium.\nAlors c’est vrai t’as l’impression qu’elle est en état de troisième mi-temps perpétuelle ! Elle a peut-être chargé en Nobrium, ceci prouve son implication.\nElle voulait le poste, elle l’a obtenu !\nEt dernier point, le "nobrium", ce métal qui n\'existe juste pas.On fusionne des molécules aussi, première nouvelle. pic.twitter.com/ewdBSW0uzl\n— Dragonfire🐉 (@Draagonfire2) February 8, 2023\nhttps://twitter.com/i/status/1623382644418289667\nAvec une telle première ligne tu peux voyager, tu crains personne. Par exemple chez les yankees, ce trio d’anthologie ne se serait pas fait marcher dessus comme la maigrichonne du RC Twitter qui a été enfoncée jusque dans son en-but !\nJ\'espère que vous appréciez le moment à sa juste valeur. Moi je me délecte. pic.twitter.com/W0o5ekVzv5\n— On m\'appelle 404 (@Red_Pill_Report) February 9, 2023\nhttps://twitter.com/i/status/1623687761663340545\nJ’y pense soudainement et si on les envoyait en Ukraine ! Avec leur puissance elles repoussent Vlad jusqu’à Vladivostok…\nhttps://youtu.be/p4XsIBJEIlk\nPaul Le Poulpe\nITER c’est comme si un sprinter s’entraînait pour dépasser le mur du son.ITER ne marchera jamais pour fournir de l’énergie commercialisable. ITER est un projet inutile, coûteux et insensé. Je suppose que Macron est pour.\nben dit donc …les Lacombe , Grégoire et autre Avoinée , on a plus vite fait de leur monter dessus que de faire le tour …c’est ce que vont faire à coup sûr les lignes adverses.\nMonter là dessus…il faut du courage pour se taper la face nord, et encore moins comme les partisans d.attaquer par derrière.Depuis l’antiquite les 3 grâces-lire les 3 grasses – ont mal vieilli … Bon courage aux grampions volontaires  .Que l’homme est petit devant la merdeglace .\nLa faute à la cantine ***** les narines bourrées de cocaïne ! C’est cela la gauche caviar, la France déconstruite de Macron !\nVoilà une idée qu’elle est bonne ! elles pourraient prendre le connard de Bézier dans leurs bagages…….\nla mére voynet s’est pris 30 ans en pleine téte !! la vache l’écolo a force de ne pas manger de viande et bouffer que des graines et du quinoa …..\nKabout, C’est vrai elle est devenue totalement difforme . Attends voir, quand les iels vont commencer a manger des vers et des insectes. A force de faire de l’écolo ils  et elles vont se transformer en plantes vertes, justes bonnes pour les chameaux. Quant à Twitter et les censeurs , j’espère qu’ils vont en avoir jusque dans le derrière car moi aussi j’ai été censuré et supprimé le compte ...

# %%
y=predictor.predict_proba(X)

# %%
df_corpus['infox_proba']=y[:,1]
# Out:
# /var/folders/fr/mhrqmk5n1xs49b7jl3tgs2r00000gn/T/ipykernel_9910/4263704096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_corpus['infox_proba']=y[:,1]

# %% [markdown]
# ## Sélections données de test

# %% [markdown]
# ### Méthode standard

# %% [raw]
# df_keep = df_corpus[df_corpus['keep']]

# %% [raw]
# random_state=10

# %% [raw]
# df_infox = df_keep[df_keep['infox_proba']>0.8].sample(50,random_state=random_state)

# %% [raw]
# df_noninfox = df_keep[df_keep['infox_proba']<0.2].sample(50,random_state=random_state)

# %% [raw]
# df_test = pd.concat([df_infox,df_noninfox]).sample(frac=1,random_state=random_state)

# %% [raw]
# df_test.value_counts('site')

# %% [markdown]
# ### Méthode équilibrée

# %%
df_keep = df_corpus[df_corpus['keep']]

# %%
df_infox = df_keep[df_keep['infox_proba']>0.8]

# %%
df_infox.value_counts('site')
# Out:
# site
# www.francesoir.fr              1143
# lezarceleurs.blogspot.com       880
# reseauinternational.net         572
# lemediaen442.fr                 498
# www.profession-gendarme.com     430
# www.lelibrepenseur.org          418
# lesakerfrancophone.fr           412
# ripostelaique.com               386
# www.dreuz.info                  325
# lesmoutonsrebelles.com          202
# lesalonbeige.fr                 118
# www.breizh-info.com              71
# www.polemia.com                  66
# lesdeqodeurs.fr                  33
# lesobservateurs.ch               29
# www.bvoltaire.fr                 14
# lalettrepatriote.com              7
# Name: count, dtype: int64

# %%
df_noninfox = df_keep[df_keep['infox_proba']<0.2]

# %%
df_noninfox.value_counts('site')
# Out:
# site
# www.francesoir.fr              10110
# www.breizh-info.com             4597
# www.dreuz.info                  2222
# lesalonbeige.fr                 2169
# www.profession-gendarme.com     1209
# lesmoutonsrebelles.com           692
# ripostelaique.com                663
# www.bvoltaire.fr                 459
# www.lelibrepenseur.org           447
# lemediaen442.fr                  368
# reseauinternational.net          345
# lalettrepatriote.com             214
# lesobservateurs.ch               143
# www.polemia.com                  112
# lezarceleurs.blogspot.com        104
# lesakerfrancophone.fr             50
# lesdeqodeurs.fr                    8
# Name: count, dtype: int64

# %%
list_dfs = []
for site in prio_sites:
    print(site)
    list_dfs.append(df_infox[df_infox['site']==site].sample(2,random_state=random_state))
    list_dfs.append(df_noninfox[df_noninfox['site']==site].sample(2,random_state=random_state))
# Out:
# www.francesoir.fr
# www.breizh-info.com
# lesmoutonsrebelles.com
# lemediaen442.fr
# www.profession-gendarme.com
# www.dreuz.info
# www.lelibrepenseur.org
# www.polemia.com
# reseauinternational.net
# lesakerfrancophone.fr
# lesalonbeige.fr
# lesobservateurs.ch
# www.bvoltaire.fr
# ripostelaique.com
# lalettrepatriote.com
# lezarceleurs.blogspot.com
# lesdeqodeurs.fr

# %%
df_balanced = pd.concat(list_dfs)

# %%
df_sup_infox = df_infox[~df_infox['url'].isin(df_balanced['url'])].sample(16,random_state=random_state)

# %%
df_sup_noninfox = df_noninfox[~df_noninfox['url'].isin(df_balanced['url'])].sample(16,random_state=random_state)

# %%
df_test = pd.concat([df_balanced,df_sup_infox,df_sup_noninfox]).sample(frac=1,random_state=random_state)

# %% [markdown]
# ## Méthode Equilibrée 2

# %%
list_dfs = []
for site in prio_sites:
    print(site)
    list_dfs.append(df_infox[df_infox['site']==site].sample(3,random_state=random_state))
    list_dfs.append(df_noninfox[df_noninfox['site']==site].sample(3,random_state=random_state))
# Out:
# www.francesoir.fr
# www.breizh-info.com
# lesmoutonsrebelles.com
# lemediaen442.fr
# www.profession-gendarme.com
# www.dreuz.info
# www.lelibrepenseur.org
# www.polemia.com
# reseauinternational.net
# lesakerfrancophone.fr
# lesalonbeige.fr
# lesobservateurs.ch
# www.bvoltaire.fr
# ripostelaique.com
# lalettrepatriote.com
# lezarceleurs.blogspot.com
# lesdeqodeurs.fr

# %%
df_balanced = pd.concat(list_dfs)

# %%
df_sup_infox = df_infox[~df_infox['url'].isin(df_balanced['url'])].sample(9,random_state=random_state)

df_sup_noninfox = df_noninfox[~df_noninfox['url'].isin(df_balanced['url'])].sample(9,random_state=random_state)

df_test = pd.concat([df_balanced,df_sup_infox,df_sup_noninfox]).sample(frac=1,random_state=random_state)

# %%
df_test
# Out:
#                                                       url  \
# 38685   https://lesakerfrancophone.fr/47eme-journee-de...
# 55371   https://www.breizh-info.com/2020/10/13/152314/...
# 28267   https://reseauinternational.net/la-chine-le-pr...
# 100512  https://www.lelibrepenseur.org/royaume-uni-les...
# 40242   https://lesakerfrancophone.fr/selon-ubs-les-pr...
# ...                                                   ...
# 50806   https://lemediaen442.fr/loi-climat-le-gouverne...
# 35063   https://www.breizh-info.com/2022/05/28/187243/...
# 82340   https://lesmoutonsrebelles.com/secte-sexuelle-...
# 75517   https://www.dreuz.info/2012/05/souhail-chicha-...
# 29432   https://www.francesoir.fr/culture/le-getty-mus...
#
#                            site  \
# 38685     lesakerfrancophone.fr
# 55371       www.breizh-info.com
# 28267   reseauinternational.net
# 100512   www.lelibrepenseur.org
# 40242     lesakerfrancophone.fr
# ...                         ...
# 50806           lemediaen442.fr
# 35063       www.breizh-info.com
# 82340    lesmoutonsrebelles.com
# 75517            www.dreuz.info
# 29432         www.francesoir.fr
#
#                                                     title article  \
# 38685   47eme journée de l’Opération Spéciale russe. D...     NaN
# 55371   Opération escargot des patrons de discothèques...     NaN
# 28267   La Chine : Le premier marché mondial de Smartp...     NaN
# 100512  Royaume-Uni : les vaccinées peuvent transmettr...     NaN
# 40242   Selon UBS, les « propriétés d’assurance tant d...     NaN
# ...                                                   ...     ...
# 50806   Loi climat : le gouvernement va exempter Amazo...     NaN
# 35063   Vers des scénarios cauchemardesques résultant ...     NaN
# 82340   Secte sexuelle : l’ex-star de Smallville Aliso...     NaN
# 75517   Souhail Chicha, musulman, antisémite, extrémis...     NaN
# 29432   Le Getty Museum restitue à Rome son mirifique ...     NaN
#
#                                                   author  \
# 38685                                              Wayan
# 55371                                                NaN
# 28267                                                NaN
# 100512                                     Par\nAguellid
# 40242                                             jmarti
# ...                                                  ...
# 50806                                                NaN
# 35063                                                NaN
# 82340                                                NaN
# 75517   Publié par  Jean-Patrick Grumberg le 13 mai 2012
# 29432                              Auteur(s)\nFranceSoir
#
#                                                     date  \
# 38685                                     avril 13, 2022
# 55371           Le \n\t\t\t\t\t\t\t\t\t\t13 octobre 2020
# 28267                                                NaN
# 100512                                      12 août 2021
# 40242                                      mars 23, 2022
# ...                                                  ...
# 50806                                       22 juin 2021
# 35063               Le \n\t\t\t\t\t\t\t\t\t\t28 mai 2022
# 82340                                                NaN
# 75517   Publié par  Jean-Patrick Grumberg le 13 mai 2012
# 29432                     Publié le 16 août 2022 - 12:55
#
#                                                      tags  \
# 38685                                                  []
# 55371   ['Economie', 'RENNES', 'COVID-19', 'discothèqu...
# 28267   ["Faits d'actu", "Faits d'actu", "Faits d'actu...
# 100512               ['in\nÀ la une, Santé, Vaccination']
# 40242                                                  []
# ...                                                   ...
# 50806   ['Mot-clés : amazon', 'Posté dans Économie, En...
# 35063        ['International', 'armes', 'ukraine', 'usa']
# 82340                                                  []
# 75517                                                  []
# 29432                                                  []
#
#                                                paragraphs  \
# 38685   [Par The Saker – Le 12 avril 2022 – Source The...
# 55371   [13 octobre 2020 : les patrons de discothèques...
# 28267   [Le marché des GSM Chinois a évolué en quelque...
# 100512  [C’est de plus en plus clair, les preuves sont...
# 40242   [Par Birch Gold Group − Le 17 février 2022 − S...
# ...                                                   ...
# 50806   [La majorité LREM s’apprête une fois de plus à...
# 35063   [L’envoi par les États-Unis de l’OTAN d’armes ...
# 82340   [Ce mercredi 15 septembre, le site américain T...
# 75517   [Souhail Chichah, c’est ce musulman normal, au...
# 29432   [Le musée J. Paul Getty de Los Angeles va rest...
#
#                          date_iso abstract  c_count  p_count  \
# 38685   2022-04-13T14:00:32+02:00      NaN    26988     89.0
# 55371         2020-10-13T00:00:00      NaN      580      2.0
# 28267                         NaN      NaN     1996      9.0
# 100512        2021-08-12T00:00:00      NaN     3300      3.0
# 40242   2022-03-23T10:00:25+01:00      NaN     9809     33.0
# ...                           ...      ...      ...      ...
# 50806   2021-06-22T13:35:07+02:00      NaN     2443     10.0
# 35063         2022-05-28T00:00:00      NaN     6227     12.0
# 82340                         NaN      NaN     1999      5.0
# 75517         2012-05-13T00:00:00      NaN     1629      8.0
# 29432         2022-08-16T12:55:00      NaN     1953      9.0
#
#                                            url_h  \
# 38685   fab1e3a09a6de7453206f319774bd527ca864d92
# 55371   04f35e7a1cf3066a783ee1da32959fa27c470058
# 28267   361a904687dd4b1abb189717de7341ce162d21c7
# 100512  b87ba31777277484b2ff1669e3e25d01ee3c0bcc
# 40242   3494ad0901a73fc6ceb2f74ac4ac1930af42b363
# ...                                          ...
# 50806   d04a526d60fa6d67f61c7abcaf45092b8217a24d
# 35063   43b385b0694721c4f90d9eb460b5736893957017
# 82340   2841a1db742a25419c20d4a56eb65d8c05d92f65
# 75517   484d66d32b309a1fd857dec246afdaf1c325075a
# 29432   a4a526320adcd239f061191043a5f13d160ceb8e
#
#                                             url_labelizer  keep  \
# 38685   http://localhost:8000/labelize?url_h=fab1e3a09...  True
# 55371   http://localhost:8000/labelize?url_h=04f35e7a1...  True
# 28267   http://localhost:8000/labelize?url_h=361a90468...  True
# 100512  http://localhost:8000/labelize?url_h=b87ba3177...  True
# 40242   http://localhost:8000/labelize?url_h=3494ad090...  True
# ...                                                   ...   ...
# 50806   http://localhost:8000/labelize?url_h=d04a526d6...  True
# 35063   http://localhost:8000/labelize?url_h=43b385b06...  True
# 82340   http://localhost:8000/labelize?url_h=2841a1db7...  True
# 75517   http://localhost:8000/labelize?url_h=484d66d32...  True
# 29432   http://localhost:8000/labelize?url_h=a4a526320...  True
#
#                                                      text  infox_proba
# 38685   47eme journée de l’Opération Spéciale russe. D...     0.995630
# 55371   Opération escargot des patrons de discothèques...     0.005081
# 28267   La Chine : Le premier marché mondial de Smartp...     0.079825
# 100512  Royaume-Uni : les vaccinées peuvent transmettr...     0.923758
# 40242   Selon UBS, les « propriétés d’assurance tant d...     0.116637
# ...                                                   ...          ...
# 50806   Loi climat : le gouvernement va exempter Amazo...     0.098583
# 35063   Vers des scénarios cauchemardesques résultant ...     0.922718
# 82340   Secte sexuelle : l’ex-star de Smallville Aliso...     0.145957
# 75517   Souhail Chicha, musulman, antisémite, extrémis...     0.064812
# 29432   Le Getty Museum restitue à Rome son mirifique ...     0.113498
#
# [120 rows x 17 columns]

# %% [markdown]
# # Vérification du jeu de données

# %%
df_test.value_counts('site')

# %%
df_test['url_labelizer']="https://app.observatoire.info/labelize?url_h="+df_test['url_h']

# %%
for url in df_test[df_test['site']=='lemediaen442.fr ']['url_labelizer']:
    print(url)

# %%
for i,url in enumerate(df_test['url_labelizer']):
    print(i,url)

# %%
df_test.iloc[1]['paragraphs']

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %%
df_test[['url_h','url_labelizer','title']].to_csv('data/tmp/230713-Experience.csv',index=False)

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# # Bricolages
# ---

# %%
import patat.imp.clean_params

# %%
patat.imp.clean_params.remove_paragraphs

# %%
'toto'.replace('o','u')

# %%
cd Work/Patat
