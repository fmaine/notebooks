# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Import recueil
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## GoogleSheet Recueil

# %%
import patat.util.gsheet

# %%
gs = patat.util.gsheet.GoogleSheet()

# %%
sheet_id = '1RFxwIBYqa_eYcx_LZpTdhi47QbLcesz9NByMfGzdJ8s'
range_name = 'articles labellisés'

# %%
df_recueil = gs.read_df(sheet_id,range_name)

# %%
df_recueil
# Out:
#     #site # article        Site  \
# 0       1         1       Alnas
# 1       1         2       Alnas
# 2       1         3       Alnas
# 3       1         4       Alnas
# 4       1         5       Alnas
# ..    ...       ...         ...
# 600    37       601  Wikistrike
# 601    37       602  Wikistrike
# 602    37       603  Wikistrike
# 603    37       604  Wikistrike
# 604    37       605  Wikistrike
#
#                                                    url Auteur/trice  \
# 0    https://www.alnas.fr/actualite/communaute/lara...
# 1    https://www.alnas.fr/actualite/en-vrac/quel-ar...
# 2    https://www.alnas.fr/actualite/politique/laust...
# 3    https://www.alnas.fr/actualite/communaute/nant...
# 4    https://www.alnas.fr/actualite/en-vrac/la-fran...
# ..                                                 ...          ...
# 600  https://www.wikistrike.com/2022/10/selon-un-an...
# 601  https://www.wikistrike.com/2022/10/la-pologne-...
# 602  https://www.wikistrike.com/2022/11/exclusivite...
# 603  https://www.wikistrike.com/2022/12/zelensky-pa...
# 604  https://www.wikistrike.com/2023/01/le-chef-du-...
#
#            Date                                              Titre  \
# 0    31/10/2022  L’Arabie saoudite organise des célébrations d'...
# 1    19/10/2022  « Quel art ! » : un étudiant en droit invente ...
# 2    18/10/2022  L’Australie ne reconnaît plus Jérusalem comme ...
# 3    17/10/2022  Nantes : une mère musulmane meurt poignardée e...
# 4    10/11/2022  La France condamnée pour avoir placé un enfant...
# ..          ...                                                ...
# 600  04/10/2022  Selon un ancien conseiller du Pentagone, les É...
# 601  31/10/2022  La Pologne s’apprête à s’emparer du territoire...
# 602  19/11/2022  Exclusivité WikiStrike: un physicien en colère...
# 603  23/12/2023  Zelensky parti demander à papa Biden une aide ...
# 604  03/01/2023  Le chef du renseignement iranien assure que la...
#
#                 Explication (pour les infox seulement) infox signé  ...  \
# 0                                                        non   non  ...
# 1                                                        non   non  ...
# 2                                                        non   non  ...
# 3                                                        non   non  ...
# 4    le titre est décalé (donne une impression faus...   non   non  ...
# ..                                                 ...   ...   ...  ...
# 600  colporte les ragots (vrais ou pas) d'un ex con...   oui   non  ...
# 601                         relai de ragots invérifiés   oui   non  ...
# 602  délire total d'un physicien anonyme (ahurissan...   oui   non  ...
# 603  l'article est vide (même si le titre accuse Ze...   oui   non  ...
# 604  long compte rendu d'un interview du chef du re...   non   non  ...
#
#     inversion de la preuve invérifiable titre décalé dénigrement  \
# 0                      non          non          non         non
# 1                      non          non          non         non
# 2                      non          non          non         non
# 3                      non          non          non         non
# 4                      non          non          oui         non
# ..                     ...          ...          ...         ...
# 600                    non          non          non         non
# 601                    non          oui          oui         non
# 602                    non          non          non         non
# 603                    non          non          non         non
# 604                    non          non          non         non
#
#     cherry picking degré infox observateur thème (abandonné)  \
# 0              non                      FB              None
# 1              non                      FB              None
# 2              non                      FB              None
# 3              non                      FB              None
# 4              non                      FB              None
# ..             ...         ...         ...               ...
# 600            non           1          FB              None
# 601            non           2          FB              None
# 602            non           1          FB              None
# 603            non           1          FB              None
# 604            non                      FB              None
#
#     type infox (abandonné) Date de collection (abandonné)
# 0                     None                           None
# 1                     None                           None
# 2                     None                           None
# 3                     None                           None
# 4                     None                           None
# ..                     ...                            ...
# 600                   None                           None
# 601                   None                           None
# 602                   None                           None
# 603                   None                           None
# 604                   None                           None
#
# [605 rows x 36 columns]

# %% [markdown]
# ## Labels et Articles

# %%
import patat.db.label_db

# %%
importlib.reload(patat.db.label_db)
label_filename = ''

label_db = patat.db.label_db.LabelDb(label_filename)
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 266473  https://www.profession-gendarme.com/zelensky-e...               infox
# 266474  https://www.profession-gendarme.com/zelensky-l...               infox
# 266475  https://www.profession-gendarme.com/zelensky-m...               infox
# 266476  https://www.profession-gendarme.com/zero-mort-...               infox
# 266477  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 266473  0.556761  220930-tf_lr.pp  pred
# 266474  0.164531  220930-tf_lr.pp  pred
# 266475  0.673791  220930-tf_lr.pp  pred
# 266476  0.103192  220930-tf_lr.pp  pred
# 266477  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 266473  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 266474  77525354644316eadab53960efa8f5fd028c7f67
# 266475  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 266476  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 266477  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266478 rows x 6 columns]

# %%
import patat.db.article_db

# %%
importlib.reload(patat.db.article_db)
article_filename = ''

article_db = patat.db.article_db.ArticleDb(article_filename)
article_db.df()
# Out:
# /Users/fm/Desktop/Work/Patat/patat/db/article_db.py:37: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#                                                      url  \
# 0      https://www.francesoir.fr/societe/decision-de-...
# 1      https://www.francesoir.fr/societe/onde-de-choc...
# 2      https://infodujour.fr/culture/cinema/62511-cet...
# 3      https://lalettrepatriote.com/colere-des-habita...
# 4                https://lecourrier-du-soir.com/31556-2/
# ...                                                  ...
# 86810  https://www.lelibrepenseur.org/une-histoire-vi...
# 86811              https://www.lelibrepenseur.org/actus/
# 86812  https://www.lelibrepenseur.org/affiche-des-dec...
# 86813         https://www.lelibrepenseur.org/communaute/
# 86814  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Décision de la CPPAP de retirer son agrément à...
# 1      Onde de choc au sein des réseaux du fact-check...
# 2                       Cet argent magique qui disparait
# 3      Colère des habitants de Saint-Varent (79) face...
# 4      France : les riches ont pris le pouvoir : 19 m...
# ...                                                  ...
# 86810              Une histoire vieille comme le monde !
# 86811                                              Actus
# 86812  Affiche des décès et malaises de sportifs de h...
# 86813                                         Communauté
# 86814             Utilisation des cookies sur notre site
#
#                                                  article  \
# 0      C’est par voie de presse le 30 novembre 2022 q...
# 1      ENQUÊTE - Depuis plusieurs mois, FranceSoir en...
# 2      Film de Yannick Kergoat coécrit avec Denis Rob...
# 3      Les problèmes rencontrés avec un petit groupe ...
# 4      Le gouvernement d’Elisabeth Borne compte 19 mi...
# ...                                                  ...
# 86810  Certains veulent des preuves ! Ils ont raison....
# 86811  Dernière vidéo !\nIl était temps, enfin ! Je v...
# 86812  Un nombre inquiétant de sportifs de haut nivea...
# 86813  Notre Réseau Telegram et ses Groupes Secondair...
# 86814  Que sont les cookies ?\n\n\nLes cookies sont d...
#
#                       author                               tag abstract  \
# 0      Auteur(s)\nFranceSoir                                []      NaN
# 1      Auteur(s)\nFranceSoir                                []      NaN
# 2             Patrick Tardit                                []      NaN
# 3             Didier Dewitte                                []      NaN
# 4          By Cheikh Dieng -  ['InternationalEuropePolitique']      NaN
# ...                      ...                               ...      ...
# 86810             Par\nAdmin                               NaN      NaN
# 86811              Par\nuser                               NaN      NaN
# 86812                    NaN                               NaN      NaN
# 86813                    NaN                               NaN      NaN
# 86814                    NaN                               NaN      NaN
#
#                          site             date_iso  \
# 0           www.francesoir.fr  2022-12-02T20:30:00
# 1           www.francesoir.fr  2022-11-28T06:30:00
# 2               infodujour.fr  2022-12-02T00:00:00
# 3        lalettrepatriote.com                  NaN
# 4      lecourrier-du-soir.com  2022-12-04T00:00:00
# ...                       ...                  ...
# 86810  www.lelibrepenseur.org  2010-05-04T00:00:00
# 86811  www.lelibrepenseur.org  2007-07-07T00:00:00
# 86812  www.lelibrepenseur.org                  NaN
# 86813  www.lelibrepenseur.org                  NaN
# 86814  www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0      4e62a771d187c4c2f731f6df853125f17e4f1f3c      NaN
# 1      64992bb518b0bbec3b45df023a0341b114132f83      NaN
# 2      0cced0564a2a888ac80a3def8bccaa1444ac52ab      NaN
# 3      563f899745ed3e801e0b6f7270dc0d720c5859f0      NaN
# 4      22b81d8ade0f14ff38823f46d209d3e3dbcd23b3      NaN
# ...                                         ...      ...
# 86810  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86811  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86812  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86813  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86814  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [86815 rows x 10 columns]

# %% [markdown]
# # Experience
# ---

# %% [markdown]
# ## Merge recueil

# %%
label_db._df
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 266473  https://www.profession-gendarme.com/zelensky-e...               infox
# 266474  https://www.profession-gendarme.com/zelensky-l...               infox
# 266475  https://www.profession-gendarme.com/zelensky-m...               infox
# 266476  https://www.profession-gendarme.com/zero-mort-...               infox
# 266477  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 266473  0.556761  220930-tf_lr.pp  pred
# 266474  0.164531  220930-tf_lr.pp  pred
# 266475  0.673791  220930-tf_lr.pp  pred
# 266476  0.103192  220930-tf_lr.pp  pred
# 266477  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 266473  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 266474  77525354644316eadab53960efa8f5fd028c7f67
# 266475  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 266476  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 266477  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266478 rows x 6 columns]

# %%
label_db.import_recueil_df(df_recueil)

# %%
label_db._df.value_counts('owner')
# Out:
# owner
# 220930-tf_lr.pp                 89156
# 221013-InfoxPred                87178
# 221028-InfoxPipe                77950
# recueil                         12205
# francois.bancilhon@gmail.com       99
# dtype: int64

# %%
article_db._df
# Out:
#                                                      url  \
# 0      https://www.francesoir.fr/societe/decision-de-...
# 1      https://www.francesoir.fr/societe/onde-de-choc...
# 2      https://infodujour.fr/culture/cinema/62511-cet...
# 3      https://lalettrepatriote.com/colere-des-habita...
# 4                https://lecourrier-du-soir.com/31556-2/
# ...                                                  ...
# 86810  https://www.lelibrepenseur.org/une-histoire-vi...
# 86811              https://www.lelibrepenseur.org/actus/
# 86812  https://www.lelibrepenseur.org/affiche-des-dec...
# 86813         https://www.lelibrepenseur.org/communaute/
# 86814  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Décision de la CPPAP de retirer son agrément à...
# 1      Onde de choc au sein des réseaux du fact-check...
# 2                       Cet argent magique qui disparait
# 3      Colère des habitants de Saint-Varent (79) face...
# 4      France : les riches ont pris le pouvoir : 19 m...
# ...                                                  ...
# 86810              Une histoire vieille comme le monde !
# 86811                                              Actus
# 86812  Affiche des décès et malaises de sportifs de h...
# 86813                                         Communauté
# 86814             Utilisation des cookies sur notre site
#
#                                                  article  \
# 0      C’est par voie de presse le 30 novembre 2022 q...
# 1      ENQUÊTE - Depuis plusieurs mois, FranceSoir en...
# 2      Film de Yannick Kergoat coécrit avec Denis Rob...
# 3      Les problèmes rencontrés avec un petit groupe ...
# 4      Le gouvernement d’Elisabeth Borne compte 19 mi...
# ...                                                  ...
# 86810  Certains veulent des preuves ! Ils ont raison....
# 86811  Dernière vidéo !\nIl était temps, enfin ! Je v...
# 86812  Un nombre inquiétant de sportifs de haut nivea...
# 86813  Notre Réseau Telegram et ses Groupes Secondair...
# 86814  Que sont les cookies ?\n\n\nLes cookies sont d...
#
#                       author                               tag abstract  \
# 0      Auteur(s)\nFranceSoir                                []      NaN
# 1      Auteur(s)\nFranceSoir                                []      NaN
# 2             Patrick Tardit                                []      NaN
# 3             Didier Dewitte                                []      NaN
# 4          By Cheikh Dieng -  ['InternationalEuropePolitique']      NaN
# ...                      ...                               ...      ...
# 86810             Par\nAdmin                               NaN      NaN
# 86811              Par\nuser                               NaN      NaN
# 86812                    NaN                               NaN      NaN
# 86813                    NaN                               NaN      NaN
# 86814                    NaN                               NaN      NaN
#
#                          site             date_iso  \
# 0           www.francesoir.fr  2022-12-02T20:30:00
# 1           www.francesoir.fr  2022-11-28T06:30:00
# 2               infodujour.fr  2022-12-02T00:00:00
# 3        lalettrepatriote.com                  NaN
# 4      lecourrier-du-soir.com  2022-12-04T00:00:00
# ...                       ...                  ...
# 86810  www.lelibrepenseur.org  2010-05-04T00:00:00
# 86811  www.lelibrepenseur.org  2007-07-07T00:00:00
# 86812  www.lelibrepenseur.org                  NaN
# 86813  www.lelibrepenseur.org                  NaN
# 86814  www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0      4e62a771d187c4c2f731f6df853125f17e4f1f3c      NaN
# 1      64992bb518b0bbec3b45df023a0341b114132f83      NaN
# 2      0cced0564a2a888ac80a3def8bccaa1444ac52ab      NaN
# 3      563f899745ed3e801e0b6f7270dc0d720c5859f0      NaN
# 4      22b81d8ade0f14ff38823f46d209d3e3dbcd23b3      NaN
# ...                                         ...      ...
# 86810  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86811  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86812  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86813  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86814  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [86815 rows x 10 columns]

# %%
article_db.import_recueil_df(df_recueil)
# Out:
# 1 https://www.lelibrepenseur.org/une-enquete-ouverte-apres-la-decouverte-dossements-humains-dans-un-temple-maconnique-a-trebons/
# 2 https://www.les-crises.fr/le-gouvernement-britannique-se-dirige-droit-vers-l-effondrement-du-marche-du-logement/
# 3 https://www.les-crises.fr/le-canada-soutient-la-nouvelle-strategie-expansionniste-de-l-otan/
# 4 https://www.les-crises.fr/guerre-en-ukraine-un-general-us-de-haut-rang-exhorte-a-la-diplomatie-mais-les-conseillers-de-biden-resistent/
# 5 https://lesmoutonsrebelles.com/la-banque-rothschild-veut-savoir-ce-que-vous-faites-de-votre-argent-en-temps-reel/
# 6 https://lesmoutonsrebelles.com/des-armes-gouvernementales-silencieuses-pour-mener-une-guerre-secrete-contre-vous/
# 7 https://lesmoutonsrebelles.com/coupures-delectricite-comment-nos-elites-dirigeantes-font-entrer-la-france-dans-le-tiers-monde/
# 8 https://lesmoutonsrebelles.com/prenant-acte-dun-vote-defavorable-elon-musk-annonce-son-depart-prochain-de-la-tete-de-twitter/
# 9 https://www.nouvelordremondial.cc/2022/11/18/lukraine-a-t-elle-essaye-de-pousser-lotan-a-declencher-la-troisieme-guerre-mondiale-apres-avoir-bombarde-accidentellement-la-pologne/
# 10 https://www.nouvelordremondial.cc/2022/10/26/les-etats-unis-veulent-demonter-le-centre-de-production-de-puces-electroniques-de-taiwan-pour-proteger-les-chaines-dapprovisionnement-en-cas-dinvasion-de-la-chine/
# 11 https://www.nouvelordremondial.cc/2022/12/12/ladn-de-restes-humains-decouverts-dans-un-puits-medieval-jette-une-lumiere-nouvelle-sur-un-crime-historique-important-et-sur-lhistoire-des-juifs-ashkenazes/
# 12 https://www.nouvelordremondial.cc/2022/12/21/des-scientifiques-trouveront-un-trou-de-ver-pour-voyager-dans-lunivers/
# 13 https://fr.novopress.info/228977/delinquance-et-immigration-cachez-ce-lien-que-je-ne-saurais-voir/
# 14 https://fr.sott.net/article/41040-C-est-de-la-folie-Des-chercheurs-de-Boston-creent-une-souche-plus-mortelle-de-COVID-ce-qui-suscite-des-appels-a-l-arret-de-la-recherche-a-risque-par-gain-de-fonction
# 15 https://fr.sott.net/article/41176-Les-politiques-sanitaires-ont-ete-imposees-a-partir-de-fraudes-scientifiques-massives
# 16 https://fr.sott.net/article/41474-Les-voisins-de-l-Ukraine-se-preparent-a-en-annexer-une-partie-par-l-ouest-et-le-sud-ouest
# Empty DataFrame
# Columns: [url, site, title, article, tag, abstract, author, date, date_iso]
# Index: []

# %%
article_db._df
# Out:
#                                                      url  \
# 0      https://www.alnas.fr/actualite/en-vrac/les-emi...
# 1      https://www.anguillesousroche.com/changement-c...
# 2      https://www.bvoltaire.fr/prediction-pour-2023-...
# 3      https://lesdeqodeurs.fr/le-premier-ministre-or...
# 4      https://lesobservateurs.ch/2022/12/18/herault-...
# ...                                                  ...
# 86822  https://www.lelibrepenseur.org/une-histoire-vi...
# 86823              https://www.lelibrepenseur.org/actus/
# 86824  https://www.lelibrepenseur.org/affiche-des-dec...
# 86825         https://www.lelibrepenseur.org/communaute/
# 86826  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Les Émirats arabes unis et l’Arabie saoudite f...
# 1      Article d’opinion du NY Times : « S’accoupler ...
# 2      Prédiction pour 2023 : ça va bien se passer… j...
# 3      Le Premier ministre Orbán affirme que le scand...
# 4      Hérault : 300 musulmans armés de kalachnikovs ...
# ...                                                  ...
# 86822              Une histoire vieille comme le monde !
# 86823                                              Actus
# 86824  Affiche des décès et malaises de sportifs de h...
# 86825                                         Communauté
# 86826             Utilisation des cookies sur notre site
#
#                                                  article            author  \
# 0      Plus des trois quarts des importations japonai...       Par Sarah -
# 1      « Nous serons plus nombreux à pouvoir monter d...
# 2      Le 31 décembre dernier, Emmanuel Macron était,...   Frédéric Lassez
# 3      Article original datant du 16/12/22 par RMX.ne...
# 4      « La horde sauvage » nouvelle version, sans la...  Francis Gruzelle
# ...                                                  ...               ...
# 86822  Certains veulent des preuves ! Ils ont raison....        Par\nAdmin
# 86823  Dernière vidéo !\nIl était temps, enfin ! Je v...         Par\nuser
# 86824  Un nombre inquiétant de sportifs de haut nivea...               NaN
# 86825  Notre Réseau Telegram et ses Groupes Secondair...               NaN
# 86826  Que sont les cookies ?\n\n\nLes cookies sont d...               NaN
#
#                                                      tag abstract  \
# 0                                  [Actualités, En vrac]
# 1                                [Changement climatique]
# 2                    [Articles\nPolitique\nVoeux Macron]
# 3      [Andrea Cozzolino, Bruxelles, corruption, Éva ...
# 4                                                     []
# ...                                                  ...      ...
# 86822                                                NaN      NaN
# 86823                                                NaN      NaN
# 86824                                                NaN      NaN
# 86825                                                NaN      NaN
# 86826                                                NaN      NaN
#
#                             site             date_iso  \
# 0                   www.alnas.fr  2023-01-03T00:00:00
# 1      www.anguillesousroche.com  2023-01-04T00:00:00
# 2               www.bvoltaire.fr  2023-01-03T00:00:00
# 3                lesdeqodeurs.fr  2022-12-19T00:00:00
# 4             lesobservateurs.ch  2022-12-18T00:00:00
# ...                          ...                  ...
# 86822     www.lelibrepenseur.org  2010-05-04T00:00:00
# 86823     www.lelibrepenseur.org  2007-07-07T00:00:00
# 86824     www.lelibrepenseur.org                  NaN
# 86825     www.lelibrepenseur.org                  NaN
# 86826     www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 86822  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86823  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86824  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86825  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86826  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [86827 rows x 10 columns]

# %% [markdown]
# ### Labelizer

# %% [markdown]
# # Mesure et observation des résultats
# ---

# %%
article_db._df['title'].isna().sum()
# Out:
# 0

# %%
article_db._df=article_db._df[article_db._df['article'].notna()]

# %%
article_db._df[article_db._df.duplicated('url',keep=False)].sort_values('url')
# Out:
# Empty DataFrame
# Columns: [url, title, article, author, tag, abstract, site, date_iso, url_h, c_count]
# Index: []

# %%
article_db._df[article_db._df.duplicated('article',keep=False)].sort_values('article')
# Out:
#                                                      url  \
# 8883   https://www.francesoir.fr/societe-sante/millie...
# 20611  https://www.francesoir.fr/societe-sante/pilote...
# 3615   https://www.bvoltaire.fr/anne-laure-bonnel-la-...
# 4216   https://www.bvoltaire.fr/anne-laure-bonnel-la-...
# 1962   https://www.medias-presse.info/une-parodie-sin...
# ...                                                  ...
# 1435   https://www.medias-presse.info/le-quart-dheure...
# 807    https://ripostelaique.com/2022-zemmour-aura-le...
# 361    https://ripostelaique.com/sortir-de-leurope-qu...
# 21335  https://www.wikistrike.com/2022/05/covid-19-le...
# 13082  https://reseauinternational.net/covid-19-le-bi...
#
#                                                    title  \
# 8883   Pilotes et scientifiques se regroupent au nive...
# 20611  Pilotes et scientifiques se regroupent au nive...
# 3615       Anne-Laure Bonnel, la journaliste qui dérange
# 4216       Anne-Laure Bonnel, la journaliste qui dérange
# 1962                              Une parodie sinon rien
# ...                                                  ...
# 1435   Le quart d’heure de Monsieur K du 27 septembre...
# 807        SORTIR DE L’EUROPE question de vie ou de mort
# 361        SORTIR DE L’EUROPE question de vie ou de mort
# 21335                Covid-19 : Le bilan en 40 questions
# 13082                Covid-19 : Le bilan en 40 questions
#
#                                                  article  \
# 8883   30 compagnies aériennes, des milliers de pilot...
# 20611  30 compagnies aériennes, des milliers de pilot...
# 3615   Anne-Laure Bonnel était inconnue au bataillon ...
# 4216   Anne-Laure Bonnel était inconnue au bataillon ...
# 1962   Cet article vous a plu ? MPI est une associati...
# ...                                                  ...
# 1435   Retrouvez chaque jour, du lundi au jeudi, le q...
# 807    Règlement par chèque à l’ordre de RIPOSTE LAIQ...
# 361    Règlement par chèque à l’ordre de RIPOSTE LAIQ...
# 21335  Résumé (Extrait du livre feuilletable sur notr...
# 13082  Résumé (Extrait du livre feuilletable sur notr...
#
#                                                   author  \
# 8883                               Auteur(s)\nFranceSoir
# 20611                              Auteur(s)\nFranceSoir
# 3615                                     Rémy Mahoudeaux
# 4216                                     Rémy Mahoudeaux
# 1962   Auteur : Pierre-Alain Depauw\n\n\n\n\nSur cet ...
# ...                                                  ...
# 1435   Auteur : MPI-TV\n\n\n\n\nSur cet auteur:\nTous...
# 807                                          Boutique RL
# 361                                          Boutique RL
# 21335                                                NaN
# 13082                                                NaN
#
#                                                      tag abstract  \
# 8883                                                 NaN      NaN
# 20611                                                NaN      NaN
# 3615   ['Articles\n#SELECTION DE BV (1-2)\nMédias\nUk...      NaN
# 4216   ['Articles\n#SELECTION DE BV (1-2)\nMédias\nUk...      NaN
# 1962                                                  []      NaN
# ...                                                  ...      ...
# 1435                                                  []      NaN
# 807                         ['Librairie Riposte Laïque']      NaN
# 361                         ['Librairie Riposte Laïque']      NaN
# 21335                                                NaN      NaN
# 13082                                                NaN      NaN
#
#                           site             date_iso  \
# 8883         www.francesoir.fr  2022-05-23T15:05:00
# 20611        www.francesoir.fr  2022-05-23T15:05:00
# 3615          www.bvoltaire.fr  2022-03-08T00:00:00
# 4216          www.bvoltaire.fr  2022-03-08T00:00:00
# 1962    www.medias-presse.info                  NaN
# ...                        ...                  ...
# 1435    www.medias-presse.info                  NaN
# 807          ripostelaique.com  2020-11-30T00:00:00
# 361          ripostelaique.com  2020-11-30T00:00:00
# 21335       www.wikistrike.com  2022-05-14T00:00:00
# 13082  reseauinternational.net  2022-08-26T00:00:00
#
#                                           url_h  c_count
# 8883   bf989348bbda8766196a07773ce4176f2f7d07e3   8714.0
# 20611  2473a589d7703f0bfa118fcb5d81bdc6e8a0df43   8714.0
# 3615   a092ec1086952b62b5ff89de4a677ff81fa15500   3184.0
# 4216   e437691b6fad069aac365e5b8285b3d608b32622   3184.0
# 1962   3f78f29cb24621b9025b74cb7c010df849c71674    196.0
# ...                                         ...      ...
# 1435   66d0867f7e2b64d6ae16b3c820bd46c25a8677b9    298.0
# 807    284f05b81c69049e7234a2f0c87d72ce56265699    407.0
# 361    1dd3b0d6304521202038ac23ee79e9bda7a865b6    407.0
# 21335  ad06cd76b3a25334d5425c8256189797fbc9089d   6598.0
# 13082  8cd2e870034b3f5bfabac4b587661766b7577405   6598.0
#
# [98 rows x 10 columns]

# %%
sheet_id = '1RFxwIBYqa_eYcx_LZpTdhi47QbLcesz9NByMfGzdJ8s'
range_name = 'vérification o.i'

df_labelizer = gs.read_df(sheet_id,range_name)
df_labelizer
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
#                       site                                                url  \
# 0     1            actu.fr  https://actu.fr/faits-divers/quatre-morts-dans...
# 1     2    francetvinfo.fr  https://www.francetvinfo.fr/economie/budget/co...
# 2     3    francetvinfo.fr  https://www.francetvinfo.fr/sante/contraceptio...
# 3     4  www.francesoir.fr  https://www.francesoir.fr/culture-art/expo-ass...
# 4     5  www.francesoir.fr  https://www.francesoir.fr/culture-celebrites/u...
# ..  ...                ...                                                ...
# 95   96        France Soir  https://www.francesoir.fr/lifestyle-shopping/f...
# 96   97               sott  https://fr.sott.net/article/39833-Hubble-confi...
# 97   98          novopress  https://fr.novopress.info/219709/vous-regardez...
# 98   99     france tv info  https://www.francetvinfo.fr/replay-radio/franc...
# 99  100        France Soir  https://www.francesoir.fr/lifestyle-gastronomi...
#
#                                                auteur        date  \
# 0                                     Nicolas Zaugra   02/05/2018
# 1   M.Damoy, N.Fleury, Y.Bodin, M.Barrois, M.Semer...  21/09/2021
# 2                                                      26/05/2018
# 3
# 4
# ..                                                ...         ...
# 95                                                     17/06/2020
# 96                                                     13/04/2022
# 97                                                     23/10/2020
# 98                                                     07/06/2022
# 99                                                     15/02/2021
#
#    prédiction VERIF prédiction infox fréquence prediction infox infox match  \
# 0                2%                0                        66%   non     1
# 1               15%                0                              non     1
# 2                3%                0                              non     1
# 3               15%                0                              non     1
# 4               35%                0                              non     1
# ..              ...              ...                        ...   ...   ...
# 95            0,387                0                              non     1
# 96             0,73                1                              non     0
# 97             0,26                0                              non     1
# 98            0,145                0                              non     1
# 99            0,238                0                              non     1
#
#    fréquence match
# 0              76%
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 95            None
# 96            None
# 97            None
# 98            None
# 99            None
#
# [100 rows x 11 columns]

# %%
df_labels = df_labelizer[['url']].copy()

# %%
df_labels['label']='infox'

# %%
df_labels['owner']='francois.bancilhon@gmail.com'

# %%
df_labels['type']='obs'

# %%
df_labels['value']=df_labelizer['infox'].apply(label_db.normalize_label)

# %%
df_labels.value_counts('value')
# Out:
# value
# 0.0    52
# 1.0    48
# dtype: int64

# %%
label_db.df().merge(df_labels)
# Out:
#                                                   url  label  value  \
# 0   https://actu.fr/faits-divers/quatre-morts-dans...  infox    0.0
# 1   https://www.francetvinfo.fr/economie/budget/co...  infox    0.0
# 2   https://www.francetvinfo.fr/sante/contraceptio...  infox    0.0
# 3   https://www.francesoir.fr/culture-art/expo-ass...  infox    0.0
# 4   https://www.francesoir.fr/culture-celebrites/u...  infox    0.0
# ..                                                ...    ...    ...
# 95  https://www.francesoir.fr/lifestyle-shopping/f...  infox    0.0
# 96  https://fr.sott.net/article/39833-Hubble-confi...  infox    0.0
# 97  https://fr.novopress.info/219709/vous-regardez...  infox    0.0
# 98  https://www.francetvinfo.fr/replay-radio/franc...  infox    0.0
# 99  https://www.francesoir.fr/lifestyle-gastronomi...  infox    0.0
#
#                            owner type  \
# 0   francois.bancilhon@gmail.com  obs
# 1   francois.bancilhon@gmail.com  obs
# 2   francois.bancilhon@gmail.com  obs
# 3   francois.bancilhon@gmail.com  obs
# 4   francois.bancilhon@gmail.com  obs
# ..                           ...  ...
# 95  francois.bancilhon@gmail.com  obs
# 96  francois.bancilhon@gmail.com  obs
# 97  francois.bancilhon@gmail.com  obs
# 98  francois.bancilhon@gmail.com  obs
# 99  francois.bancilhon@gmail.com  obs
#
#                                        url_h
# 0   5b6a6aca16294236b87a7e0ff7df6232ae5ca4fc
# 1   022ce9aa2e29225d5d7435d125942c6399a00569
# 2   c68fe38ff932e53a1c2ff45eda84b2a60c64b712
# 3   c9d121cc5ca2c3fbb1001c85680a02a6a658757d
# 4   5ee5351e7832abd005a7dd936ad46a5e03cef37f
# ..                                       ...
# 95  11dff6919bbc94894c7d31a6480ae7a19ab9ebd7
# 96  645c3f6c815ce0a0283850d4ed47756c80be4744
# 97  3a1a42c8fbf323dd0a2b69aaa721cc24c8886588
# 98  9660258c54f2a9c83ccbf9cd374dcb52ea831a77
# 99  34a9c70d8ec4accc4b752c593bdf44908a4a4918
#
# [100 rows x 6 columns]

# %%
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 278700  https://www.profession-gendarme.com/zelensky-e...               infox
# 278701  https://www.profession-gendarme.com/zelensky-l...               infox
# 278702  https://www.profession-gendarme.com/zelensky-m...               infox
# 278703  https://www.profession-gendarme.com/zero-mort-...               infox
# 278704  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 278700  0.556761  220930-tf_lr.pp  pred
# 278701  0.164531  220930-tf_lr.pp  pred
# 278702  0.673791  220930-tf_lr.pp  pred
# 278703  0.103192  220930-tf_lr.pp  pred
# 278704  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 278700  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 278701  77525354644316eadab53960efa8f5fd028c7f67
# 278702  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 278703  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 278704  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266588 rows x 6 columns]

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %%
article_db.save_prod()

# %%
label_db.save_prod()

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# - Ajout Recueil
# - Ajour Labelizer

# %% [markdown]
# # Bricolages
# ---
