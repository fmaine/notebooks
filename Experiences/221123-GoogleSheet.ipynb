# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet :  Google Sheet
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## GoogleSheet Recueil

# %%
import patat.util.gsheet

# %%
gs = patat.util.gsheet.GoogleSheet()

# %%
sheet_id = '1RFxwIBYqa_eYcx_LZpTdhi47QbLcesz9NByMfGzdJ8s'
range_name = 'articles labellisés'

# %%
gs.read_df(sheet_id,range_name)
# Out:
#     #site # article        Site  \
# 0       1         1       Alnas
# 1       1         2       Alnas
# 2       1         3       Alnas
# 3       1         4       Alnas
# 4       1         5       Alnas
# ..    ...       ...         ...
# 557    37       558  Wikistrike
# 558    37       559  Wikistrike
# 559    37       560  Wikistrike
# 560    37       561  Wikistrike
# 561    37       562  Wikistrike
#
#                                                    url Auteur/trice  \
# 0    https://www.alnas.fr/actualite/communaute/lara...
# 1    https://www.alnas.fr/actualite/en-vrac/quel-ar...
# 2    https://www.alnas.fr/actualite/politique/laust...
# 3    https://www.alnas.fr/actualite/communaute/nant...
# 4    https://www.alnas.fr/actualite/en-vrac/la-fran...
# ..                                                 ...          ...
# 557  https://www.wikistrike.com/2022/09/coupures-el...
# 558  https://www.wikistrike.com/2022/09/11-septembr...
# 559  https://www.wikistrike.com/2022/10/selon-un-an...
# 560  https://www.wikistrike.com/2022/10/la-pologne-...
# 561  https://www.wikistrike.com/2022/11/exclusivite...
#
#            Date                                              Titre  \
# 0    31/10/2022  L’Arabie saoudite organise des célébrations d'...
# 1    19/10/2022  « Quel art ! » : un étudiant en droit invente ...
# 2    18/10/2022  L’Australie ne reconnaît plus Jérusalem comme ...
# 3    17/10/2022  Nantes : une mère musulmane meurt poignardée e...
# 4    10/11/2022  La France condamnée pour avoir placé un enfant...
# ..          ...                                                ...
# 557  29/09/2022          Coupures électriques imminentes en France
# 558  29/09/2022  11 septembre 2001 : La théorie du « complot pi...
# 559  04/10/2022  Selon un ancien conseiller du Pentagone, les É...
# 560  31/10/2022  La Pologne s’apprête à s’emparer du territoire...
# 561  19/11/2022  Exclusivité WikiStrike: un physicien en colère...
#
#                 Explication (pour les infox seulement) infox signé  ...  \
# 0                                                        non   non  ...
# 1                                                        non   non  ...
# 2                                                        non   non  ...
# 3                                                        non   non  ...
# 4    le titre est décalé (donne une impression faus...   non   non  ...
# ..                                                 ...   ...   ...  ...
# 557  l'article de Reuters ne dit pas ça, il dit que...   oui   non  ...
# 558  les gens qui disent que 9/11 était un complot ...   oui   non  ...
# 559  colporte les ragots (vrais ou pas) d'un ex con...   oui   non  ...
# 560                         relai de ragots invérifiés   oui   non  ...
# 561  délire total d'un physicien anonyme (ahurissan...   oui   non  ...
#
#     inversion de la preuve invérifiable titre décalé dénigrement  \
# 0                      non          non          non         non
# 1                      non          non          non         non
# 2                      non          non          non         non
# 3                      non          non          non         non
# 4                      non          non          oui         non
# ..                     ...          ...          ...         ...
# 557                    non          non          oui         non
# 558                    non          non          non         non
# 559                    non          non          non         non
# 560                    non          oui          oui         non
# 561                    non          non          non         non
#
#     cherry picking degré infox observateur thème (abandonné)  \
# 0              non                      FB              None
# 1              non                      FB              None
# 2              non                      FB              None
# 3              non                      FB              None
# 4              non                      FB              None
# ..             ...         ...         ...               ...
# 557                          1          FB              None
# 558                          2          FB              None
# 559            non           1          FB              None
# 560            non           2          FB              None
# 561            non           1          FB              None
#
#     type infox (abandonné) Date de collection (abandonné)
# 0                     None                           None
# 1                     None                           None
# 2                     None                           None
# 3                     None                           None
# 4                     None                           None
# ..                     ...                            ...
# 557                   None                           None
# 558                   None                           None
# 559                   None                           None
# 560                   None                           None
# 561                   None                           None
#
# [562 rows x 36 columns]

# %% [markdown]
# ## Labels et Articles

# %%
import patat.db.label_db

# %%
importlib.reload(patat.db.label_db)
label_filename = ''

label_db = patat.db.label_db.LabelDb(label_filename)
label_db.df()

# %%
import patat.db.article_db

# %%
importlib.reload(patat.db.article_db)
article_filename = ''

article_db = patat.db.article_db.ArticleDb(article_filename)
article_db.df()

# %% [markdown]
# # Experience
# ---

# %% [markdown]
# ## Exemple

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
#SAMPLE_SPREADSHEET_ID = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
#SAMPLE_RANGE_NAME = 'Class Data!A2:E'
SAMPLE_SPREADSHEET_ID = '1RFxwIBYqa_eYcx_LZpTdhi47QbLcesz9NByMfGzdJ8s'
SAMPLE_RANGE_NAME = 'articles labellisés'

"""Shows basic usage of the Sheets API.
Prints values from a sample spreadsheet.
"""
creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

try:
    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')
    else:
        data = values
#        print('Name, Major:')
#        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
#            print('%s, %s' % (row[0], row[4]))
except HttpError as err:
    print(err)

# %%
df_recueil = pd.DataFrame(data[1:],columns = data[0])

# %%
df_recueil.keys()

# %% [markdown]
# # Mesure et observation des résultats
# ---

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# - ...

# %% [markdown]
# # Bricolages
# ---
