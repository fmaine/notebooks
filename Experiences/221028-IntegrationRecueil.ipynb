# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Intégration du recueil
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Import des labels du recueil

# %%
recueil_filename = 'data/imports/221025-RecueilBrut.csv'

# %%
import patat.db.label_db

# %%
importlib.reload(patat.db.label_db)
label_filename = ''

label_db = patat.db.label_db.LabelDb(label_filename)
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.anguillesousroche.com/actualite/ou...               infox
# 1       https://www.anguillesousroche.com/actualite/ou...               signe
# 2       https://www.anguillesousroche.com/actualite/ou...     entites_nommees
# 3       https://www.anguillesousroche.com/actualite/ou...  entites_coherentes
# 4       https://www.anguillesousroche.com/actualite/ou...    ouverture_esprit
# ...                                                   ...                 ...
# 186286  https://www.profession-gendarme.com/zelensky-e...               infox
# 186287  https://www.profession-gendarme.com/zelensky-l...               infox
# 186288  https://www.profession-gendarme.com/zelensky-m...               infox
# 186289  https://www.profession-gendarme.com/zero-mort-...               infox
# 186290  https://www.profession-gendarme.com/zoom-franc...               infox
#
# ...

# %%
df = label_db._df.drop(label_db._df[label_db._df['owner']=='recueil'].index)

# %%
label_db._df = df

# %%
label_db.import_recueil(recueil_filename)

# %%
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.anguillesousroche.com/actualite/ou...               infox
# 1       https://www.anguillesousroche.com/actualite/ou...               signe
# 2       https://www.anguillesousroche.com/actualite/ou...     entites_nommees
# 3       https://www.anguillesousroche.com/actualite/ou...  entites_coherentes
# 4       https://www.anguillesousroche.com/actualite/ou...    ouverture_esprit
# ...                                                   ...                 ...
# 186286  https://www.profession-gendarme.com/zelensky-e...               infox
# 186287  https://www.profession-gendarme.com/zelensky-l...               infox
# 186288  https://www.profession-gendarme.com/zelensky-m...               infox
# 186289  https://www.profession-gendarme.com/zero-mort-...               infox
# 186290  https://www.profession-gendarme.com/zoom-franc...               infox
#
# ...

# %%
label_db.save_prod()

# %% [markdown]
# # Import des articles du recueil

# %%
import patat.db.article_db

# %%
importlib.reload(patat.db.article_db)
article_filename = ''

article_db = patat.db.article_db.ArticleDb(article_filename)
article_db.df()
# Out:
# /Users/fm/Desktop/Work/Patat/patat/db/article_db.py:35: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#                                                      url  \
# 0      https://www.breizh-info.com/2022/09/30/208531/...
# 1      https://www.breizh-info.com/2022/10/02/208574/...
# 2      https://www.dreuz.info/2022/10/elections-de-mi...
# 3      https://www.dreuz.info/2022/10/lukraine-est-en...
# 4      https://www.dreuz.info/2022/10/la-fda-va-publi...
# ...                                                  ...
# 77959  https://www.lelibrepenseur.org/une-histoire-vi...
# 77960              https://www.lelibrepenseur.org/actus/
# 77961  https://www.lelibrepenseur.org/affiche-des-dec...
# 77962         https://www.lelibrepenseur.org/communaute/
# 77963  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# ...

# %%
article_db.import_recueil(recueil_filename)
# Out:
# 1 https://www.anguillesousroche.com/actualite/ouverture-du-gazoduc-baltic-pipe-qui-relie-la-norvege-et-la-pologne/
# 2 https://www.anguillesousroche.com/technologie/la-cia-aurait-investi-dans-une-puissante-technologie-de-mutation-genetique-et-de-resurrection-de-mammouths-laineux/
# 3 https://www.anguillesousroche.com/actualite/jusqua-present-seuls-9-des-30-etats-membres-de-lotan-ont-exprime-leur-soutien-a-la-candidature-de-lukraine-a-lotan/
# 4 https://bonsens.info/essais-pfizer-sur-le-vaccin-anti-covid-le-rapport-explosif-de-christine-cotton/
# 5 https://www.espritsciencemetaphysiques.com/type-de-personne-qui-serait-plus-susceptible-de-vivre-apres-90-ens-etude.html
# 6 https://www.fdesouche.com/2022/07/07/paris-arme-dun-couteau-un-migrant-clandestin-nigerian-sattaque-a-un-agent-de-securite-puis-menace-des-policiers-a-la-gare-de-lest%ef%bf%bc/
# 7 https://www.globalresearch.ca/why-former-president-trump-mar-a-lago-estate-raided/5790043
# ...

# %%
article_db.save_prod()

# %%
from patat.imp.importer import Importer
imp = Importer()

# %% [markdown]
# # Qualité Corpus

# %%
df = article_db.df()

# %%
df = df[df['title']!='>Mondialisation.ca']

# %%
df.shape
# Out:
# (77950, 11)

# %%
article_db._df = df

# %%
article_db.save_prod()

# %% [markdown]
# ## Mesure et observation des résultats
# ---

# %% [markdown]
# ## Sauvegarde des résultats
# ---

# %% [markdown]
# ## Conclusions
# ---

# %% [markdown]
# - Importation du recueil 500 OK

# %% [markdown]
# ## Bricolages
# ---

# %%
df_recueil = pd.read_csv(recueil_filename)

# %%
df_recueil[df_recueil['url'].apply(article_db.known_url)==False]
