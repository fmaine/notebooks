# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Paillasse d'expérimentation
# ---
#
# ## Sujet : Développement Recueil Manager
#
# ---

# %% [markdown]
# ## Initialisation de la paillasse
# ---

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd

# %% [markdown]
# ## Observations et environnement
# ---

# %% [markdown]
# ### FIchier recueil

# %%
recueil_filename = 'data/imports/recueil d\'observation - articles labellisés.csv'

# %% [markdown]
# ### Fichier Corpus

# %%
corpus_filename = 'data/corpus/221003-CorpusApp.csv'

# %%
dtypes = {'date_iso' : str}
df_corpus = pd.read_csv(corpus_filename, dtype = dtypes)
df_corpus = df_corpus.convert_dtypes()

# %%
df_corpus[df_corpus['url'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, title, article, author, date_iso, site, infox, y_proba]
# Index: []

# %%
df_corpus[df_corpus['infox'].notna()]
# Out:
#                                                      url  \
# 0      https://reseauinternational.net/tous-les-jeune...
# 1      https://reseauinternational.net/adhesion-a-la-...
# 2      https://lemediaen442.fr/onu-le-premier-ministr...
# 3      https://www.francesoir.fr/societe-environnemen...
# 18     https://www.dreuz.info/2022/09/qui-est-elle-an...
# ...                                                  ...
# 87372  https://www.profession-gendarme.com/leffet-kis...
# 87438  https://www.profession-gendarme.com/les-labora...
# 87510  https://www.profession-gendarme.com/lettre-ouv...
# 88737  https://www.profession-gendarme.com/tour-de-fr...
# 88933  https://www.profession-gendarme.com/un-rapport...
#
#                                                    title  \
# 0            Tous les jeunes, portez la nouvelle (russe)
# 1      Adhésion à la Russie : 93% pour le « oui » dan...
# 2      ONU – Le Premier ministre de Nouvelle-Zélande ...
# ...

# %% [markdown]
# ## Expérience
# ---

# %% [markdown]
# ### CorpusMgr

# %%
import patat.imp.corpus_mgr

# %%
importlib.reload(patat.imp.corpus_mgr)
# Out:
# <module 'patat.imp.corpus_mgr' from '/Users/fm/Desktop/Work/Patat/patat/imp/corpus_mgr.py'>

# %%
cm = patat.imp.corpus_mgr.CorpusMgr()

# %%
cm.load(corpus_filename)
# Out:
# /Users/fm/Desktop/Work/Patat/patat/imp/corpus_mgr.py:32: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   self._df = pd.read_csv(filename)
#                                                      url  \
# 0      https://reseauinternational.net/tous-les-jeune...
# 1      https://reseauinternational.net/adhesion-a-la-...
# 2      https://lemediaen442.fr/onu-le-premier-ministr...
# 3      https://www.francesoir.fr/societe-environnemen...
# 4      https://www.breizh-info.com/2022/09/27/208410/...
# ...                                                  ...
# 89157  https://www.profession-gendarme.com/zelensky-e...
# 89158  https://www.profession-gendarme.com/zelensky-l...
# 89159  https://www.profession-gendarme.com/zelensky-m...
# 89160  https://www.profession-gendarme.com/zero-mort-...
# 89161  https://www.profession-gendarme.com/zoom-franc...
#
#                                                    title  \
# ...

# %% [markdown]
# ### RecueilMgr

# %%
import patat.imp.recueil_mgr

# %%
importlib.reload(patat.imp.recueil_mgr)
# Out:
# <module 'patat.imp.recueil_mgr' from '/Users/fm/Desktop/Work/Patat/patat/imp/recueil_mgr.py'>

# %%
rm = patat.imp.recueil_mgr.RecueilMgr()

# %%
rm.load_raw(recueil_filename)
# Out:
#      # site  # article                 Site  \
# 0         1          1  Anguille sous roche
# 1         1          2  Anguille sous roche
# 2         1          3  Anguille sous roche
# 3         2          4          bonsens.org
# 4         3          5               breizh
# ..      ...        ...                  ...
# 481      39        481           Wikistrike
# 482      39        482           Wikistrike
# 483      39        483           Wikistrike
# 484      39        484           Wikistrike
# 485      39        485           Wikistrike
#
#                                                    url Auteur/trice  \
# 0    https://www.anguillesousroche.com/actualite/ou...         <NA>
# 1    https://www.anguillesousroche.com/technologie/...         <NA>
# 2    https://www.anguillesousroche.com/actualite/ju...         <NA>
# 3    https://bonsens.info/essais-pfizer-sur-le-vacc...         <NA>
# 4    https://www.breizh-info.com/2022/02/23/180457/...         <NA>
# ...

# %%
df = rm._df.drop(columns=['Site'])

# %%
df_articles = rm.acquire(df)
# Out:
# https://www.anguillesousroche.com/actualite/ouverture-du-gazoduc-baltic-pipe-qui-relie-la-norvege-et-la-pologne/
# https://www.anguillesousroche.com/technologie/la-cia-aurait-investi-dans-une-puissante-technologie-de-mutation-genetique-et-de-resurrection-de-mammouths-laineux/
# https://www.anguillesousroche.com/actualite/jusqua-present-seuls-9-des-30-etats-membres-de-lotan-ont-exprime-leur-soutien-a-la-candidature-de-lukraine-a-lotan/
# https://bonsens.info/essais-pfizer-sur-le-vaccin-anti-covid-le-rapport-explosif-de-christine-cotton/
# https://www.breizh-info.com/2022/02/23/180457/tests-vaccins-pass-fabrique-de-la-panique-braquage-des-comptes-publics/
# https://www.breizh-info.com/2022/02/20/180182/covid-19-la-pandemie-et-les-vaccins-pour-mieux-justifier-un-coup-detat-mondial/
# https://www.breizh-info.com/2022/04/19/185260/covid-19-une-epidemie-quasiment-terminee-avant-lete-au-niveau-mondial/
# ...

# %%
df_parse = rm.parse(df_articles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df_parse = rm.parse(df_articles)
#
# File ~/Desktop/Work/Patat/patat/imp/recueil_mgr.py:60, in RecueilMgr.parse(self, df)
#      59 def parse(self, df: pd.DataFrame) -> pd.DataFrame:
# ---> 60     parsed = df.apply(lambda row: parse_article(row['url'], row['html'], row['site']), axis=1)
#      61     df_parsed = pd.DataFrame(list(parsed))
#      62     df_articles = df_parsed[df_parsed['parse_method'] == 'parse']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:8833, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8822 from pandas.core.apply import frame_apply
#    8824 op = frame_apply(
#    8825     self,
#    8826     func=func,
#    (...)
#    8831     kwargs=kwargs,
#    8832 )
# ...

# %% [markdown]
# ## Mesure
# ---

# %% [markdown]
# ## Sauvegarde des résultats
# ---

# %%
predict_filename = '221002-CorpusNewsLabelPred.csv'
df_pred.to_csv(f'data/corpus/{predict_filename}',index=False)

# %% [markdown]
# ## Conclusions
# ---

# %% [markdown]
# - Production Corpus Labelisé avec prédictions : OK

# %% [markdown]
# ## Bricolages
# ---

# %%
df_pred
