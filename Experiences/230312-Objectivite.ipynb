# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Import recueil
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
cd ../..
# Out:
# /Volumes/Geek/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## GoogleSheet Recueil

# %%
import patat.util.gsheet

# %%
gs = patat.util.gsheet.GoogleSheet()

# %%
sheet_id = '1qr62-tvqvKumHibv2Eb1fu59ocyxX__T1LKs9akHL00'
range_name = 'test François'

# %%
df_fb = gs.read_df(sheet_id,range_name)

# %%
sheet_id = '1qr62-tvqvKumHibv2Eb1fu59ocyxX__T1LKs9akHL00'
range_name = 'test Guy'
df_gp = gs.read_df(sheet_id,range_name)

# %%
df_gp = df_gp[df_gp['infox'].notna()]

# %%
df_fb = df_fb[df_fb['infox'].notna()]

# %%
df_gp
# Out:
#                                                 Id  \
# 0      1  690c5d67f6729a085293aedf56777918a4caeb3e
# 1      2  0843ad68f83d11ac7db6feeb15f10dad15d1b797
# 2      3  9148e2ba0bc5b380c6009c43fdc6e90c214d316c
# 3      4  c0e46901a1482e2cc9406fbe869490e23faed0a2
# 4      5  934366c5659908bd56571277a7f5fa02c441e56b
# ..   ...                                       ...
# 96    97  4f275d07e088d4223824bc1e7f72166bf06c3340
# 97    98  723809e1689f302ac3a54b1e5f31b451cee75278
# 98    99  166d32300f4d7766a82fe39a1185f35bc347c05f
# 99   100  c4e58c361007e21a202d6e98b357b1730fefe758
# 103   22  a065524d78a076eecd5d5b6a3af0643691a5ca28
#
#                                              Labelizer infox  \
# 0    https://observatoire.info/labelize?url_h=690c5...   oui
# 1    https://observatoire.info/labelize?url_h=0843a...   non
# 2    https://observatoire.info/labelize?url_h=9148e...   non
# 3    https://observatoire.info/labelize?url_h=c0e46...   non
# 4    https://observatoire.info/labelize?url_h=93436...   non
# ..                                                 ...   ...
# 96   https://observatoire.info/labelize?url_h=4f275...   non
# 97   https://observatoire.info/labelize?url_h=72380...   non
# 98   https://observatoire.info/labelize?url_h=166d3...   oui
# 99   https://observatoire.info/labelize?url_h=c4e58...   non
# 103  https://observatoire.info/labelize?url_h=a0655...   oui
#
#     lieux, dates et personnes points de vue différents présentés faits  \
# 0                         non                                non   oui
# 1                         oui                                non   oui
# 2                         non                                non   oui
# 3                         oui                                non   oui
# 4                         oui                                non   oui
# ..                        ...                                ...   ...
# 96                        non                                non   oui
# 97                        oui                                non   oui
# 98                        non                                non   oui
# 99                        non                                non   oui
# 103                       non                                non   oui
#
#     opinions propos rapporté sources citées fausse nouvelle insinuations  \
# 0        non             oui            oui             oui          non
# 1        non             non            non             non          non
# 2        non             non            npn             non          non
# 3        non             non            non             non          non
# 4        non             non            non             non          non
# ..       ...             ...            ...             ...          ...
# 96       non             non            non             non          non
# 97       non             oui            oui             non          non
# 98       oui             non            non             oui          oui
# 99       oui             non            non             non          non
# 103      non             oui            oui             non          non
#
#     exagération invérifiable titre décalé cherry picking  \
# 0           oui          oui          non            non
# 1           non          oui          bob            non
# 2           non          non          non            bob
# 3           non          non          non            non
# 4           non          non          non            non
# ..          ...          ...          ...            ...
# 96          non          non          non            non
# 97          non          non          non           nono
# 98          oui          oui          non            non
# 99          non          oui          non             on
# 103         non          non          non            non
#
#                                    justification infox
# 0         embaumeurs qui détectent des décès du COVID
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 96                                                None
# 97                                                None
# 98                                    fausses nouvelle
# 99                                                None
# 103  un Dr Ph D. s'attaque à la vaccination et à Ma...
#
# [98 rows x 17 columns]

# %% [markdown]
# ## Labels et Articles

# %%
import patat.db.label_db

# %%
importlib.reload(patat.db.label_db)
label_filename = ''

label_db = patat.db.label_db.LabelDb(label_filename)
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 266957  https://www.profession-gendarme.com/zelensky-e...               infox
# 266958  https://www.profession-gendarme.com/zelensky-l...               infox
# 266959  https://www.profession-gendarme.com/zelensky-m...               infox
# 266960  https://www.profession-gendarme.com/zero-mort-...               infox
# 266961  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 266957  0.556761  220930-tf_lr.pp  pred
# 266958  0.164531  220930-tf_lr.pp  pred
# 266959  0.673791  220930-tf_lr.pp  pred
# 266960  0.103192  220930-tf_lr.pp  pred
# 266961  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 266957  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 266958  77525354644316eadab53960efa8f5fd028c7f67
# 266959  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 266960  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 266961  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266962 rows x 6 columns]

# %%
import patat.db.article_db

# %%
importlib.reload(patat.db.article_db)
article_filename = ''

article_db = patat.db.article_db.ArticleDb(article_filename)
article_db.df()
# Out:
# /Volumes/Geek/Work/Patat/patat/db/article_db.py:37: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#                                                      url  \
# 0      https://www.alnas.fr/actualite/en-vrac/les-emi...
# 1      https://www.anguillesousroche.com/changement-c...
# 2      https://www.bvoltaire.fr/prediction-pour-2023-...
# 3      https://lesdeqodeurs.fr/le-premier-ministre-or...
# 4      https://lesobservateurs.ch/2022/12/18/herault-...
# ...                                                  ...
# 86822  https://www.lelibrepenseur.org/une-histoire-vi...
# 86823              https://www.lelibrepenseur.org/actus/
# 86824  https://www.lelibrepenseur.org/affiche-des-dec...
# 86825         https://www.lelibrepenseur.org/communaute/
# 86826  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Les Émirats arabes unis et l’Arabie saoudite f...
# 1      Article d’opinion du NY Times : « S’accoupler ...
# 2      Prédiction pour 2023 : ça va bien se passer… j...
# 3      Le Premier ministre Orbán affirme que le scand...
# 4      Hérault : 300 musulmans armés de kalachnikovs ...
# ...                                                  ...
# 86822              Une histoire vieille comme le monde !
# 86823                                              Actus
# 86824  Affiche des décès et malaises de sportifs de h...
# 86825                                         Communauté
# 86826             Utilisation des cookies sur notre site
#
#                                                  article            author  \
# 0      Plus des trois quarts des importations japonai...       Par Sarah -
# 1      « Nous serons plus nombreux à pouvoir monter d...               NaN
# 2      Le 31 décembre dernier, Emmanuel Macron était,...   Frédéric Lassez
# 3      Article original datant du 16/12/22 par RMX.ne...               NaN
# 4      « La horde sauvage » nouvelle version, sans la...  Francis Gruzelle
# ...                                                  ...               ...
# 86822  Certains veulent des preuves ! Ils ont raison....        Par\nAdmin
# 86823  Dernière vidéo !\nIl était temps, enfin ! Je v...         Par\nuser
# 86824  Un nombre inquiétant de sportifs de haut nivea...               NaN
# 86825  Notre Réseau Telegram et ses Groupes Secondair...               NaN
# 86826  Que sont les cookies ?\n\n\nLes cookies sont d...               NaN
#
#                                                      tag abstract  \
# 0                              ['Actualités', 'En vrac']      NaN
# 1                              ['Changement climatique']      NaN
# 2                  ['Articles\nPolitique\nVoeux Macron']      NaN
# 3      ['Andrea Cozzolino', 'Bruxelles', 'corruption'...      NaN
# 4                                                     []      NaN
# ...                                                  ...      ...
# 86822                                                NaN      NaN
# 86823                                                NaN      NaN
# 86824                                                NaN      NaN
# 86825                                                NaN      NaN
# 86826                                                NaN      NaN
#
#                             site             date_iso  \
# 0                   www.alnas.fr  2023-01-03T00:00:00
# 1      www.anguillesousroche.com  2023-01-04T00:00:00
# 2               www.bvoltaire.fr  2023-01-03T00:00:00
# 3                lesdeqodeurs.fr  2022-12-19T00:00:00
# 4             lesobservateurs.ch  2022-12-18T00:00:00
# ...                          ...                  ...
# 86822     www.lelibrepenseur.org  2010-05-04T00:00:00
# 86823     www.lelibrepenseur.org  2007-07-07T00:00:00
# 86824     www.lelibrepenseur.org                  NaN
# 86825     www.lelibrepenseur.org                  NaN
# 86826     www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0      d9726057bcbe0182c5bec27f5cc2e1c73594a361      NaN
# 1      7dce1f2479231f6e9606c69da67444b634c2d32d      NaN
# 2      b11055abd5b8f6c385a79096ae29d90f8a0348ff      NaN
# 3      790fa6da6e1d9151e0ad6ce08627f738ad1e864c      NaN
# 4      2b314df4e0710050ae0441d6423177362127c784      NaN
# ...                                         ...      ...
# 86822  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86823  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86824  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86825  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86826  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [86827 rows x 10 columns]

# %% [markdown]
# # Experience
# ---

# %%
df_fb['fb-infox'] = df_fb['infox'].apply(label_db.normalize_label)
df_fb = df_fb[df_fb['fb-infox'].notna()]

# %%
df_gp['gp-infox'] = df_gp['infox'].apply(label_db.normalize_label)
df_gp = df_gp[df_gp['gp-infox'].notna()]

# %%
df_fb['infox']
# Out:
# 0     oui
# 1     non
# 2     non
# 3     non
# 4     non
#      ...
# 95    non
# 96    non
# 97    non
# 98    non
# 99    non
# Name: infox, Length: 98, dtype: object

# %%
df_merge = pd.merge(df_fb[['Id','fb-infox']],df_gp[['Id','gp-infox']])

# %%
df_merge
# Out:
#                                           Id  fb-infox  gp-infox
# 0   690c5d67f6729a085293aedf56777918a4caeb3e       1.0       1.0
# 1   0843ad68f83d11ac7db6feeb15f10dad15d1b797       0.0       0.0
# 2   9148e2ba0bc5b380c6009c43fdc6e90c214d316c       0.0       0.0
# 3   c0e46901a1482e2cc9406fbe869490e23faed0a2       0.0       0.0
# 4   934366c5659908bd56571277a7f5fa02c441e56b       0.0       0.0
# ..                                       ...       ...       ...
# 91  49b2e53a8ad27e6ecf099823204c211b779c2777       0.0       0.0
# 92  4f275d07e088d4223824bc1e7f72166bf06c3340       0.0       0.0
# 93  723809e1689f302ac3a54b1e5f31b451cee75278       0.0       0.0
# 94  166d32300f4d7766a82fe39a1185f35bc347c05f       0.0       1.0
# 95  c4e58c361007e21a202d6e98b357b1730fefe758       0.0       0.0
#
# [96 rows x 3 columns]

# %%
df_labels = label_db.df()

# %%
df_predict = df_labels[df_labels['owner']=='221028-InfoxPipe']

# %%
df_predict['Id']=df_predict['url_h']
# Out:
# /var/folders/fr/mhrqmk5n1xs49b7jl3tgs2r00000gn/T/ipykernel_9965/2947665307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Id']=df_predict['url_h']

# %%
df_merge = pd.merge(df_merge,df_predict[['Id','value']])

# %%
df_merge['bool_value']=df_merge['value'].apply(lambda v: 1 if v >0.5 else 0)

# %%
df_merge
# Out:
#                                           Id  fb-infox  gp-infox     value  \
# 0   690c5d67f6729a085293aedf56777918a4caeb3e       1.0       1.0  0.841567
# 1   0843ad68f83d11ac7db6feeb15f10dad15d1b797       0.0       0.0  0.098066
# 2   9148e2ba0bc5b380c6009c43fdc6e90c214d316c       0.0       0.0  0.043016
# 3   c0e46901a1482e2cc9406fbe869490e23faed0a2       0.0       0.0  0.124321
# 4   934366c5659908bd56571277a7f5fa02c441e56b       0.0       0.0  0.330243
# ..                                       ...       ...       ...       ...
# 91  49b2e53a8ad27e6ecf099823204c211b779c2777       0.0       0.0  0.070440
# 92  4f275d07e088d4223824bc1e7f72166bf06c3340       0.0       0.0  0.155026
# 93  723809e1689f302ac3a54b1e5f31b451cee75278       0.0       0.0  0.053859
# 94  166d32300f4d7766a82fe39a1185f35bc347c05f       0.0       1.0  0.991269
# 95  c4e58c361007e21a202d6e98b357b1730fefe758       0.0       0.0  0.073975
#
#     bool_value
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 91           0
# 92           0
# 93           0
# 94           1
# 95           0
#
# [96 rows x 5 columns]

# %% [markdown]
# ## Mesures

# %%
from sklearn import metrics

# %%
results_fb_gp = {}
results_fb_gp['f1']=metrics.f1_score(df_merge['fb-infox'], df_merge['gp-infox'])
results_fb_gp['accuracy']=metrics.accuracy_score(df_merge['fb-infox'], df_merge['gp-infox'])
results_fb_gp['recall']=metrics.recall_score(df_merge['fb-infox'], df_merge['gp-infox'])
cnf_matrix = metrics.confusion_matrix(df_merge['fb-infox'], df_merge['gp-infox'],normalize='all')
results_fb_gp['false_positive']=cnf_matrix[0,1]
results_fb_gp['false_negative']=cnf_matrix[1,0]

# %%
results_fb_gp
# Out:
# {'f1': 0.8333333333333333,
#  'accuracy': 0.9375,
#  'recall': 1.0,
#  'false_positive': 0.0625,
#  'false_negative': 0.0}

# %%
results_fb_pred = {}
results_fb_pred['f1']=metrics.f1_score(df_merge['fb-infox'], df_merge['bool_value'])
results_fb_pred['accuracy']=metrics.accuracy_score(df_merge['fb-infox'], df_merge['bool_value'])
results_fb_pred['recall']=metrics.recall_score(df_merge['fb-infox'], df_merge['bool_value'])
cnf_matrix = metrics.confusion_matrix(df_merge['fb-infox'], df_merge['bool_value'],normalize='all')
results_fb_pred['false_positive']=cnf_matrix[0,1]
results_fb_pred['false_negative']=cnf_matrix[1,0]

# %%
results_fb_pred
# Out:
# {'f1': 0.6829268292682926,
#  'accuracy': 0.8645833333333334,
#  'recall': 0.9333333333333333,
#  'false_positive': 0.125,
#  'false_negative': 0.010416666666666666}

# %%
results_gp_pred = {}
results_gp_pred['f1']=metrics.f1_score(df_merge['gp-infox'], df_merge['bool_value'])
results_gp_pred['accuracy']=metrics.accuracy_score(df_merge['gp-infox'], df_merge['bool_value'])
results_gp_pred['recall']=metrics.recall_score(df_merge['gp-infox'], df_merge['bool_value'])
cnf_matrix = metrics.confusion_matrix(df_merge['gp-infox'], df_merge['bool_value'],normalize='all')
results_gp_pred['false_positive']=cnf_matrix[0,1]
results_gp_pred['false_negative']=cnf_matrix[1,0]

# %%
results_gp_pred
# Out:
# {'f1': 0.7234042553191489,
#  'accuracy': 0.8645833333333334,
#  'recall': 0.8095238095238095,
#  'false_positive': 0.09375,
#  'false_negative': 0.041666666666666664}

# %% [markdown]
# # Mesure et observation des résultats
# ---

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# - Ajout Recueil
# - Ajour Labelizer

# %% [markdown]
# # Bricolages
# ---
