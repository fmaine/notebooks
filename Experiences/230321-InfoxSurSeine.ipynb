# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Présentation Infox Sur Seine
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
random_state = 42

# %%
cd ../..
# Out:
# /Users/fm/Desktop/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Articles & Labels

# %%
import patat.db.label_db
filename = 'data/demo/230226-Label.csv'
label_db = patat.db.label_db.LabelDb(filename)
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 266503  https://www.profession-gendarme.com/zelensky-e...               infox
# 266504  https://www.profession-gendarme.com/zelensky-l...               infox
# 266505  https://www.profession-gendarme.com/zelensky-m...               infox
# 266506  https://www.profession-gendarme.com/zero-mort-...               infox
# 266507  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 266503  0.556761  220930-tf_lr.pp  pred
# 266504  0.164531  220930-tf_lr.pp  pred
# 266505  0.673791  220930-tf_lr.pp  pred
# 266506  0.103192  220930-tf_lr.pp  pred
# 266507  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 266503  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 266504  77525354644316eadab53960efa8f5fd028c7f67
# 266505  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 266506  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 266507  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266508 rows x 6 columns]

# %%
import patat.db.article_db
filename = 'data/demo/230226-Article.csv'
article_db = patat.db.article_db.ArticleDb(filename)
article_db.df()
# Out:
# /Users/fm/Desktop/Work/Patat/patat/db/article_db.py:37: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#                                                      url  \
# 0      https://www.alnas.fr/actualite/communaute/lara...
# 1      https://www.alnas.fr/actualite/en-vrac/quel-ar...
# 2      https://www.alnas.fr/actualite/politique/laust...
# 3      https://www.alnas.fr/actualite/communaute/nant...
# 4      https://www.alnas.fr/actualite/en-vrac/la-fran...
# ...                                                  ...
# 78019  https://www.lelibrepenseur.org/une-histoire-vi...
# 78020              https://www.lelibrepenseur.org/actus/
# 78021  https://www.lelibrepenseur.org/affiche-des-dec...
# 78022         https://www.lelibrepenseur.org/communaute/
# 78023  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      L’Arabie saoudite organise des célébrations d'...
# 1      « Quel art ! » : un étudiant en droit invente ...
# 2      L’Australie ne reconnaît plus Jérusalem comme ...
# 3      Nantes : une mère musulmane meurt poignardée e...
# 4      La France condamnée pour avoir placé un enfant...
# ...                                                  ...
# 78019              Une histoire vieille comme le monde !
# 78020                                              Actus
# 78021  Affiche des décès et malaises de sportifs de h...
# 78022                                         Communauté
# 78023             Utilisation des cookies sur notre site
#
#                                                  article         author  \
# 0      L’Arabie saoudite a organisé un événement pour...   Par Youcef -
# 1      Une professeure de droit a partagé sur Twitter...  Par Oussama -
# 2      Le gouvernement israélien a qualifié la positi...  Par Oussama -
# 3      NANTES – Une enquête pour « homicide volontair...    Par Sarah -
# 4      La Cour européenne des droits de l’Homme (CEDH...    Par Sarah -
# ...                                                  ...            ...
# 78019  Certains veulent des preuves ! Ils ont raison....     Par\nAdmin
# 78020  Dernière vidéo !\nIl était temps, enfin ! Je v...      Par\nuser
# 78021  Un nombre inquiétant de sportifs de haut nivea...            NaN
# 78022  Notre Réseau Telegram et ses Groupes Secondair...            NaN
# 78023  Que sont les cookies ?\n\n\nLes cookies sont d...            NaN
#
#                                 tag abstract                    site  \
# 0      ['Actualités', 'Communauté']      NaN            www.alnas.fr
# 1         ['Actualités', 'En vrac']      NaN            www.alnas.fr
# 2       ['Actualités', 'Politique']      NaN            www.alnas.fr
# 3      ['Actualités', 'Communauté']      NaN            www.alnas.fr
# 4         ['Actualités', 'En vrac']      NaN            www.alnas.fr
# ...                             ...      ...                     ...
# 78019                           NaN      NaN  www.lelibrepenseur.org
# 78020                           NaN      NaN  www.lelibrepenseur.org
# 78021                           NaN      NaN  www.lelibrepenseur.org
# 78022                           NaN      NaN  www.lelibrepenseur.org
# 78023                           NaN      NaN  www.lelibrepenseur.org
#
#                   date_iso                                     url_h  c_count
# 0      2022-10-31T00:00:00  ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f      NaN
# 1      2022-10-19T00:00:00  87a4fb33eda6f687b0fac707bf5f2e4fcf871420      NaN
# 2      2022-10-18T00:00:00  8ca485af906f70b02317c62d6290dd089bdbc733      NaN
# 3      2022-10-17T00:00:00  cf03698371b368f772c43c7c9bb77104afb56875      NaN
# 4      2022-11-10T00:00:00  9897ea7e1978c196268819dfccc4288d23f53cd5      NaN
# ...                    ...                                       ...      ...
# 78019  2010-05-04T00:00:00  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7889.0
# 78020  2007-07-07T00:00:00  d4d5a37a8ff545664bea75664c8d8695e70d0941   2179.0
# 78021                  NaN  a175027896cf79e76dfad6409694fafacf1919b3   2250.0
# 78022                  NaN  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2937.0
# 78023                  NaN  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7702.0
#
# [78024 rows x 10 columns]

# %% [markdown]
# # Experience
# ---

# %% [markdown]
# ## Textes

# %%
df_labels = label_db.df()

# %%
df_infox = df_labels[(df_labels['label']=='infox') & (df_labels['type'] == 'obs')].copy()

# %%
df_infox = df_infox[['url','value']]

# %%
df_infox = df_infox.rename(columns={'value': 'infox'})

# %%
df_infox = df_infox.merge(article_db.df()[['url','title','article','site']].copy())

# %%
df_infox['text'] = df_infox['title'] + '\n' + df_infox['article']

# %%
df_texts_afp =  pd.read_csv('data/demo/221221-TextAfp.csv')

# %% [markdown]
# ## Statistiques sites

# %%
df_infox.pivot_table(index='site',columns='infox',values='article',aggfunc='count').fillna(0).astype(int)
# Out:
# infox                        0.0  1.0
# site
# actu.fr                        2    0
# fr.novopress.info              5    0
# fr.sott.net                    3   16
# infodujour.fr                  4    2
# lalettrepatriote.com           1    3
# lecourrier-du-soir.com         3    6
# lemediaen442.fr               12   12
# lesakerfrancophone.fr          4    6
# lesdeqodeurs.fr                4   24
# lesmoutonsrebelles.com        17   26
# lesobservateurs.ch             5    3
# lezarceleurs.blogspot.com      6   38
# reseauinternational.net       11    4
# www.alnas.fr                   6    0
# www.anguillesousroche.com      3    4
# www.breizh-info.com           40   11
# www.bvoltaire.fr               4    1
# www.cnews.fr                   4    0
# www.dreuz.info                14    6
# www.francesoir.fr             88   35
# www.francetvinfo.fr            4    0
# www.lelibrepenseur.org         7   11
# www.les-crises.fr              4    1
# www.lesalonbeige.fr            7    4
# www.nouvelordremondial.cc      3    7
# www.polemia.com                7   10
# www.profession-gendarme.com    2   18
# www.voltairenet.org            3    8
# www.wikistrike.com            17   28

# %%
pd.DataFrame(article_db.df().value_counts('site'))
# Out:
#                                  0
# site
# www.francesoir.fr            18454
# www.francetvinfo.fr          14597
# www.breizh-info.com           6071
# www.dreuz.info                5143
# www.legorafi.fr               4488
# www.wikistrike.com            3899
# www.profession-gendarme.com   3196
# actu.fr                       2874
# www.lelibrepenseur.org        2618
# fr.sott.net                   2602
# lesmoutonsrebelles.com        2174
# lezarceleurs.blogspot.com     2134
# lemediaen442.fr               1878
# www.cnews.fr                  1519
# reseauinternational.net       1149
# theconversation.com           1049
# www.lesalonbeige.fr            995
# lesakerfrancophone.fr          874
# www.polemia.com                628
# fr.novopress.info              611
# infodujour.fr                  493
# lesobservateurs.ch             341
# www.nouvelordremondial.cc       97
# lesdeqodeurs.fr                 93
# www.voltairenet.org             11
# lecourrier-du-soir.com           9
# www.anguillesousroche.com        7
# www.alnas.fr                     6
# www.les-crises.fr                5
# www.bvoltaire.fr                 5
# lalettrepatriote.com             4

# %% [markdown]
# ## Taille articles

# %%
df_infox['c_count']=df_infox['text'].apply(len)

# %%
max_c_count = 50_000

# %%
df_infox[df_infox['c_count']>=max_c_count]
# Out:
#                                                    url  infox  \
# 20   https://www.breizh-info.com/2022/04/19/185260/...    1.0
# 72   https://www.dreuz.info/2022/04/attentats-crime...    1.0
# 568  https://lezarceleurs.blogspot.com/2022/08/le-g...    1.0
#
#                                                  title  \
# 20   Covid-19. Une épidémie quasiment terminée avan...
# 72   Attentats, crimes, tueries et autres atrocités...
# 568               Le ginseng du pauvre contre le covid
#
#                                                article  \
# 20   Voici mon avant dernier bulletin de situation ...
# 72   Dreuz publie chaque année depuis 9 ans la list...
# 568  De : https://doorlesscarp953.substack.com/p/th...
#
#                           site  \
# 20         www.breizh-info.com
# 72              www.dreuz.info
# 568  lezarceleurs.blogspot.com
#
#                                                   text  c_count
# 20   Covid-19. Une épidémie quasiment terminée avan...    54474
# 72   Attentats, crimes, tueries et autres atrocités...   109679
# 568  Le ginseng du pauvre contre le covid\nDe : htt...   178457

# %%
df_infox = df_infox[df_infox['c_count']<max_c_count]

# %%
df_infox = df_infox.reset_index()

# %%
sns.displot(df_infox,x='c_count',hue='infox')

# %%
df_infox.groupby('infox').mean()
# Out:
#             index      c_count
# infox
# 0.0    240.613793  4898.334483
# 1.0    334.565836  8186.619217

# %% [markdown]
# ## Part of Speech

# %%
import spacy
from spacy.language import Language
# Out:
# 2023-03-21 15:25:15.262051: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
spacy.info()
# Out:
# {'spacy_version': '3.5.1',
#  'location': '/Users/fm/anaconda3/lib/python3.9/site-packages/spacy',
#  'platform': 'macOS-10.16-x86_64-i386-64bit',
#  'python_version': '3.9.13',
#  'pipelines': {'fr_core_news_lg': '3.5.0', 'fr_dep_news_trf': '3.5.0'}}

# %%
nlp = spacy.load("fr_core_news_lg")

# %%
def get_spacy_doc(text):
    print(text[:80])
    return nlp(text)

# %%
df_spacy = df_infox[['infox','text']].copy()

# %%
# %%time
df_spacy['spacy_doc'] = df_spacy['text'].apply(get_spacy_doc)
# Out:
# L’Arabie saoudite organise des célébrations d' »Halloween » autrefois interdites
# « Quel art ! » : un étudiant en droit invente un système ingénieux pour tricher
# L’Australie ne reconnaît plus Jérusalem comme capitale d’Israël
# Le gouvernement
# Nantes : une mère musulmane meurt poignardée en pleine rue, le suspect en fuite
#
# La France condamnée pour avoir placé un enfant musulman dans une famille chrétie
# Hassan Iquioussen : la justice belge refuse de remettre l’imam à la France
# La pe
# Ouverture du gazoduc Baltic Pipe, qui relie la Norvège et la Pologne
# Les dirigea
# La CIA aurait investi dans une puissante technologie de mutation génétique et de
# Jusqu’à présent, seuls 9 des 30 États membres de l’OTAN ont exprimé leur soutien
# Révélé : des documents montrent comment le DHS complote pour contrôler la « dési
# Rumble déclare qu’il ne modifiera pas sa politique pour satisfaire les exigences
# Ne vous inquiétez pas, nous ne manquerons jamais de pétrole
# Quand serons-nous à
# 10 raisons pour lesquelles le multivers pourrait être réel et pourquoi nous pour
# Faux-semblants et vraies raisons du recul de l’âge de départ à la retraite
# Les q
# Incroyable surprise : le repli identitaire islamiste se renforcerait en France !
# La Manif pour tous : dix ans après, que reste-t-il ?
# Dix ans déjà. Le 2 novembre
# [Edito] Soirée en non-mixité d’Élisabeth Borne : imaginez une minute que Jean Ca
# Pour les féministes, Miss France est discriminatoire… et ça se règle aux prud’ho
# Tests – vaccins – pass : fabrique de la panique, braquage des comptes publics
# Ce
# Covid-19. La pandémie et les vaccins, pour mieux justifier un coup d’Etat mondia
# Piscine, voile, ramadan : scènes de la vie ordinaire dans un prestigieux lycée
# O
# Faut-il vous métisser comme le suggère la presse mainstream ?
# Comme nous le verr
# QI, races, différences, intelligence, délinquance, wokisme. Tour d’horizon du né
# Géopolitique. Une analyse pro-russe de la stratégie militaire en Ukraine
# Ci-dess
# Publicité : le Grand Effacement des Blancs
# Regardez attentivement les publicités
# Rennes. Reprise des vols commerciaux le 15 juin à l’aéroport
# Les vols commerciau
# Afrique-du-Sud : l’afrikaans, le khoi et le san reconnus comme « langues indigèn
# Saône-et-Loire : le forcené retranché dans un hôtel de Montceau-les-Mines est mo
# Mayotte : des centres de redressement pour les mineurs délinquants ?
# En déplacem
# «Kohlantess» : responsabilité, sélection des participants... que contient le rap
# «KohLantess» : un détenu condamné pour viol et un autre pour meurtre parmi les p
# Procès sur l’origine du dossier russe : le FBI a poursuivi l’enquête sur Trump s
# La gauche américaine a tué 19 enfants et deux enseignants à Uvalde, Texas
# L’atro
# Invasion de l’Ukraine : la Suisse neutre se rapproche de l’OTAN – oui, même la S
# Israël augmente sa production de gaz naturel pour l’Europe, qui s’éloigne du gaz
# Pourquoi la Chine s’entête-t-elle avec sa stratégie « zéro covid » ?
# Surprise ce
# Burkini dans les piscines municipales : Pour Darmanin, le choix fait à Grenoble
# Un centre de compétences spatiales européen créé en Suisse
# Source : Lematin
# Un c
# Fraudes, conspirations et tribunal populaire des médias
# Très peu évoqué dans la
# Panique sur les cryptos !
# Depuis quelques semaines, les mauvaises nouvelles sur
# L’ancien Premier ministre Bernard Cazeneuve lance un manifeste pour « une autre
# C’est la rentrée, alors faites confiance au gouvernement !
# Voilà, c’est dit ! Ce
# Qui est-elle ? Anti-UE, pro-Otan, pro-Ukraine, pro-Israël, anti-immigration : vo
# Elections américaines de mi-mandat : suivi quotidien
# Voici le suivi quotidien de
# L’Ukraine est en train de gagner la guerre
# On ne saura sans doute jamais exactem
# La FDA va publier une étude sur les effets indésirables potentiels du vaccin COV
# Binyamin Netanyahou, homme d’Etat
# L’ancien premier ministre israélien Binyamin N
# ZFE : des sanctions automatiques et un objectif crapuleux
# Comme le mentionnait u
# Midterms : non, Donald Trump n’est pas responsable de la performance décevante d
# L’avortement sans condition jusqu’à neuf mois préconisé par l’OMS
# L'Organisation
# "Elles n'ont plus de règles" après le vaccin covid: "Où est mon cycle" libère la
# Un Doctothon ce 16 avril centré exclusivement sur les effets secondaires du vacc
# "RothschildGate" ? "Où est passé le patrimoine de Macron?" Jean-Baptiste Rivoire
# Vrais mensonges et fausses vérités: les nouveaux standards de la propagande
# EDIT
# Les masques pourraient générer des cancers : l'avocat Jean-Pierre Joseph lance u
# "Il faut prendre conscience urgemment des problèmes de ces vaccins" - Jean-Marc
# Ursula von der Leyen, la nouvelle Victoria Nuland
# TRIBUNE — Victoria Nuland, act
# "Tôt ou tard, une révolution éclatera en France", prédit un chercheur chinois sp
# SIDA, maladies auto-immunes, hépatites infantiles: multiplication des syndromes
# "Emmanuel Macron est un psychopathe amoral", selon le psychiatre italien Adriano
# Le gouvernement va lancer une application d’identité numérique: vers le crédit s
# Joe Biden inaugure discrètement un "Comité gouvernemental de la désinformation"
#
# Chronique N°93 – "Ne tester que le Covid peut faire croire à la disparition des
# Brésil : les paradoxes de l'infectiologue David Uip, encensé par la presse mais
# Des soldats français à Marioupol? Francis Lalanne demande un démenti au chef d'é
# BMJ Gate : interprétation manipulée des données statistiques au bénéfice des men
# Pilotes et scientifiques se regroupent au niveau mondial pour alerter sur les ri
# "Un autre monde": Vincent Lindon captivant dans le costume d’un dirigeant au bou
# De l’importance d’une Assemblée vraiment nationale
# Depuis hier soir, ne serions-
# Projet de "loi Covid": encore une prolongation du passe vaccinal?
# D'aucuns pensa
# Celerat 500L : un avion révolutionnaire à hydrogène
# Cet avion à l'allure de supp
# Diplômes obligatoires pour les influenceurs chinois sur TikTok
# Dans le cadre de
# Macron en marionnette d'Attali: une fresque murale qui fait polémique
# Le 22 juin
# "À Roland-Garros, une épidémie de covid, personne n'en a parlé": Alizé Cornet, l
# Google : désinformateur criminel ou informateur d’utilité publique?
# EDITO - Ce j
# Grèves, sous-effectif, vols supprimés… Le secteur aérien peine à redécoller
# Appe
# La traçabilité des fonds vers l’Ukraine se perd
# CHRONIQUE - La nouvelle de la ch
# Du Covid à la guerre en Ukraine, les mêmes techniques de manipulation
# TRIBUNE -
# Amazon va donner à Alexa la capacité de reproduire les voix humaines, même celle
# Discours de politique générale: huée, Élisabeth Borne appelle au "compromis"
# Dev
# "La technique favorite des auteurs anti-conspirationnistes: l’inversion accusato
# Allianz met en garde les entreprises quant à l'ampleur des révoltes à travers le
# Le Figaro nous donne raison sur tout: Macron devient "rassuriste"
# TRIBUNE — C’es
# La réalité "parallèle" s'installe dans les aéroports
# La réalité augmentée, popul
# De "nouveaux" vaccins de rappels pour cet automne: la folle course en avant
# Alor
# Hong Kong: les personnes testées positives au Covid-19 devront porter un bracele
# "Un président de la République qui rend honneur à Pétain": Mathilde Panot provoq
# EXCLU: L’Antonov ukrainien qui s'est écrasé en Grèce avait stationné à Paris, 36
# Malgré les risques de pénurie, la France va fournir l'Allemagne en gaz
# Alors que
# L’Espagne se rebelle face aux exigences de réduction de consommation de gaz de V
# Une nouvelle IA prédit les crimes une semaine en avance
# Des chercheurs américain
# Charge mentale: selon l'Ifop, les femmes ne sont jamais en vacances
# La charge me
# "S’interroger est-il encore possible ?" Fausses vérités contre vrais mensonges
# E
# France Connect: arnaques et vols d'identifiants se multiplient
# Des petits malins
# Mohammed ben Salmane visite l'Europe, une première depuis l’affaire Khashoggi
# C’
# Le tribunal de l'Union européenne confirme la suspension de RT France, la chaîne
# Imbécilisation de l’espèce, le passage à l’Idiocène
# CHRONIQUE - Entre toutes les
# Vaccination anti-Covid: l’Argentine va indemniser les victimes des effets indési
# L'efficacité des antidépresseurs remise en cause par des chercheurs
# La sérotonin
# Ukraine: la chaine CBS censure un documentaire qui révèle que 70% des armes amér
# Chine: après les puces électroniques et les capteurs cérébraux, des écoliers sur
# Vaccinolâtres et ukrainolâtres, la même technique de désinformation totalitaire
#
# Insécurité et agressions: des Français quittent l’Hexagone "par dépit"
# Le nombre
# Israël et la Turquie se réconcilient après 12 années de rapports houleux
# Après u
# Pourquoi travailler pour FranceSoir ?
# TRIBUNE - « Pourquoi acceptez-vous de trav
# Courses de karting à la prison de Fresnes: Dupont-Moretti ordonne une enquête, g
# Dire NON à la guerre !
# TRIBUNE - La guerre entre la Russie et l’Ukraine fait rag
# Dernier hommage à Sempé, grand poète du dessin d'humour, à l'église de Saint-Ger
# « LETTRE OUVERTE A LA FRANCE ET AUX NATIONS »
# L’un de nos lecteurs (ou l’une de
# ALERTE – Vaccins COVID Un scientifique britannique révèle une analyse de  donnée
# Tour de France – Abandon de Victor Lafay :« On est tous négatifs aux  tests Covi
# Un rapport du gouvernement britannique admet que 18,9 millions de  personnes ne
# Le bureau de l’Académie de Médecine expose sa complicité d’empoisonnement en ban
# Aujourd’hui, 4 documents très courts pour vous garder éveillés et occuper votre
# Les laboratoires du Pentagone et la dépopulation
# par Dragomir Bojkov.
# La vice-pr
# La fin de la Pax Americana : De la chute d’un empire
# par Andreas Mölzer.
# C’est l
# La maladie des ondes radio : l’histoire de l’électrohypersensibilité
# Au cours de
# Il n’y a pas de Crise Climatique dans le Monde !
# Il n’y a pas de crise climatiqu
# L’effet Kiss Coll de la guerre
# Par WD
#
#
# Nous sommes imbriqués dans l’Otan. Ce qu
# Délitement, décadence, écroulement… Fin?
# Place d’Armes Ile de France : le 23 aoû
# L’Euthanasie des personnes en Maison de Retraite en 2020 !
# Pendant la « Plandémi
# Black Rock: un problème majeur pour l’humanité
# Vue(s) : 4 048
#
#
# Pendant trois an
# Attaque contre la Pologne : lâché par l’OTAN et les Etats-Unis, Zelensky vient d
# Étude du Pr Raoult: « La présentation des preuves de Complément d’enquête est fr
# L’épouse de Zelensky a dépensé 40 000 euros pour faire du shopping à  Paris tout
# Pourquoi les États-Unis ont tant besoin de déstabiliser le continent européen ?
#
# Grande-Bretagne : Le Titanic heurte l’iceberg
# par Batiushka.
# « Le pouvoir est co
# La Russie gagne un soutien international alors que les crimes occidentaux sont r
# Crimée : Comment la Turquie appelle à la capitulation de la Russie
# par  Karine B
# Éducation nationale, la grande désertion
# par Anne Coffinier.
# Pap Ndiaye en a fai
# La contre-offensive n’est pas Ukro, elle est OTAN. Et donc différente
# De nouvell
# Tous les jeunes, portez la nouvelle (russe)
# par Pepe Escobar.
# L’OCS à Samarcande
# Adhésion à la Russie : 93% pour le « oui » dans la région de Zaporijia, 87% dans
# Pourquoi la Russie « tente » l’Europe avec la réparation des conduites Nord Stre
# Enedis autorisé à couper des ballons d’eau chaude à certaines heures via Linky
# C
# L’offensive hivernale de Poutine
# par Mike Whitney.
# « Chaque mort russe et ukrain
# Les différents visages des sous-traitants de Washington
# par Mikhail Gamandiy-Ego
# Pourquoi les États-Unis ont-ils fabriqué le Qatargate ?
# Le fait que l’UE pue la
# Le Pentagone organise la victoire de l'Ukraine à l'Eurovision 2022
# Le festival d
# OTAN : quand la Finlande déclare la guerre
# En compagnie de la Suède, la Finlande
# Effet domino de la reddition des soldats ukrainiens à Azovstal sur le reste des
# Guerre en Ukraine: les seize preuves de l'entière responsabilité de l'Amérique
# A
# Otan : après la Finlande, la Suède va officialiser sa candidature
# Après celle de
# La Chine augmente ses importations d'énergie en provenance de Russie
# Les achats
# La tyrannie digitale et le code QR  -  prof. Michel Chossudovsky et Peter Koenig
# L'étau se resserre autour de la Chine
def get_linguistic_features(row):
    text = row['text']
    doc = row['spacy_doc']
    nb_token = len(doc)
    row['nb_token'] = nb_token
    row['nb_sent'] = len(row['text'].split('.'))
    row['nb_exclam'] = text.count('?')+text.count('!')+text.count('()')+text.count(')')
    token_pos = [token.pos_ for token in doc]
    pos_counter = Counter(token_pos)
    for pos in pos_counter:
        row[pos] = pos_counter[pos]    
    return row

# %%
# %%time
df_features = df_spacy.apply(get_linguistic_features, axis=1)
# Out:
# CPU times: user 4.18 s, sys: 25.8 ms, total: 4.21 s
# Wall time: 4.29 s

# %%
df_features = df_features.fillna(0)

# %%
no_scale_columns = ['infox','nb_token', 'spacy_doc', 'text','nb_sent'] 
df_pos = df_features.drop(columns=['infox', 'spacy_doc', 'text']).astype(int)
df_y = df_features[['infox']].astype(int)

# %%
df_pos
# Out:
#      ADJ  ADP  ADV  AUX  CCONJ  DET  INTJ  NOUN  NUM  PRON  PROPN  PUNCT  \
# 0     24   63   27   28      9   58     0    77    3    21     29     49
# 1      9   55   14   22      5   56     0    73    1    19     11     37
# 2     42   71   14   23      9   77     0    95    3    11     46     55
# 3     21   58   10   24      4   53     0    84    4    16      9     57
# 4     27   49   13   18      8   45     0    62    6     4      5     20
# ..   ...  ...  ...  ...    ...  ...   ...   ...  ...   ...    ...    ...
# 566   69  113   56   32     21  101     0   142    3    51     29     77
# 567   59   77   32   31     13   86     0   114    1    40     26     64
# 568  190  611  170  129     62  422     0   783  119   145     89    333
# 569  133  386  126   94     41  261     0   441   56    89    122    202
# 570   23   50   31   13      8   39     0    64    9    28      9     33
#
#      SCONJ  SPACE  SYM  VERB   X  nb_exclam  nb_sent  nb_token
# 0        5     10    0    46   2          1       14       451
# 1        5     10    0    45   0          2       12       362
# 2        6     15    0    42   0          0       17       509
# 3        3      6    0    37   0          1       18       386
# 4        6      5    0    29   0          2        8       297
# ..     ...    ...  ...   ...  ..        ...      ...       ...
# 566     21     11    0    92   0          8       37       818
# 567     11      7    1    61   2          1       23       625
# 568     48     63    0   312   0         19      113      3476
# 569     34     23    0   160  13          7       75      2181
# 570      9      2    0    41   0          4       10       359
#
# [571 rows x 20 columns]

# %%
df_pos['sent_size']=df_pos['nb_token']/df_pos['nb_sent']

# %%
df_pos[df_y['infox']==0]['sent_size'].describe()
# Out:
# count    290.000000
# mean      30.819481
# std        7.075753
# min       14.483871
# 25%       26.203309
# 50%       29.970588
# 75%       34.049370
# max       60.533333
# Name: sent_size, dtype: float64

# %%
df_pos[df_y['infox']==1]['sent_size'].describe()
# Out:
# count    281.000000
# mean      31.904474
# std       13.793860
# min        8.205882
# 25%       25.540541
# 50%       30.281250
# 75%       35.459016
# max      171.666667
# Name: sent_size, dtype: float64

# %%
def normalize(row):
    nb_token = row['nb_token']
    row = row.apply(lambda x : x/nb_token)
    row['nb_token'] = nb_token
    return row

df_pos_norm = df_pos.apply(normalize,axis=1)

df_pos_norm
# Out:
#           ADJ       ADP       ADV       AUX     CCONJ       DET  INTJ  \
# 0    0.053215  0.139690  0.059867  0.062084  0.019956  0.128603   0.0
# 1    0.024862  0.151934  0.038674  0.060773  0.013812  0.154696   0.0
# 2    0.082515  0.139489  0.027505  0.045187  0.017682  0.151277   0.0
# 3    0.054404  0.150259  0.025907  0.062176  0.010363  0.137306   0.0
# 4    0.090909  0.164983  0.043771  0.060606  0.026936  0.151515   0.0
# ..        ...       ...       ...       ...       ...       ...   ...
# 566  0.084352  0.138142  0.068460  0.039120  0.025672  0.123472   0.0
# 567  0.094400  0.123200  0.051200  0.049600  0.020800  0.137600   0.0
# 568  0.054661  0.175777  0.048907  0.037112  0.017837  0.121404   0.0
# 569  0.060981  0.176983  0.057772  0.043099  0.018799  0.119670   0.0
# 570  0.064067  0.139276  0.086351  0.036212  0.022284  0.108635   0.0
#
#          NOUN       NUM      PRON  ...     PUNCT     SCONJ     SPACE     SYM  \
# 0    0.170732  0.006652  0.046563  ...  0.108647  0.011086  0.022173  0.0000
# 1    0.201657  0.002762  0.052486  ...  0.102210  0.013812  0.027624  0.0000
# 2    0.186640  0.005894  0.021611  ...  0.108055  0.011788  0.029470  0.0000
# 3    0.217617  0.010363  0.041451  ...  0.147668  0.007772  0.015544  0.0000
# 4    0.208754  0.020202  0.013468  ...  0.067340  0.020202  0.016835  0.0000
# ..        ...       ...       ...  ...       ...       ...       ...     ...
# 566  0.173594  0.003667  0.062347  ...  0.094132  0.025672  0.013447  0.0000
# 567  0.182400  0.001600  0.064000  ...  0.102400  0.017600  0.011200  0.0016
# 568  0.225259  0.034235  0.041715  ...  0.095800  0.013809  0.018124  0.0000
# 569  0.202201  0.025676  0.040807  ...  0.092618  0.015589  0.010546  0.0000
# 570  0.178273  0.025070  0.077994  ...  0.091922  0.025070  0.005571  0.0000
#
#          VERB         X  nb_exclam   nb_sent  nb_token  sent_size
# 0    0.101996  0.004435   0.002217  0.031042     451.0   0.071429
# 1    0.124309  0.000000   0.005525  0.033149     362.0   0.083333
# 2    0.082515  0.000000   0.000000  0.033399     509.0   0.058824
# 3    0.095855  0.000000   0.002591  0.046632     386.0   0.055556
# 4    0.097643  0.000000   0.006734  0.026936     297.0   0.125000
# ..        ...       ...        ...       ...       ...        ...
# 566  0.112469  0.000000   0.009780  0.045232     818.0   0.027027
# 567  0.097600  0.003200   0.001600  0.036800     625.0   0.043478
# 568  0.089758  0.000000   0.005466  0.032509    3476.0   0.008850
# 569  0.073361  0.005961   0.003210  0.034388    2181.0   0.013333
# 570  0.114206  0.000000   0.011142  0.027855     359.0   0.100000
#
# [571 rows x 21 columns]

# %% [markdown]
# ### Comparaison moyenne autres features

# %%
desc_1 = df_pos_norm[df_y['infox']==1].describe()
desc_0 = df_pos_norm[df_y['infox']==0].describe()

df_desc_ratio =(desc_1/desc_0).loc[['mean']].T.sort_values('mean')

pos_names = {
    'ADJ': 'adjective',
    'ADP': 'adposition',
    'ADV': 'adverb',
    'AUX': 'auxiliary',
    'CCONJ': 'coordinating conjunction',
    'DET': 'determiner',
    'INTJ': 'interjection',
    'NOUN': 'noun',
    'NUM': 'numeral',
    'PART': 'particle',
    'PRON': 'pronoun',
    'PROPN': 'proper noun',
    'PUNCT': 'punctuation',
    'SCONJ': 'subordinating conjunction',
    'SYM': 'symbol',
    'VERB': 'verb',
    'X': 'other',
}

df_desc_ratio['comment'] = df_desc_ratio.index.map(lambda pos : pos_names.get(pos,''))
df_desc_ratio
# Out:
#                mean                    comment
# sent_size  0.809634
# PUNCT      0.931215                punctuation
# PROPN      0.938586                proper noun
# ADP        0.939760                 adposition
# NOUN       0.967142                       noun
# DET        0.990547                 determiner
# NUM        0.997645                    numeral
# nb_sent    1.023429
# VERB       1.024927                       verb
# ADJ        1.048130                  adjective
# AUX        1.055273                  auxiliary
# ADV        1.060796                     adverb
# CCONJ      1.091671   coordinating conjunction
# PRON       1.104198                    pronoun
# SYM        1.180589                     symbol
# nb_exclam  1.184672
# SPACE      1.187458
# SCONJ      1.195155  subordinating conjunction
# nb_token   1.636840
# INTJ       1.872225               interjection
# X          2.156045                      other

# %% [markdown]
# ### Benchmark Machine Learning

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import (AdaBoostClassifier,
                              HistGradientBoostingClassifier,
                              RandomForestClassifier)
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
#from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
predictors = {
    "Logistic Regression" : LogisticRegression(C=1000, random_state=random_state, solver='lbfgs', multi_class='ovr', max_iter=1000),
    "Neural Network" : MLPClassifier(alpha=1, max_iter=1000, hidden_layer_sizes=(8,8), random_state=random_state),
#    "RBF SVM" : SVC(gamma=2, C=1, probability=True, random_state=random_state),
#    "Gaussian Naive Bayes" : GaussianNB(),
#    "Multinomial Naive Bayes" : MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None),
#    "Nearest Neighbors" : KNeighborsClassifier(3),
#    "Linear SVM" : SVC(kernel="linear", C=0.025, probability=True, random_state=random_state),
#    "Gaussian Process" : GaussianProcessClassifier(1.0 * RBF(1.0), random_state=random_state),
#    "Decision Tree" : DecisionTreeClassifier(max_depth=5, random_state=random_state),
#    "Random Forest" : RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1, random_state=random_state),
#    "AdaBoost" : AdaBoostClassifier(random_state=random_state),
#    "QDA" : QuadraticDiscriminantAnalysis(),
#    'Gradient Boosting': HistGradientBoostingClassifier(random_state=random_state),
#    'Dummy' : DummyClassifier(strategy='uniform', random_state=random_state),
}

# %%
train_size = 0.75

# %%
import patat.ml.benchmark

# %%
importlib.reload(patat.ml.benchmark)
# Out:
# <module 'patat.ml.benchmark' from '/Users/fm/Desktop/Work/Patat/patat/ml/benchmark.py'>

# %%
bench = patat.ml.benchmark.Benchmark()

# %%
df_X=df_pos_norm[['nb_token','SPACE','SCONJ','nb_exclam','INTJ']]
df_bench = bench.benchmark(df_X,df_y['infox'],train_size=0.8,random_state=random_state)
# Out:
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.04276394844055176 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 0.08704900741577148 s
# INFO:root:Training RBF SVM
# INFO:root:Training time : 0.05382394790649414 s
# INFO:root:Training Gaussian Naive Bayes
# INFO:root:Training time : 0.0022728443145751953 s
# INFO:root:Training Multinomial Naive Bayes
# INFO:root:Training time : 0.00500798225402832 s
# INFO:root:Training Nearest Neighbors
# INFO:root:Training time : 0.005176067352294922 s
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# INFO:root:Training Linear SVM
# INFO:root:Training time : 4.948846101760864 s
# INFO:root:Training Gaussian Process
# INFO:root:Training time : 0.7478711605072021 s
# INFO:root:Training Decision Tree
# INFO:root:Training time : 0.003643035888671875 s
# INFO:root:Training Random Forest
# INFO:root:Training time : 0.022744178771972656 s
# INFO:root:Training AdaBoost
# INFO:root:Training time : 0.0920867919921875 s
# INFO:root:Training QDA
# INFO:root:Training time : 0.011546850204467773 s
# INFO:root:Training Gradient Boosting
# INFO:root:Training time : 0.14856719970703125 s
# INFO:root:Training Dummy
# INFO:root:Training time : 0.0005650520324707031 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.7272307692307693

# %%
df_bench = df_bench.sort_values(by='roc_auc',ascending=False)

# %%
df_bench
# Out:
#                           roc_auc        f1  accuracy  recall   log_loss  \
# Random Forest            0.727231  0.634615  0.669565    0.66  11.412959
# AdaBoost                 0.724308  0.621359  0.660870    0.64  11.713296
# Gradient Boosting        0.718462  0.634615  0.669565    0.66  11.412959
# QDA                      0.715077  0.571429  0.686957    0.48  10.812208
# Neural Network           0.659077  0.410959  0.626087    0.30  12.914555
# Logistic Regression      0.657538  0.531915  0.617391    0.50  13.214968
# Linear SVM               0.657231  0.469136  0.626087    0.38  12.914582
# Decision Tree            0.643231  0.494382  0.608696    0.44  13.515292
# Gaussian Naive Bayes     0.619692  0.415584  0.608696    0.32  13.515250
# Nearest Neighbors        0.608308  0.579439  0.608696    0.62  13.515354
# Multinomial Naive Bayes  0.568923  0.606061  0.434783    1.00  19.522369
# RBF SVM                  0.514154  0.541353  0.469565    0.72  18.320895
# Dummy                    0.500000  0.478632  0.469565    0.56  18.320840
# Gaussian Process         0.455231  0.305882  0.486957    0.26  17.720047
#
#                          false_positive  false_negative  fit_time  proba_time
# Random Forest                  0.182609        0.147826  0.022744    0.003928
# AdaBoost                       0.182609        0.156522  0.092087    0.009305
# Gradient Boosting              0.182609        0.147826  0.148567    0.003389
# QDA                            0.086957        0.226087  0.011547    0.002962
# Neural Network                 0.069565        0.304348  0.087049    0.001514
# Logistic Regression            0.165217        0.217391  0.042764    0.000829
# Linear SVM                     0.104348        0.269565  4.948846    0.002658
# Decision Tree                  0.147826        0.243478  0.003643    0.001125
# Gaussian Naive Bayes           0.095652        0.295652  0.002273    0.001520
# Nearest Neighbors              0.226087        0.165217  0.005176    0.001980
# Multinomial Naive Bayes        0.565217        0.000000  0.005008    0.001060
# RBF SVM                        0.408696        0.121739  0.053824    0.005111
# Dummy                          0.339130        0.191304  0.000565    0.000421
# Gaussian Process               0.191304        0.321739  0.747871    0.005713

# %%
sns.scatterplot(data=df_bench,y='f1',x='roc_auc',hue=df_bench.index)
# Out:
# <AxesSubplot:xlabel='roc_auc', ylabel='accuracy'>

# %% [markdown]
# ## Ignore Words / Lemmas

# %%
import patat.util.text
import patat.ml.lex_analyser
lex = patat.ml.lex_analyser.LexAnalyser()

# %% [markdown]
# ### Lemmas

# %%
preprocessor = patat.util.text.preprocess
tokenizer = lex.get_lemmas_from_text

# %%
df_words = lex.get_df_words(texts= df_infox['text'],values = df_infox['infox'].astype(int), preprocessor=preprocessor, tokenizer= tokenizer)
### Rare Words
for occ_rare in [1,2,3,4,5,6,7]:
    df_words['rare_'+str(occ_rare)]=(df_words['count_0']<=occ_rare)&(df_words['count_1']<=occ_rare)
### Common words
for common_size in [50,80,120,200,500]:
    common_0 = df_words.sort_values('count_0',ascending=False).head(common_size).index
    common_1 = df_words.sort_values('count_1',ascending=False).head(common_size).index
    df_words['common_'+str(common_size)]=(df_words.index.isin(common_0))&(df_words.index.isin(common_1))
### Ignore Lemmas
ignore_lemmas={
    'None' : None,
    'small' : list(df_words[df_words['common_80']].index)+list(df_words[df_words['rare_1']].index),
    'medium' : list(df_words[df_words['common_80']].index)+list(df_words[df_words['rare_2']].index),
    'large' : list(df_words[df_words['common_200']].index)+list(df_words[df_words['rare_5']].index),
    'xlarge' : list(df_words[df_words['common_500']].index)+list(df_words[df_words['rare_7']].index),
}

# %%
df_words
# Out:
#           count_0  count_1  count  rare_1  rare_2  rare_3  rare_4  rare_5  \
# de          12631    19202  31833   False   False   False   False   False
# la           7376    10290  17666   False   False   False   False   False
# le           5421     8192  13613   False   False   False   False   False
# et           4748     8062  12810   False   False   False   False   False
# les          4669     8544  13213   False   False   False   False   False
# ...           ...      ...    ...     ...     ...     ...     ...     ...
# ipc             0        7      7   False   False   False   False   False
# iphone          0        1      1    True    True    True    True    True
# iq              0        7      7   False   False   False   False   False
# iqs             0        3      3   False   False    True    True    True
# þórólfur        0        1      1    True    True    True    True    True
#
#           rare_6  rare_7  common_50  common_80  common_120  common_200  \
# de         False   False       True       True        True        True
# la         False   False       True       True        True        True
# le         False   False       True       True        True        True
# et         False   False       True       True        True        True
# les        False   False       True       True        True        True
# ...          ...     ...        ...        ...         ...         ...
# ipc        False    True      False      False       False       False
# iphone      True    True      False      False       False       False
# iq         False    True      False      False       False       False
# iqs         True    True      False      False       False       False
# þórólfur    True    True      False      False       False       False
#
#           common_500
# de              True
# la              True
# le              True
# et              True
# les             True
# ...              ...
# ipc            False
# iphone         False
# iq             False
# iqs            False
# þórólfur       False
#
# [24999 rows x 15 columns]

# %% [markdown]
# ### Words

# %%
tokenizer = lex.get_words

# %%
df_words = lex.get_df_words(texts= df_infox['text'],values = df_infox['infox'].astype(int), preprocessor=preprocessor, tokenizer= tokenizer)
### Rare Words
for occ_rare in [1,2,3,4,5,6,7]:
    df_words['rare_'+str(occ_rare)]=(df_words['count_0']<=occ_rare)&(df_words['count_1']<=occ_rare)
### Common words
for common_size in [50,80,120,200,500]:
    common_0 = df_words.sort_values('count_0',ascending=False).head(common_size).index
    common_1 = df_words.sort_values('count_1',ascending=False).head(common_size).index
    df_words['common_'+str(common_size)]=(df_words.index.isin(common_0))&(df_words.index.isin(common_1))
### Ignore Lemmas
ignore_words={
    'None' : None,
    'small' : list(df_words[df_words['common_80']].index)+list(df_words[df_words['rare_1']].index),
    'medium' : list(df_words[df_words['common_80']].index)+list(df_words[df_words['rare_2']].index),
    'large' : list(df_words[df_words['common_200']].index)+list(df_words[df_words['rare_5']].index),
    'xlarge' : list(df_words[df_words['common_500']].index)+list(df_words[df_words['rare_7']].index),
}

# %%
for key in ['small','medium','large','xlarge']:
    print(key,len(ignore_words[key]))
# Out:
# small 18317
# medium 24047
# large 29978
# xlarge 31778

# %%
ignore_words
# Out:
# {'None': None,
#  'small': ['de',
#   'la',
#   'le',
#   'et',
#   'les',
#   'des',
#   'en',
#   'un',
#   'est',
#   'du',
#   'une',
#   'que',
#   'pour',
#   'dans',
#   'qui',
#   'il',
#   'par',
#   'sur',
#   'au',
#   'pas',
#   'ce',
#   'plus',
#   'qu',
#   'ne',
#   'ont',
#   'se',
#   'avec',
#   'sont',
#   'ou',
#   'été',
#   'son',
#   'aux',
#   'mais',
#   'nous',
#   'cette',
#   'comme',
#   'elle',
#   'on',
#   'fait',
#   'être',
#   'tout',
#   'pays',
#   'même',
#   'ces',
#   'leur',
#   'si',
#   'sa',
#   'aussi',
#   'ils',
#   'ses',
#   'bien',
#   'je',
#   'sans',
#   'faire',
#   'vous',
#   'contre',
#   'après',
#   'russie',
#   'avait',
#   'monde',
#   'depuis',
#   'entre',
#   'peut',
#   'était',
#   'autres',
#   'tous',
#   'covid',
#   'selon',
#   'ukraine',
#   'très',
#   'cela',
#   'medellin',
#   'muhabir',
#   'ksg',
#   'laine',
#   'matos',
#   'menacent',
#   'kergroise',
#   'muhammad',
#   'medecins',
#   'multiculturelle',
#   'memo',
#   'launch',
#   'industriellement',
#   'krugman',
#   'mpe',
#   'interpelé',
#   'megan',
#   'informatisés',
#   'multiculturel',
#   'lauréats',
#   'msrzfff',
#   'informateur',
#   'invectives',
#   'kerviel',
#   'laisney',
#   'kyrsten',
#   'kristalina',
#   'maîtrisée',
#   'maïsréputée',
#   'matilda',
#   'interviendront',
#   'libérera',
#   'intervenues',
#   'médiatisées',
#   'kuldorff',
#   'inventées',
#   'ldsmgqmtlp',
#   'informatif',
#   'médiatiser',
#   'kerrain',
#   'kuhl',
#   'kuklos',
#   'megel',
#   'laurentwauquiez',
#   'maîtrisé',
#   'inventifs',
#   'measure',
#   'mearsheimertraduit',
#   'kemune',
#   'muette',
#   'kendine',
#   'kendinemuhabir',
#   'lancetgate',
#   'kent',
#   'libéra',
#   'myocardiques',
#   'libé',
#   'libèrent',
#   'informationnelle',
#   'kenya',
#   'libère',
#   'interphone',
#   'keough',
#   'leaks',
#   'interpersonnelles',
#   'invention',
#   'mensongères',
#   'lahogue',
#   'krop',
#   'kerckhove',
#   'lahellec',
#   'muesli',
#   'mugu',
#   'matinales',
#   'muettes',
#   'interprétables',
#   'lancerait',
#   'katharina',
#   'musso',
#   'kyrylenko',
#   'mehmed',
#   'leads',
#   'libéralisation',
#   'intl',
#   'libya',
#   'lagardère',
#   'infectée',
#   'karl',
#   'kristersson',
#   'keegan',
#   'intégrés',
#   'kulldorff',
#   'medicare',
#   'kalin',
#   'lignée',
#   'introduite',
#   'moulins',
#   'kalibr',
#   'memoriam',
#   'lignées',
#   'moustiques',
#   'mastrangelo',
#   'moulinette',
#   'massoud',
#   'ligonnès',
#   'lavoixdunord',
#   'moudenc',
#   'infectent',
#   'infoutu',
#   'kaiser',
#   'laïcards',
#   'matches',
#   'lauwersoog',
#   'light',
#   'mouton',
#   'lamentablement',
#   'intestinal',
#   'mat',
#   'lame',
#   'mutilation',
#   'mutisme',
#   'masturber',
#   'memoire',
#   'laisseront',
#   'mué',
#   'méditations',
#   'motrices',
#   'limitations',
#   'kahovka',
#   'intestins',
#   'lawsuit',
#   'kyev',
#   'méditer',
#   'massima',
#   'ligues',
#   'lavrentiy',
#   'investies',
#   'infranchissable',
#   'méditation',
#   'limitant',
#   'kaicho',
#   'mou',
#   'mvalet',
#   'liman',
#   'laïcisme',
#   'kupmcj',
#   'lampes',
#   'licencier',
#   'intuitives',
#   'mathieuslama',
#   'kao',
#   'intuitif',
#   'mykolaïv',
#   'mykolaiv',
#   'intitule',
#   'lbd',
#   'kylian',
#   'kandinsky',
#   'intégral',
#   'karim',
#   'moza',
#   'inverser',
#   'kyrielle',
#   'informel',
#   'moyenâgeuse',
#   'libérés',
#   'medhope',
#   'kyriakos',
#   'matriarcale',
#   'licenciement',
#   'muséum',
#   'mathias',
#   'interpellez',
#   'médiologie',
#   'kamala',
#   'kanavape',
#   'intimidations',
#   'medium',
#   'kamel',
#   'lampe',
#   'muter',
#   'laminaire',
#   'mediterraneo',
#   'kamal',
#   'médiocrité',
#   'moutonnesque',
#   'lamentait',
#   'kusturica',
#   'myanmar',
#   'lider',
#   'meg',
#   'mykhaïlo',
#   'industrialo',
#   'mentaient',
#   'maîtrisés',
#   'laïcs',
#   'mycosique',
#   'liderada',
#   'mutent',
#   'meetings',
#   'lie',
#   'musicales',
#   'launay',
#   'multiethnique',
#   'lançons',
#   'mbappé',
#   'kostyukov',
#   'intervalles',
#   'levage',
#   'kourtrajmé',
#   'interrogeons',
#   'kimdotcom',
#   'laad',
#   'lare',
#   'multitudes',
#   'lacağ',
#   'levez',
#   'leurres',
#   'leurre',
#   'labouré',
#   'inexcusables',
#   'largest',
#   'mènerait',
#   'kirry',
#   'intraveineux',
#   'kircik',
#   'intravasculaire',
#   'interrogiez',
#   'interservices',
#   'intransigeante',
#   'infanterie',
#   'lachainemeteo',
#   'levi',
#   'lassociation',
#   'lematin',
#   'lapin',
#   'kibboutz',
#   'intraduisibles',
#   'maximilien',
#   'lexique',
#   'lacrymogènes',
#   'mba',
#   'lapidaire',
#   'murakami',
#   'mendie',
#   'interrogeant',
#   'lançot',
#   'melenchon',
#   'lenarcic',
#   'koweït',
#   'lacroix',
#   'levrette',
#   'mauritanie',
#   'melo',
#   'lent',
#   'kids',
#   'last',
#   'intérimaire',
#   'laps',
#   'maugendre',
#   'intervenaient',
#   'inepte',
#   'infligeait',
#   'largeurs',
#   'kits',
#   'infirmité',
#   'larron',
#   'lessive',
#   'kobold',
#   'mccann',
#   'konbinifr',
#   'lesueur',
#   'kobach',
#   'knafo',
#   'mc',
#   'mawlid',
#   'inflationary',
#   'mccabe',
#   'kongais',
#   'inflationnistes',
#   'maxblumenthal',
#   'konservative',
#   'interviewait',
#   'inflammables',
#   'mythifiées',
#   'meneurs',
#   'lartige',
#   'municipalité',
#   'kordet',
#   'larves',
#   'lesmesle',
#   'mâle',
#   'lesvoitures',
#   'inflexible',
#   'leonid',
#   'maxim',
#   'multivalente',
#   'inexplicable',
#   'multivaccinés',
#   'laborieux',
#   'lepvraud',
#   'larguées',
#   'infinité',
#   'mbbs',
#   'letribunaldunet',
#   'kosciusko',
#   'kjbya',
#   'menez',
#   'inexpérience',
#   'inflige',
#   'kkk',
#   'mundell',
#   'interrompt',
#   'larousse',
#   'mundi',
#   'labelliser',
#   'laborieusement',
#   'infirmiers',
#   'menerle',
#   'melonipic',
#   'kka',
#   'larina',
#   'khôl',
#   'inutilité',
#   'interprétant',
#   'mcdaniel',
#   'latino',
#   'maturité',
#   'méconnaissent',
#   'lebranchu',
#   'mature',
#   'liberal',
#   'mdkudndayw',
#   'infobricsla',
#   'mécontentes',
#   'matti',
#   'kharcyz',
#   'khalid',
#   'infantilisation',
#   'intoxication',
#   'kz',
#   'infestation',
#   'infiltre',
#   'libellés',
#   'multiplicité',
#   'kérosène',
#   'matérialisée',
#   'latin',
#   'indéniables',
#   'matérialiste',
#   'landivisiau',
#   'kharjiv',
#   'latente',
#   'matérialisme',
#   'lancées',
#   'infographies',
#   'infomigrants',
#   'leasing',
#   'mdr',
#   'mdups',
#   'multilinguisme',
#   'matshidiso',
#   'lagane',
#   'latinos',
#   'indéfiniment',
#   'multilingue',
#   'myriamhebuterne',
#   'multifactor',
#   'indécis',
#   'inextinguible',
#   'interviewés',
#   'infondée',
#   'keystone',
#   'intolérables',
#   'museau',
#   'médaille',
#   'lafon',
#   'informaient',
#   'matthias',
#   'multipartagés',
#   'maëlig',
#   'lanciato',
#   'libertycounsel',
#   'indéniablement',
#   'informait',
#   'latent',
#   'invasif',
#   'liaisons',
#   'méchanceté',
#   'leighton',
#   'kherbat',
#   'künstle',
#   'intégriste',
#   'mutée',
#   'mennechet',
#   'murdoch',
#   'maximo',
#   'krav',
#   'mennetrier',
#   'königsberg',
#   'murielle',
#   'mcgregor',
#   'lanterne',
#   'interviews',
#   'ladite',
#   'influences',
#   'limiteraient',
#   'krach',
#   'menjoulet',
#   'mécaniques',
#   'multipliées',
#   'mécanisation',
#   'melanie',
#   'interrogeait',
#   'khmers',
#   'lanz',
#   'kravchenko',
#   'landowners',
#   'multipliez',
#   'invariablement',
#   'lgvnwq',
#   'lecter',
#   'lh',
#   'invariants',
#   'influençant',
#   'lael',
#   'kris',
#   'leclercq',
#   'meme',
#   'mazout',
#   'lecarpentier',
#   'laernoes',
#   'indépendances',
#   'indépendantistes',
#   'lfihttps',
#   'influenceur',
#   'intégrative',
#   'murmurs',
#   'mystérieusement',
#   'influencée',
#   'krejcikova',
#   'lgb',
#   'lang',
#   'lanester',
#   'kéré',
#   'infime',
#   'kozh',
#   'insularités',
#   'massifiée',
#   'mihet',
#   'insistez',
#   'insomniaques',
#   'intensifiés',
#   'lâchée',
#   'lèse',
#   'mijaurées',
#   'jetée',
#   'isidoros',
#   'mikaël',
#   'manitou',
#   'milanovic',
#   'insomnies',
#   'jettera',
#   'intensifiée',
#   'iskander',
#   'jette',
#   'migré',
#   'manne',
#   'isaac',
#   'mienne',
#   'lydie',
#   'migerel',
#   'insertion',
#   'jeun',
#   'lyman',
#   'insidieuse',
#   'insignifiant',
#   'migranti',
#   'insist',
#   'intensive',
#   'lyre',
#   'manouchian',
#   'mody',
#   'lyrique',
#   'migrent',
#   'lyrisme',
#   'migrer',
#   'miliaires',
#   'lxxiry',
#   'légendaire',
#   'légiférer',
#   'inspirantes',
#   'jesi',
#   'mange',
#   'manga',
#   'moderniser',
#   'modernise',
#   'inspirent',
#   'militantes',
#   'mandate',
#   'militantsantenne',
#   'militari',
#   'militarisme',
#   'législations',
#   'inspirée',
#   'législature',
#   'légiste',
#   'légitimation',
#   'jessey',
#   'mangeur',
#   'léaument',
#   'modifient',
#   'insoumission',
#   'insoupçonné',
#   'manifs',
#   'manifestée',
#   'insoupçonnée',
#   'insoutenables',
#   'modifiable',
#   'islamisme',
#   'islamogauchiste',
#   'intensifieront',
#   'jetable',
#   'manient',
#   'manie',
#   'légalisées',
#   'inspirante',
#   'maniaquerie',
#   'modestes',
#   'insensibilité',
#   'iryna',
#   'molle',
#   'lufthansa',
#   'manteaux',
#   'jnyrfrk',
#   'molette',
#   'michelle',
#   'manteau',
#   'luhan',
#   'miches',
#   'luiz',
#   'lukas',
#   'lumineuse',
#   'lumineuses',
#   'intentionnés',
#   'manqués',
#   'microbiologistes',
#   'jingle',
#   'lumières',
#   'lun',
#   'microfilaires',
#   'irrémissible',
#   'mantra',
#   'jin',
#   'mollusques',
#   'map',
#   'johanna',
#   'mao',
#   'inquisition',
#   'inquisitoriale',
#   'manuscrits',
#   'mevlut',
#   'mevlüt',
#   'mgalithiques',
#   'manuscript',
#   'manufacturing',
#   'miasmes',
#   'inquiétais',
#   'lucre',
#   'molotov',
#   'michaël',
#   'mantras',
#   'luna',
#   'micronésie',
#   'insecticide',
#   'inscrira',
#   'moelzer',
#   'moeller',
#   'lutteouvriere',
#   'jeunesses',
#   'inscrites',
#   'lutz',
#   'irréversiblement',
#   'inscrivent',
#   'luxuriante',
#   'luzhniki',
#   'lv',
#   'irrévérence',
#   'lw',
#   'lwezkbhpk',
#   'lwwibyx',
#   'irrévérences',
#   'manquerait',
#   'jijorgw',
#   'moeti',
#   'intentionnel',
#   'jiechi',
#   'jiang',
#   'manquées',
#   'manquée',
#   'luneau',
#   'manquez',
#   'manques',
#   'micros',
#   'jewish',
#   'insatiabilité',
#   'jeuxvideo',
#   'intensives',
#   'mohammad',
#   'irrémédiable',
#   'irrésistibles',
#   'moghole',
#   'insatisfaisante',
#   'lus',
#   'lut',
#   'isolated',
#   'jeromeguedj',
#   'inoxydable',
#   'intangible',
#   'magma',
#   'magnat',
#   'magneronresponsable',
#   'minima',
#   'minimal',
#   'minimales',
#   'maladroit',
#   'magnifiques',
#   'magnétoencéphalographie',
#   'mahmud',
#   'missak',
#   'mahncke',
#   'intactes',
#   'maia',
#   'minimalistes',
#   'minimas',
#   'majuscule',
#   'malaga',
#   'jaeghere',
#   'mitigées',
#   'jamaa',
#   'miteux',
#   'jama',
#   'jaloux',
#   'mimosas',
#   'jalousie',
#   'mimé',
#   'malaxer',
#   'malavisés',
#   'maghrébine',
#   'intelligences',
#   'jakob',
#   'israéliénne',
#   'jaimungal',
#   'jaillissement',
#   'magicien',
#   'maginnis',
#   'jaillira',
#   'malaisie',
#   'magiquement',
#   'misled',
#   'jack',
#   'mitsotakis',
#   'majesté',
#   'mirent',
#   'maitrisé',
#   'maitrise',
#   'istituto',
#   'ives',
#   'insurgerais',
#   'iverctine',
#   'italiennne',
#   'italo',
#   'mirages',
#   'insultes',
#   'italy',
#   'maints',
#   'miquettes',
#   'insuffisances',
#   'minérales',
#   'itinéraires',
#   'ive',
#   'minorer',
#   'mirifiques',
#   'jabotinsky',
#   'jabor',
#   'jab',
#   'maille',
#   'insérée',
#   'instrumentaliser',
#   'instrumentalisé',
#   'misiak',
#   'miserias',
#   'maillon',
#   'ministériel',
#   'maillons',
#   'ministériels',
#   'insèrent',
#   'ja',
#   'ivème',
#   'insubmersible',
#   'miromesnil',
#   'ivrognes',
#   'ivoire',
#   'mitigés',
#   'jeromedurain',
#   'maléfique',
#   'installeront',
#   'maastricht',
#   'maboulisme',
#   'milité',
#   'malédiction',
#   'macaux',
#   'mobilisésle',
#   'macbook',
#   'mobilisées',
#   'mobilisé',
#   'installée',
#   'mobilisant',
#   'miller',
#   'macomb',
#   'macro',
#   'léthargie',
#   'management',
#   'jc',
#   'lésés',
#   'inspirés',
#   'mandarin',
#   'isolating',
#   'militariste',
#   'jerome',
#   'légitimé',
#   'militaristes',
#   'légèreté',
#   'léhart',
#   'isolationniste',
#   'manchin',
#   'mod',
#   'mobilization',
#   'jefferson',
#   'jeddah',
#   'manches',
#   'managers',
#   'macrofinancière',
#   'maltraitées',
#   'magalimarc',
#   'mktordn',
#   'mizuho',
#   'instaure',
#   'madiran',
#   'maduro',
#   'malhonnête',
#   'mae',
#   'mael',
#   'instaurées',
#   'maelig',
#   'janez',
#   'maffesoli',
#   'malheureux',
#   'israeliennes',
#   'mittani',
#   'malentendus',
#   'jamal',
#   'mademoiselle',
#   'mnangagwa',
#   'mallettes',
#   'macronien',
#   'macronienne',
#   'jbxqwendw',
#   'isolément',
#   'malraux',
#   'macroéconomiques',
#   'jattali',
#   'jassem',
#   'intelligentsia',
#   'macy',
#   'jaser',
#   'mladen',
#   'jarrige',
#   'jarres',
#   'malls',
#   'instaurant',
#   'irréformable',
#   'ltd',
#   'motivé',
#   'moraliste',
#   'inégales',
#   'moralisme',
#   'moralisateur',
#   'jurant',
#   'martelait',
#   'jura',
#   'juppé',
#   'livrée',
#   'inhumains',
#   'interloqués',
#   'inépuisable',
#   'marshall',
#   'lk',
#   'interim',
#   'julius',
#   'inhérent',
#   'martelant',
#   'inhérentes',
#   'interministérielle',
#   'ingérable',
#   'inhabitables',
#   'justes',
#   'inhabituellement',
#   'inhabituelles',
#   'invitent',
#   'inviter',
#   'internal',
#   'moraux',
#   'inhibent',
#   'inhibition',
#   'livni',
#   'inhumain',
#   'inhumaine',
#   'jurisprudences',
#   'julienbayou',
#   'moo',
#   'marre',
#   'iouchtchenko',
#   'lobotomisé',
#   'initiateurs',
#   'merdia',
#   'monétairement',
#   'localiser',
#   'localisé',
#   'localizzate',
#   'locatif',
#   'interfèrent',
#   'interfax',
#   'monuments',
#   'marqueur',
#   'monumentalidades',
#   'monumental',
#   'monétarisme',
#   'inhérents',
#   'juiverie',
#   'llavori',
#   'llbnvgjwuk',
#   'intergroupe',
#   'lloyd',
#   'mercinier',
#   'lmt',
#   'marronnier',
#   'marron',
#   'moqués',
#   'iom',
#   'jul',
#   'moquée',
#   'mercure',
#   'loana',
#   'moqueur',
#   'lobby',
#   'moquent',
#   'moque',
#   'interférer',
#   'moor',
#   'invitaient',
#   'lockdowns',
#   'investigateur',
#   'mossoul',
#   'linkage',
#   'ingouvernable',
#   'jéhovah',
#   'lionel',
#   'ingraham',
#   'jxk',
#   'mentant',
#   'masquée',
#   'mosque',
#   'lipovetski',
#   'liquident',
#   'menteurs',
#   'mason',
#   'internazionali',
#   'masochisme',
#   'jvpjjg',
#   'juxtaposés',
#   'mostafa',
#   'limitrophes',
#   'kadima',
#   'motivent',
#   'internée',
#   'interné',
#   'internetisé',
#   'limoges',
#   'limonov',
#   'infâmants',
#   'motive',
#   'jürgen',
#   'mentalités',
#   'jérémy',
#   'lindell',
#   'massard',
#   'lines',
#   'ling',
#   'linge',
#   'investigación',
#   'massacrés',
#   'mostra',
#   'juy',
#   'mentioning',
#   'ingéniosité',
#   'morigène',
#   'morgenstern',
#   'litigieuse',
#   'litigieux',
#   'litre',
#   'morel',
#   'justifiait',
#   'little',
#   'mordu',
#   'martina',
#   'littorales',
#   'mordre',
#   'mordent',
#   'justiciables',
#   'mentons',
#   'martial',
#   'littéraire',
#   'mord',
#   'invisibilisation',
#   'marti',
#   'morizet',
#   'justifiées',
#   'morlaix',
#   ...],
#  'medium': ['de',
#   'la',
#   'le',
#   'et',
#   'les',
#   'des',
#   'en',
#   'un',
#   'est',
#   'du',
#   'une',
#   'que',
#   'pour',
#   'dans',
#   'qui',
#   'il',
#   'par',
#   'sur',
#   'au',
#   'pas',
#   'ce',
#   'plus',
#   'qu',
#   'ne',
#   'ont',
#   'se',
#   'avec',
#   'sont',
#   'ou',
#   'été',
#   'son',
#   'aux',
#   'mais',
#   'nous',
#   'cette',
#   'comme',
#   'elle',
#   'on',
#   'fait',
#   'être',
#   'tout',
#   'pays',
#   'même',
#   'ces',
#   'leur',
#   'si',
#   'sa',
#   'aussi',
#   'ils',
#   'ses',
#   'bien',
#   'je',
#   'sans',
#   'faire',
#   'vous',
#   'contre',
#   'après',
#   'russie',
#   'avait',
#   'monde',
#   'depuis',
#   'entre',
#   'peut',
#   'était',
#   'autres',
#   'tous',
#   'covid',
#   'selon',
#   'ukraine',
#   'très',
#   'cela',
#   'abdelmadjid',
#   'ngptj',
#   'évitée',
#   'dissidence',
#   'forestier',
#   'illimités',
#   'nc',
#   'mus',
#   'dues',
#   'nd',
#   'prononce',
#   'achètent',
#   'achète',
#   'achille',
#   'achevés',
#   'abstient',
#   'nutritionniste',
#   'promue',
#   'exporter',
#   'pourrissent',
#   'villigen',
#   'illimitée',
#   'menu',
#   'poursuivra',
#   'internat',
#   'achevée',
#   'multiplicateur',
#   'dissensions',
#   'immensément',
#   'promouvant',
#   'mehra',
#   'valjean',
#   'nutri',
#   'fourniraient',
#   'vilaines',
#   'épaule',
#   'mentionnait',
#   'ignoraient',
#   'villablanca',
#   'fournira',
#   'dolu',
#   'dissoudre',
#   'prolongement',
#   'pouvions',
#   'étasunien',
#   'indifféremment',
#   'illogique',
#   'évitent',
#   'dissuader',
#   'antagonismes',
#   'nui',
#   'apprenait',
#   'nuisant',
#   'apprenant',
#   'étasunienne',
#   'médiation',
#   'exemption',
#   'promeut',
#   'forfait',
#   'promise',
#   'pourvu',
#   'immenses',
#   'pourvoir',
#   'mentionnées',
#   'valises',
#   'villers',
#   'proactive',
#   'promettent',
#   'métaphore',
#   'valls',
#   'immatriculé',
#   'académiciens',
#   'abdominales',
#   'interviewé',
#   'nice',
#   'épanouissement',
#   'numérisation',
#   'doive',
#   'vingtième',
#   'megalítico',
#   'abad',
#   'valets',
#   'dutour',
#   'duval',
#   'envoler',
#   'objection',
#   'aasland',
#   'dynamiser',
#   'postures',
#   'mégalithes',
#   'expédie',
#   'envois',
#   'mystification',
#   'envoyant',
#   'annexée',
#   'objecteurs',
#   'mélanger',
#   'enz',
#   'dogmes',
#   'objecter',
#   'indignes',
#   'évêque',
#   'abandonne',
#   'dogmatisme',
#   'imminent',
#   'indignations',
#   'expulsions',
#   'acter',
#   'poteaux',
#   'muet',
#   'duo',
#   'apparaitre',
#   'méditerranéens',
#   'interface',
#   'virtuel',
#   'abusant',
#   'mégalithe',
#   'émigration',
#   'proportions',
#   'valent',
#   'disparue',
#   'exclusif',
#   'aaron',
#   'expérimenté',
#   'postuler',
#   'expéditionnaire',
#   'expérimenter',
#   'oblasts',
#   'virer',
#   'envisageable',
#   'activiste',
#   'medvedev',
#   'eo',
#   'éternise',
#   'mutuel',
#   'approchent',
#   'ménon',
#   'expositions',
#   'nécropole',
#   'poullaouec',
#   'abbasi',
#   'duprat',
#   'procède',
#   'immeubles',
#   'valorise',
#   'achève',
#   'vingts',
#   'exposant',
#   'disputée',
#   'pourrai',
#   'vint',
#   'incorporé',
#   'prononcer',
#   'dupin',
#   'disputer',
#   'newt',
#   'incontrôlée',
#   'pronostics',
#   'abattre',
#   'mystiques',
#   'durcissement',
#   'émouvant',
#   'mémorielle',
#   'négocié',
#   'familial',
#   'néolibérale',
#   'nevada',
#   'évoquées',
#   'émotionnel',
#   'procréer',
#   'négliger',
#   'annoncés',
#   'ericpiolle',
#   'faap',
#   'erich',
#   'falsification',
#   'acquaviva',
#   'fabien',
#   'dispositions',
#   'mystères',
#   'era',
#   'abîme',
#   'évite',
#   'distances',
#   'pozzallo',
#   'muqueuse',
#   'accordés',
#   'menstruelle',
#   'municipaux',
#   'noeuds',
#   'verbalisation',
#   'profils',
#   'donatienne',
#   'nocivité',
#   'interviens',
#   'doucement',
#   'applaudi',
#   'norvégien',
#   'exosquelette',
#   'variables',
#   'variés',
#   'accomplissement',
#   'exonération',
#   'accorde',
#   'eut',
#   'équipage',
#   'veste',
#   'primitive',
#   'natal',
#   'virulence',
#   'applaudir',
#   'privilèges',
#   'evangile',
#   'nausées',
#   'nain',
#   'naguère',
#   'imaginait',
#   'antimissile',
#   'eve',
#   'exhorté',
#   'notent',
#   'équestre',
#   'ined',
#   'expatriés',
#   'évaluations',
#   'indemnités',
#   'eva',
#   'indemnité',
#   'indicateur',
#   'primé',
#   'interpellés',
#   'dixit',
#   'nommant',
#   'inexorablement',
#   'interprétée',
#   'existentiels',
#   'eurasienne',
#   'équivalences',
#   'fade',
#   'interviendra',
#   'appellation',
#   'foudres',
#   'donnez',
#   'accommodements',
#   'étrillé',
#   'étroit',
#   'donnons',
#   'verront',
#   'illustrée',
#   'étranglement',
#   'étudiante',
#   'exigées',
#   'murgeanu',
#   'équivalente',
#   'antony',
#   'antiques',
#   'faiblement',
#   'verhaeghe',
#   'vertou',
#   'dostoïevski',
#   'vertus',
#   'princes',
#   'antiracisme',
#   'dividendes',
#   'vergogne',
#   'mètre',
#   'vertigineux',
#   'naufrage',
#   'verticale',
#   'interrogation',
#   'nonobstant',
#   'forteresse',
#   'prisons',
#   'verisk',
#   'interprétations',
#   'mèneraient',
#   'antiviral',
#   'fougères',
#   'nociception',
#   'épidémique',
#   'distingue',
#   'apportant',
#   'exploitants',
#   'facilitent',
#   'métrage',
#   'exploits',
#   'vierge',
#   'valéry',
#   'apporteront',
#   'métropole',
#   'interrogent',
#   'exploitée',
#   'exacerbée',
#   'épiscopal',
#   'épingle',
#   'apport',
#   'étiquettes',
#   'épine',
#   'accentué',
#   'infligée',
#   'mem',
#   'exploit',
#   'exacerber',
#   'épidémiques',
#   'exploité',
#   'apports',
#   'incubation',
#   'values',
#   'drh',
#   'nietzsche',
#   'domestique',
#   'épicé',
#   'fortunés',
#   'interner',
#   'poésie',
#   'épices',
#   'valu',
#   'influe',
#   'acharne',
#   'dreal',
#   'aperçu',
#   'espérait',
#   'vif',
#   'dresser',
#   'projectiles',
#   'abstenir',
#   'prisme',
#   'acculée',
#   'notoirement',
#   'douterait',
#   'dmytro',
#   'pressé',
#   'vices',
#   'douzaine',
#   'profonds',
#   'productives',
#   'épouvantables',
#   'ever',
#   'factions',
#   'prestataires',
#   'notifié',
#   'explicitement',
#   'épuise',
#   'douloureux',
#   'prestigieuses',
#   'accroissement',
#   'events',
#   'prestation',
#   'extrémiste',
#   'acceptons',
#   'abominable',
#   'nine',
#   'mécontents',
#   'formelle',
#   'distribue',
#   'estaing',
#   'accueillera',
#   'imaginent',
#   'étiquetés',
#   'essonne',
#   'acceptent',
#   'acceptation',
#   'métropolitaine',
#   'acceptables',
#   'intervieweur',
#   'vandermeersch',
#   'accueillie',
#   'formellement',
#   'victims',
#   'nourrie',
#   'formidable',
#   'individualisme',
#   'inflationniste',
#   'evidemment',
#   'esthétique',
#   'victorieux',
#   'mécontent',
#   'esthéticienne',
#   'productions',
#   'formelles',
#   'obligera',
#   'passionnante',
#   'émeuve',
#   'inondé',
#   'incarnée',
#   'agissements',
#   'pannes',
#   'pannier',
#   'panoplie',
#   'pans',
#   'allures',
#   'dépassant',
#   'waziri',
#   'pantois',
#   'misapplied',
#   'obligerait',
#   'eikon',
#   'papers',
#   'allouées',
#   'misent',
#   'impopulaire',
#   'allongement',
#   'allocation',
#   'westminster',
#   'alliée',
#   'départementale',
#   'elena',
#   'panama',
#   'échéance',
#   'pais',
#   'embarquement',
#   'washingtonien',
#   'palaces',
#   'palestinien',
#   'aggrave',
#   'palier',
#   'eltsine',
#   'elsonn',
#   'palin',
#   'dénonçaient',
#   'mire',
#   'pallier',
#   'palmes',
#   'palomba',
#   'impliquerait',
#   'fessenheim',
#   'whether',
#   'personnalité',
#   'dépendra',
#   'instructif',
#   'perrin',
#   'allergique',
#   'wikileaks',
#   'échanger',
#   'misère',
#   'permit',
#   'momies',
#   'misères',
#   'permises',
#   'permise',
#   'institutionnelle',
#   'inquiet',
#   'agroalimentaire',
#   'incalculable',
#   'wimbledon',
#   'perrot',
#   'fiscalement',
#   'personnalisées',
#   'personnalisé',
#   'parachuté',
#   'fishermen',
#   'egypte',
#   'egron',
#   'egorov',
#   'échappatoire',
#   'persone',
#   'ficelle',
#   'effroyable',
#   'instruire',
#   'paragraphe',
#   'effrayée',
#   'dépensés',
#   'persistants',
#   'persistante',
#   'imports',
#   'monarchies',
#   'effrayante',
#   'mons',
#   'agglomérations',
#   'paingault',
#   'injustes',
#   'écopé',
#   'affrété',
#   'flash',
#   'ouganda',
#   'inchangé',
#   'vélot',
#   'vénétitay',
#   'vénézuéliens',
#   'démissionne',
#   'vérifications',
#   'insurgés',
#   'outrage',
#   'outrances',
#   'afghane',
#   'outrée',
#   'injustifiée',
#   'altitude',
#   'véhémence',
#   'vécue',
#   'vécues',
#   'intacts',
#   'pid',
#   'emportent',
#   'affrontements',
#   'picardie',
#   'minimaliste',
#   'picard',
#   'oubliettes',
#   'démangeaisons',
#   'piano',
#   'imperméable',
#   'phéérique',
#   'oubliée',
#   'oubliés',
#   'écosystème',
#   'végétaliens',
#   'végétation',
#   'flatter',
#   'empereur',
#   'démocratiser',
#   'insuffisante',
#   'pa',
#   'peuplé',
#   'allégée',
#   'montagne',
#   'wang',
#   'éclater',
#   'implicitement',
#   'padrig',
#   'paelvi',
#   'fermés',
#   'pagaille',
#   'emblématique',
#   'impliquent',
#   'éclatement',
#   'pessac',
#   'dénigrer',
#   'dénigré',
#   'owens',
#   'alternance',
#   'walgreens',
#   'ouvertures',
#   'insurgé',
#   'empare',
#   'ag',
#   'écoliers',
#   'pharmaciens',
#   'montauzier',
#   'vêtus',
#   'alsace',
#   'ovale',
#   'insupportable',
#   'flamands',
#   'ovation',
#   'démontraient',
#   'démontrant',
#   'emmanuelmacron',
#   'insulter',
#   'démontrée',
#   'pharaonique',
#   'agatha',
#   'pgf',
#   'win',
#   'effectuent',
#   'permettait',
#   'modifiées',
#   'paysages',
#   'xiujian',
#   'alcoolique',
#   'payantes',
#   'partons',
#   'yvette',
#   'parts',
#   'imprudence',
#   'ajoutent',
#   'détournée',
#   'modifiera',
#   'détonation',
#   'insouciance',
#   'ajoutée',
#   'désinformateur',
#   'yair',
#   'parvenus',
#   'déshumanise',
#   'détester',
#   'détérioré',
#   'impressionné',
#   'peines',
#   'peinent',
#   'particularité',
#   'filiales',
#   'zar',
#   'insistent',
#   'airways',
#   'xiaoshun',
#   'désertion',
#   'désespoir',
#   'mobilise',
#   'insister',
#   'dévastatrice',
#   'zaporijjia',
#   'désespérance',
#   'moduler',
#   'mobilisée',
#   'désespérés',
#   'zakharova',
#   'partira',
#   'album',
#   'désastreuses',
#   'patientes',
#   'détenait',
#   'patiemment',
#   'pathétique',
#   'désolée',
#   'alan',
#   'détectée',
#   'passerait',
#   'inspirer',
#   'filtré',
#   'déstabilisation',
#   'déstabilisent',
#   'pasteurs',
#   'modestie',
#   'passeurs',
#   'alarm',
#   'inspiration',
#   'passsanitaire',
#   'ylva',
#   'financements',
#   'patois',
#   'fillon',
#   'parvis',
#   'ajustement',
#   'yann',
#   'désinvolture',
#   'passager',
#   'détermineront',
#   'filmé',
#   'akbar',
#   'alabama',
#   'désobéir',
#   'détenteur',
#   'désobéissance',
#   'yellow',
#   'alastair',
#   'peinte',
#   'parcelles',
#   'mitt',
#   'eda',
#   'perdront',
#   'parisiens',
#   'perdez',
#   'wokistes',
#   'aligné',
#   'wong',
#   'mixte',
#   'park',
#   'dérision',
#   'ecologiste',
#   'parker',
#   'dérivant',
#   'parks',
#   'dérives',
#   'paria',
#   'ahsani',
#   'parcourant',
#   'permanents',
#   'déposants',
#   'déposent',
#   'dépositaire',
#   'effacée',
#   'pardonné',
#   'mollahs',
#   'pardès',
#   'mit',
#   'dépouillement',
#   'pareillement',
#   'pareils',
#   'performants',
#   'dépourvue',
#   'performances',
#   'editions',
#   'wipperfürth',
#   'wire',
#   'mitigé',
#   'pensions',
#   'développées',
#   'penchée',
#   'désaffection',
#   'partagés',
#   'désagréable',
#   'modélisations',
#   'penchants',
#   'penchait',
#   'impressionnantes',
#   'dévoilé',
#   'finiront',
#   'filature',
#   'mna',
#   'dévoilant',
#   'participait',
#   'participations',
#   'peintures',
#   'peints',
#   'instants',
#   'echos',
#   'inattendu',
#   'pension',
#   'zoulou',
#   'déroulant',
#   'alice',
#   'parleur',
#   'inaliénables',
#   'dérouler',
#   'déroulerait',
#   'ebrahimi',
#   'parois',
#   'paroissiens',
#   'paroxysme',
#   'ailes',
#   'worse',
#   'dûment',
#   'penn',
#   'peng',
#   'mlp',
#   'injurieuses',
#   'piers',
#   'ottomane',
#   'andreas',
#   'meu',
#   'oecd',
#   'vitro',
#   'intercepter',
#   'ensuivent',
#   'mosquées',
#   'enseignée',
#   'enseigné',
#   'détaillants',
#   'ingrat',
#   'ancrées',
#   'interagissent',
#   'polo',
#   'oeuvré',
#   'déclenchant',
#   'motards',
#   'décisif',
#   'pompier',
#   'ponts',
#   'enthousiaste',
#   'motreff',
#   'déchéance',
#   'adhésions',
#   'enterrement',
#   'motiver',
#   'interceptés',
#   'entente',
#   'entendue',
#   'foncée',
#   'infréquentable',
#   'farfelue',
#   'andreï',
#   'océanie',
#   'entendaient',
#   'immunogène',
#   'incomplet',
#   'mortelles',
#   'offres',
#   'anaphylaxie',
#   'immunogénicité',
#   'fatalement',
#   'offusque',
#   'foll',
#   'offusquer',
#   'vizio',
#   'poils',
#   'décortique',
#   'michèle',
#   'ogm',
#   'découle',
#   'poder',
#   'décourager',
#   'voeu',
#   'voeux',
#   'anadolu',
#   'incomplète',
#   'politisé',
#   'admirables',
#   'politisation',
#   'ancrage',
#   'ancienneté',
#   'enrichi',
#   'offices',
#   'déclinant',
#   'anchorage',
#   'mortifères',
#   'politicien',
#   'enregistrent',
#   'meurt',
#   'élevait',
#   'mortiers',
#   'immunodéprimés',
#   'anarchistes',
#   'offrait',
#   'visés',
#   'visée',
#   'entrevue',
#   'visaient',
#   'animation',
#   'positionner',
#   'émergentes',
#   'positionnement',
#   'entretiennent',
#   'débordé',
#   'acyn',
#   'entretenus',
#   'obsessions',
#   'déboucher',
#   'posant',
#   'informées',
#   'émanciper',
#   'adamo',
#   'obstinément',
#   'mouvance',
#   'inconnu',
#   'obtenant',
#   'débarquent',
#   'débarqués',
#   'débarrassé',
#   'viré',
#   'obs',
#   'animé',
#   'débattu',
#   'fanatique',
#   'msc',
#   'entête',
#   'émetteur',
#   'émettant',
#   'animosités',
#   'débattus',
#   'interes',
#   'entérinant',
#   'débit',
#   'foods',
#   'posons',
#   'fantoche',
#   'visibilité',
#   'éloigné',
#   'décence',
#   'obéissance',
#   'obéit',
#   'entrainement',
#   'décentes',
#   'élèvent',
#   'occasionnellement',
#   'occasionnés',
#   'infractions',
#   'entourée',
#   'élyséen',
#   'pors',
#   'éloignés',
#   'décevante',
#   'éloignées',
#   'interdictions',
#   'décharger',
#   'populiste',
#   'visuels',
#   'anglaises',
#   'fonder',
#   'obtenons',
#   'adaptation',
#   'adapte',
#   'entraînées',
#   'immortalisé',
#   'entraînée',
#   'angoisse',
#   'portez',
#   'débutants',
#   'entraînera',
#   'porteur',
#   'angoissant',
#   'débâcle',
#   'porteront',
#   'adaptées',
#   'anglos',
#   'entraver',
#   'décalage',
#   'décale',
#   'anglia',
#   'ennui',
#   'otto',
#   'édifiantes',
#   'inclinaison',
#   'pj',
#   'più',
#   'voyous',
#   'americana',
#   'encre',
#   'intenses',
#   'fdpi',
#   'amenée',
#   'dégoût',
#   'affectation',
#   'orfraie',
#   'amendements',
#   'imparfaits',
#   'affectent',
#   'monégasque',
#   'initier',
#   'encouragement',
#   'écroule',
#   'déférer',
#   'plabennec',
#   'écrivains',
#   'oradour',
#   'définis',
#   'définissent',
#   'fluides',
#   'militarisé',
#   'oran',
#   'plafond',
#   'moquer',
#   'endiguement',
#   'déformation',
#   'voyaient',
#   'places',
#   'ordinaires',
#   'amherd',
#   'militent',
#   'placement',
#   'édifice',
#   'impartiale',
#   'intelligible',
#   'favorisées',
#   'délicat',
#   'pilotable',
#   'écrasant',
#   'osez',
#   'fleuve',
#   ...],
#  'large': ['de',
#   'la',
#   'le',
#   'et',
#   'les',
#   'des',
#   'en',
#   'un',
#   'est',
#   'du',
#   'une',
#   'que',
#   'pour',
#   'dans',
#   'qui',
#   'il',
#   'par',
#   'sur',
#   'au',
#   'pas',
#   'ce',
#   'plus',
#   'qu',
#   'ne',
#   'ont',
#   'se',
#   'avec',
#   'sont',
#   'ou',
#   'été',
#   'son',
#   'aux',
#   'mais',
#   'nous',
#   'cette',
#   'comme',
#   'elle',
#   'on',
#   'fait',
#   'être',
#   'tout',
#   'pays',
#   'même',
#   'ces',
#   'leur',
#   'si',
#   'sa',
#   'aussi',
#   'ils',
#   'ses',
#   'france',
#   'bien',
#   'je',
#   'sans',
#   'faire',
#   'vous',
#   'contre',
#   'après',
#   'deux',
#   'russie',
#   'avait',
#   'monde',
#   'politique',
#   'depuis',
#   'entre',
#   'peut',
#   'était',
#   'ans',
#   'avoir',
#   'guerre',
#   'autres',
#   'tous',
#   'covid',
#   'selon',
#   'ukraine',
#   'président',
#   'très',
#   'cela',
#   'alors',
#   'leurs',
#   'encore',
#   'dont',
#   'non',
#   'ainsi',
#   'où',
#   'sous',
#   'lui',
#   'moins',
#   'cas',
#   'donc',
#   'états',
#   'temps',
#   'gouvernement',
#   'également',
#   'français',
#   'otan',
#   'état',
#   'russe',
#   'notre',
#   'vers',
#   'autre',
#   'personnes',
#   'soit',
#   'europe',
#   'avant',
#   'unis',
#   'déclaré',
#   'déjà',
#   'macron',
#   'lors',
#   'va',
#   'fin',
#   'toujours',
#   'mois',
#   'nos',
#   'toute',
#   'car',
#   'com',
#   'peu',
#   'source',
#   'ceux',
#   'voir',
#   'cet',
#   'plusieurs',
#   'années',
#   'aujourd',
#   'hui',
#   'fois',
#   'jusqu',
#   'vie',
#   'santé',
#   'rien',
#   'ai',
#   'chez',
#   'pendant',
#   'première',
#   'grande',
#   'certains',
#   'rapport',
#   'twitter',
#   'quand',
#   'nombre',
#   'beaucoup',
#   'dit',
#   'russes',
#   'millions',
#   'question',
#   'quelques',
#   'the',
#   'toutes',
#   'système',
#   'médias',
#   'jamais',
#   'grand',
#   'dire',
#   'vaccin',
#   'article',
#   'calvaire',
#   'sollicité',
#   'lamballe',
#   'serbe',
#   'cap',
#   'leadership',
#   'lanta',
#   'exceptions',
#   'signifier',
#   'calme',
#   'fonctionnaire',
#   'session',
#   'navire',
#   'socialistes',
#   'laura',
#   'socialisme',
#   'celsius',
#   'popularité',
#   'cents',
#   'exemptions',
#   'débarquer',
#   'bêtise',
#   'signalées',
#   'larsonneur',
#   'catastrophiques',
#   'expulsion',
#   'débuté',
#   'soft',
#   'messe',
#   'caméra',
#   'lc',
#   'celera',
#   'cazeneuve',
#   'carney',
#   'socle',
#   'profité',
#   'rattachement',
#   'croisade',
#   'critère',
#   'creuses',
#   'cresson',
#   'manquent',
#   'rechercher',
#   'craintes',
#   'reconditionné',
#   'croyances',
#   'reconditionnés',
#   'coûteux',
#   'moments',
#   'féministes',
#   'mandats',
#   'pivot',
#   'quitte',
#   'dégradation',
#   'cède',
#   'quête',
#   'files',
#   'radicale',
#   'rafle',
#   'edito',
#   'partagent',
#   'marines',
#   'ralentissement',
#   'marianne',
#   'cubes',
#   'rapidité',
#   'edf',
#   'panneaux',
#   'convertibilité',
#   'dotés',
#   'formée',
#   'doubler',
#   'employeurs',
#   'mensuel',
#   'contrôles',
#   'emprisonnement',
#   'ose',
#   'contribuer',
#   'contribue',
#   'orthodoxe',
#   'majoritairement',
#   'remercié',
#   'coupure',
#   'palestinienne',
#   'formés',
#   'reforestation',
#   'refusant',
#   'garant',
#   'couche',
#   'registre',
#   'elysée',
#   'palestiniens',
#   'malheur',
#   'embauche',
#   'malbrunot',
#   'définitive',
#   'relocalisations',
#   'doté',
#   'relèvent',
#   'ouvrant',
#   'célébrations',
#   'questionnaire',
#   'provisoire',
#   'dépassent',
#   'mcconnell',
#   'franchement',
#   'mearsheimer',
#   'préconisée',
#   'dépistage',
#   'maîtrise',
#   'forêts',
#   'dictateur',
#   'frappée',
#   'protégé',
#   'meat',
#   'disposent',
#   'distributeur',
#   'foulée',
#   'profits',
#   'promesses',
#   'diversité',
#   'dissident',
#   'philippot',
#   'propice',
#   'mediterranean',
#   'philosophiques',
#   'proposons',
#   'démoniaque',
#   'maximale',
#   'dgccrf',
#   'modernité',
#   'financial',
#   'massivement',
#   'pylône',
#   'pédagogique',
#   'périodiquement',
#   'quai',
#   'qualifiant',
#   'pivet',
#   'parvenu',
#   'payent',
#   'procurer',
#   'mitch',
#   'performance',
#   'perdent',
#   'destouches',
#   'déroulé',
#   'préventives',
#   'prévoyait',
#   'psilocybine',
#   'fresque',
#   'dep',
#   'monts',
#   'née',
#   'collaborateurs',
#   'décrire',
#   'plénière',
#   'régulation',
#   'négatives',
#   'location',
#   'falloir',
#   'répétition',
#   'nullement',
#   'réflexions',
#   'collectivement',
#   'entretient',
#   'plier',
#   'obtient',
#   'commentateurs',
#   'migration',
#   'réagit',
#   'réaliste',
#   'entrent',
#   'entrepreneurs',
#   'observatoire',
#   'longs',
#   'colorado',
#   'collègue',
#   'colline',
#   'objectivité',
#   'réduisant',
#   'poche',
#   'multipolaire',
#   'clairs',
#   'chesnot',
#   'chesnais',
#   'normandie',
#   'chaves',
#   'espoirs',
#   'sauli',
#   'musicaux',
#   'liberticide',
#   'chanson',
#   'musulmane',
#   'champignons',
#   'nostalgie',
#   'décor',
#   'cjue',
#   'civilisationnel',
#   'lits',
#   'rétifs',
#   'rétroaction',
#   'circulant',
#   'cinquante',
#   'chrétien',
#   'estimant',
#   'pourparlers',
#   'christianisme',
#   'linares',
#   'pounds',
#   'entourage',
#   'commissions',
#   'repentance',
#   'opposés',
#   'macronisme',
#   'georges',
#   'opérateurs',
#   'consacre',
#   'enfer',
#   'ressemblent',
#   'geste',
#   'moratoire',
#   'draghi',
#   'confusion',
#   'engagent',
#   'confort',
#   'revendications',
#   'léger',
#   'représenté',
#   'orientale',
#   'contesté',
#   'conteneurs',
#   'flèche',
#   'reproduire',
#   'défiance',
#   'organisant',
#   'organique',
#   'repères',
#   'rescapé',
#   'ordonnances',
#   'consommateur',
#   'endiguer',
#   'revenue',
#   'lrem',
#   'enregistre',
#   'comptait',
#   'roosevelt',
#   'complément',
#   'go',
#   'engagées',
#   'loïg',
#   'ruffin',
#   'ruines',
#   'run',
#   'dressées',
#   'lourds',
#   'rythmes',
#   'compteurs',
#   'drastiques',
#   'confie',
#   'onze',
#   'gingrich',
#   'conduisant',
#   'ribera',
#   'conducteur',
#   'condoléances',
#   'lève',
#   'condamner',
#   'concrètement',
#   'concorde',
#   'premium',
#   'lycées',
#   'riyad',
#   'plateaux',
#   'luxembourg',
#   'rodéos',
#   'maintenu',
#   'accélère',
#   'today',
#   'instruments',
#   'bourreaux',
#   'heurts',
#   'justesse',
#   'soulignant',
#   'assurent',
#   'bourguignon',
#   'belliot',
#   'transférés',
#   'bourget',
#   'incarne',
#   'aurez',
#   'allure',
#   'accusatoire',
#   'transactions',
#   'éternel',
#   'éternelle',
#   'vedette',
#   'apparente',
#   'intervenant',
#   'baccalauréat',
#   'assumer',
#   'agissent',
#   'khoi',
#   'thématiques',
#   'stoltenberg',
#   'urbain',
#   'inquiétant',
#   'administratif',
#   'ahmed',
#   'brûlée',
#   'all',
#   'argentin',
#   'tebboune',
#   'wokisme',
#   'annuler',
#   'administrations',
#   'âgé',
#   'souffrir',
#   'aboutir',
#   'amélioré',
#   'indiquer',
#   'transmises',
#   'étroitement',
#   'anatolie',
#   'tiens',
#   'appelons',
#   'souhait',
#   'éleveurs',
#   'investissements',
#   'bouquets',
#   'australien',
#   'échéant',
#   'australienne',
#   'hivernale',
#   'issues',
#   'affrontent',
#   'autorisations',
#   'suspect',
#   'artiste',
#   'épuisement',
#   'illusions',
#   'avignon',
#   'turque',
#   'spécialisés',
#   'jugée',
#   'tournoi',
#   'affrontement',
#   'bretonnes',
#   'ambassade',
#   'verser',
#   'biographie',
#   'suédoise',
#   'vs',
#   'antique',
#   'afflux',
#   'historien',
#   'affichant',
#   'hôtel',
#   'udmf',
#   'hôte',
#   'indifférence',
#   'arrée',
#   'soutenues',
#   'ayons',
#   'bracelet',
#   'interrompu',
#   'beyond',
#   'imaginer',
#   'agglomération',
#   'junior',
#   'tombé',
#   'josé',
#   'éclairer',
#   'sévères',
#   'acceptant',
#   'hybride',
#   'koh',
#   'écologiste',
#   'accentuer',
#   'voyageurs',
#   'automatiquement',
#   'interrogées',
#   'arrêtés',
#   'votée',
#   'axes',
#   'academy',
#   'instauré',
#   'acquisition',
#   'évolué',
#   'ironie',
#   'iranien',
#   'trouble',
#   'yannick',
#   'évoquée',
#   'intestin',
#   'énième',
#   'vaincu',
#   'bardella',
#   'ipg',
#   'attaché',
#   'émir',
#   'tenant',
#   'baule',
#   'attachés',
#   'attendait',
#   'visé',
#   'bords',
#   'suffira',
#   'infraction',
#   'ajaccio',
#   'installe',
#   'insisté',
#   'apprête',
#   'vaimalama',
#   'apprenons',
#   'burn',
#   'kergoat',
#   'inévitable',
#   'bombardiers',
#   'annonces',
#   'hennebont',
#   'installées',
#   'irlandais',
#   'byline',
#   'annuelle',
#   'story',
#   'herblain',
#   'impulsion',
#   'souci',
#   'atténuer',
#   'éminemment',
#   'approvisionnements',
#   'balle',
#   'algérienne',
#   'ballons',
#   'hormis',
#   'indépendantiste',
#   'suisses',
#   'flynn',
#   'répression',
#   'manche',
#   'funérailles',
#   'clientèle',
#   'isolement',
#   'entreprendre',
#   'mario',
#   'impasse',
#   'orange',
#   'suspendus',
#   'islamophobie',
#   'gallon',
#   'coupé',
#   'défini',
#   'couples',
#   'courageuse',
#   'pipe',
#   'successeur',
#   'gpa',
#   'bipartisan',
#   'militairement',
#   'attendue',
#   'fustigé',
#   'tricheurs',
#   'raisonnablement',
#   'redressement',
#   'affaibli',
#   'sanctionné',
#   'opérationnelle',
#   'coercitives',
#   'funéraire',
#   'fléau',
#   'groupements',
#   'coercition',
#   'orienter',
#   'marins',
#   'oriente',
#   'surveillé',
#   'malsaine',
#   'ambitieuse',
#   'réguler',
#   'juif',
#   'entretenu',
#   'clément',
#   'afficher',
#   'animales',
#   'oreilles',
#   'réjouit',
#   'initiatives',
#   'traditionnellement',
#   'irakien',
#   'émergent',
#   'cote',
#   'salvatore',
#   'samarcande',
#   'affichage',
#   'acusensus',
#   'réjouir',
#   'coail',
#   'entrés',
#   'portugais',
#   'vrbpac',
#   'régulier',
#   'édith',
#   'répercussions',
#   'possiblement',
#   'florian',
#   'refusait',
#   'viser',
#   'regrette',
#   'immobilières',
#   'couler',
#   'réparation',
#   'voyant',
#   'cherchez',
#   'isolé',
#   'gar',
#   'chemins',
#   'fusil',
#   'cuvillier',
#   'affiches',
#   'clos',
#   'croix',
#   'redon',
#   'superpuissance',
#   'voies',
#   'justificatifs',
#   'réveil',
#   'poing',
#   'révision',
#   'admissibles',
#   'offrant',
#   'révoltes',
#   'cruciale',
#   'justificatif',
#   'supervision',
#   'justifié',
#   'décide',
#   'pluralisme',
#   'morgan',
#   'rechange',
#   'recevront',
#   'éloigne',
#   'réunies',
#   'circulent',
#   'administrés',
#   'vivants',
#   'trajet',
#   'féminisme',
#   'rassurer',
#   'rassuriste',
#   'liquide',
#   'féminine',
#   'hypocrite',
#   'ravagé',
#   'marchandises',
#   'mosquée',
#   'ravages',
#   'andersson',
#   'rayons',
#   'incompétence',
#   'lira',
#   'félicité',
#   'rassembler',
#   'transporter',
#   'enrichir',
#   'raymond',
#   'audace',
#   'andrei',
#   'chroniqueuse',
#   'blocages',
#   'ombre',
#   'addition',
#   'trentaine',
#   'fonde',
#   'chirac',
#   'recrutement',
#   'résident',
#   'rappelant',
#   'bombardé',
#   'plateau',
#   'voltaire',
#   'égards',
#   'aussitôt',
#   'morandini',
#   'kala',
#   'rêves',
#   'choquantes',
#   'optimisme',
#   'favorisent',
#   'bis',
#   'tricher',
#   'authenticité',
#   'islamo',
#   'optimiser',
#   'égale',
#   'clause',
#   'plantation',
#   'interdisant',
#   'bitcoin',
#   'islamiques',
#   'adverse',
#   'city',
#   'élargir',
#   'amuse',
#   'créateur',
#   'mettrait',
#   'plonger',
#   'live',
#   'pontivy',
#   'ploërmel',
#   'adressant',
#   'rapporteur',
#   'fautes',
#   'litzmannstadt',
#   'occitanie',
#   'transformant',
#   'choeur',
#   'saine',
#   'reconsidérer',
#   'hexagonal',
#   'mettra',
#   'oiseaux',
#   'passées',
#   'coffre',
#   'insalubre',
#   'balkans',
#   'respectueuse',
#   'conspirationnistes',
#   'alignements',
#   'respectent',
#   'constant',
#   'thermomix',
#   'alignés',
#   'mitterrand',
#   'ronaldo',
#   'ronds',
#   'parisienne',
#   'alinéa',
#   'déroulement',
#   'aigu',
#   'aigus',
#   'comédien',
#   'conservatisme',
#   'bancs',
#   'conservatrices',
#   'partenariats',
#   'aimer',
#   'partagées',
#   'luxe',
#   'désaccord',
#   'concepts',
#   'tempérament',
#   'baltic',
#   'thomin',
#   'zombies',
#   'constitutionnelle',
#   'tchèque',
#   'tiktok',
#   'agrément',
#   'permettaient',
#   'baissé',
#   'consécutive',
#   'jair',
#   'homosexuel',
#   'routine',
#   'routière',
#   'bain',
#   'effectuée',
#   'inquiets',
#   'belenet',
#   'permettrait',
#   'rousseau',
#   'dépourvu',
#   'inauguré',
#   'fierté',
#   'molac',
#   'bechet',
#   'constructeur',
#   'jn',
#   'roue',
#   'tiendra',
#   'lugan',
#   'composée',
#   'gelées',
#   'représenterait',
#   'tienne',
#   'effectif',
#   'concessions',
#   'rivière',
#   'confier',
#   'yaël',
#   'patrie',
#   'modification',
#   'congés',
#   'yorker',
#   'reçoit',
#   'retourne',
#   'macronistes',
#   'ypg',
#   'getty',
#   'jens',
#   'gestionnaire',
#   'pause',
#   'impératifs',
#   'conductrices',
#   'inspirées',
#   'légitimement',
#   'imprévisible',
#   'retranché',
#   'légers',
#   'conforme',
#   'passible',
#   'législatif',
#   'revers',
#   'confronté',
#   'pathogénicité',
#   'passera',
#   'détecté',
#   'gilead',
#   'confirmant',
#   'terminal',
#   'détente',
#   'gestes',
#   'resteront',
#   'mobiliser',
#   'consacrée',
#   'hostilité',
#   'installés',
#   'restant',
#   'filiale',
#   'désastreux',
#   'alertes',
#   'hot',
#   'finira',
#   'concluant',
#   'battu',
#   'ly',
#   'modifiés',
#   'mobilisés',
#   'richesse',
#   'ringard',
#   'tes',
#   'girl',
#   'ajout',
#   'bastion',
#   'rieu',
#   'désigné',
#   'impérialisme',
#   'détruite',
#   'agricole',
#   'flickr',
#   'minoritaire',
#   'africaine',
#   'remplie',
#   'rempli',
#   'touchent',
#   'économiser',
#   'économiste',
#   'rendues',
#   'coloniale',
#   'colonel',
#   'emploie',
#   'ouragan',
#   'démissionner',
#   'obligés',
#   'emparer',
#   'minoritaires',
#   'gouffre',
#   'longues',
#   'rébellion',
#   'insuffisantes',
#   'convenu',
#   'gauchistes',
#   'séduire',
#   'itinéraire',
#   'hlm',
#   'gauchiste',
#   'phare',
#   'démonstration',
#   'sécuritaire',
#   'rencontrés',
#   'avoué',
#   'récidive',
#   'emmerdés',
#   'renaudie',
#   'colloque',
#   'collomb',
#   'empêchent',
#   'injonctions',
#   'judicieux',
#   'fellow',
#   'piller',
#   'emr',
#   'israéliennes',
#   'pilote',
#   'aval',
#   'régionales',
#   'délibération',
#   'autriche',
#   'majoritaires',
#   'remet',
#   'syndromes',
#   'bilatérales',
#   'affronter',
#   'aveu',
#   'végan',
#   'tournage',
#   'tourne',
#   'emporte',
#   'cornet',
#   'malaise',
#   'relu',
#   'coronarien',
#   'coronariens',
#   'tournée',
#   'mines',
#   'gardiens',
#   'axe',
#   'compliquée',
#   'fibre',
#   'dépendante',
#   'instrumentalisation',
#   'bennett',
#   'dépasser',
#   'benoît',
#   'maires',
#   'eimer',
#   'repas',
#   'allusion',
#   'contradictoire',
#   'bachar',
#   'golovko',
#   'communiquer',
#   'contraindre',
#   'parade',
#   'lovecraft',
#   'continents',
#   'échappe',
#   'magiques',
#   'magistrat',
#   'wikipedia',
#   'jadis',
#   'reproche',
#   ...],
#  'xlarge': ['de',
#   'la',
#   'le',
#   'et',
#   'les',
#   'des',
#   'en',
#   'un',
#   'est',
#   'du',
#   'une',
#   'que',
#   'pour',
#   'dans',
#   'qui',
#   'il',
#   'par',
#   'sur',
#   'au',
#   'pas',
#   'ce',
#   'plus',
#   'qu',
#   'ne',
#   'ont',
#   'se',
#   'avec',
#   'sont',
#   'ou',
#   'été',
#   'son',
#   'aux',
#   'mais',
#   'nous',
#   'cette',
#   'comme',
#   'elle',
#   'on',
#   'fait',
#   'être',
#   'tout',
#   'pays',
#   'même',
#   'ces',
#   'leur',
#   'si',
#   'sa',
#   'aussi',
#   'ils',
#   'ses',
#   'france',
#   'bien',
#   'je',
#   'sans',
#   'faire',
#   'vous',
#   'contre',
#   'après',
#   'deux',
#   'russie',
#   'avait',
#   'monde',
#   'politique',
#   'depuis',
#   'entre',
#   'peut',
#   'était',
#   'ans',
#   'avoir',
#   'guerre',
#   'autres',
#   'tous',
#   'covid',
#   'selon',
#   'ukraine',
#   'président',
#   'très',
#   'cela',
#   'alors',
#   'leurs',
#   'encore',
#   'dont',
#   'non',
#   'ainsi',
#   'où',
#   'sous',
#   'lui',
#   'moins',
#   'cas',
#   'donc',
#   'états',
#   'temps',
#   'gouvernement',
#   'également',
#   'français',
#   'otan',
#   'état',
#   'ministre',
#   'russe',
#   'notre',
#   'vers',
#   'autre',
#   'personnes',
#   'soit',
#   'europe',
#   'avant',
#   'unis',
#   'déclaré',
#   'déjà',
#   'premier',
#   'macron',
#   'lors',
#   'va',
#   'fin',
#   'toujours',
#   'mois',
#   'nos',
#   'toute',
#   'notamment',
#   'car',
#   'com',
#   'peu',
#   'source',
#   'sera',
#   'juillet',
#   'ceux',
#   'projet',
#   'faut',
#   'voir',
#   'cet',
#   'européenne',
#   'crise',
#   'plusieurs',
#   'années',
#   'pouvoir',
#   'aujourd',
#   'hui',
#   'prix',
#   'fois',
#   'jusqu',
#   'trois',
#   'vie',
#   'santé',
#   'rien',
#   'ai',
#   'pourrait',
#   'chez',
#   'pendant',
#   'première',
#   'grande',
#   'face',
#   'certains',
#   'doit',
#   'rapport',
#   'twitter',
#   'dernier',
#   'quand',
#   'nombre',
#   'beaucoup',
#   'dit',
#   'russes',
#   'mai',
#   'nouveau',
#   'année',
#   'juin',
#   'millions',
#   'question',
#   'effet',
#   'quelques',
#   'part',
#   'gaz',
#   'the',
#   'toutes',
#   'système',
#   'médias',
#   'jamais',
#   'grand',
#   'dire',
#   'politiques',
#   'vaccin',
#   'emmanuel',
#   'article',
#   'union',
#   'travail',
#   'site',
#   'homme',
#   'ni',
#   'liberté',
#   'jours',
#   'jean',
#   'compte',
#   'ailleurs',
#   'situation',
#   'presse',
#   'raison',
#   'elles',
#   'partie',
#   'nouvelle',
#   'jour',
#   'ça',
#   'là',
#   'celle',
#   'place',
#   'début',
#   'afin',
#   'origine',
#   'risque',
#   'peuvent',
#   'pourquoi',
#   'sécurité',
#   'étaient',
#   'mondiale',
#   'eu',
#   'conseil',
#   'groupe',
#   'eux',
#   'celui',
#   'lieu',
#   'mal',
#   'ici',
#   'trump',
#   'société',
#   'aucun',
#   'pourtant',
#   'serait',
#   'tant',
#   'parce',
#   'point',
#   'cours',
#   'enfants',
#   'savoir',
#   'population',
#   'seulement',
#   'forces',
#   'données',
#   'près',
#   'exemple',
#   'sanitaire',
#   'me',
#   'euros',
#   'suite',
#   'mesure',
#   'aurait',
#   'informations',
#   'ci',
#   'maintenant',
#   'public',
#   'étude',
#   'armée',
#   'comment',
#   'personne',
#   'ensemble',
#   'ayant',
#   'européens',
#   'plan',
#   'mis',
#   'étant',
#   'reste',
#   'chine',
#   'moment',
#   'prendre',
#   'droit',
#   'votre',
#   'nombreux',
#   'histoire',
#   'chaque',
#   'manière',
#   'membres',
#   'dollars',
#   'demande',
#   'or',
#   'chef',
#   'milliards',
#   'semble',
#   'avaient',
#   'gens',
#   'cadre',
#   'trop',
#   'veut',
#   'femmes',
#   'seront',
#   'information',
#   'septembre',
#   'agit',
#   'vaccination',
#   'lorsque',
#   'dès',
#   'nord',
#   'américain',
#   'vaccins',
#   'mon',
#   'énergie',
#   'économique',
#   'anti',
#   'cause',
#   'laquelle',
#   'façon',
#   'puis',
#   'mettre',
#   'défense',
#   'taux',
#   'lire',
#   'possible',
#   'ukrainien',
#   'enquête',
#   'réalité',
#   'général',
#   'autorités',
#   'militaire',
#   'réponse',
#   'biden',
#   'https',
#   'of',
#   'sociaux',
#   'mondial',
#   'existe',
#   'ministère',
#   'armes',
#   'chose',
#   'effets',
#   'période',
#   'bon',
#   'vote',
#   'partir',
#   'entreprises',
#   'mars',
#   'sujet',
#   'aucune',
#   'novembre',
#   'besoin',
#   'niveau',
#   'avons',
#   'malgré',
#   'cependant',
#   'administration',
#   'vérité',
#   'national',
#   'terre',
#   'hommes',
#   'doivent',
#   'sommes',
#   'publique',
#   'campagne',
#   'pu',
#   'sûr',
#   'donné',
#   'devrait',
#   'mise',
#   'ancien',
#   'an',
#   'mort',
#   'vu',
#   'accès',
#   'famille',
#   'pris',
#   'moyen',
#   'organisation',
#   'ensuite',
#   'résultats',
#   'vont',
#   'occident',
#   'quel',
#   'nom',
#   'élections',
#   'aide',
#   'virus',
#   'contrôle',
#   'base',
#   'terme',
#   'seul',
#   'quelque',
#   'jeunes',
#   'mêmes',
#   'nationalité',
#   'répartir',
#   'composer',
#   'ruben',
#   'homologues',
#   'sain',
#   'escalade',
#   'chantier',
#   'synthèse',
#   'liberty',
#   'chomsky',
#   'condamnée',
#   'syndicat',
#   'voisins',
#   'acteur',
#   'suspension',
#   'énergies',
#   'sceaux',
#   'fameux',
#   'symbolique',
#   'leçon',
#   'compagnie',
#   'communistes',
#   'col',
#   'facilité',
#   'christophe',
#   'hazanavicius',
#   'accueillis',
#   'estimer',
#   'girard',
#   'syndicats',
#   'conclut',
#   'adoptée',
#   'hautes',
#   'christiana',
#   'indignation',
#   'saône',
#   'musulmanes',
#   'neutre',
#   'cercueils',
#   'vienne',
#   'gravement',
#   'bel',
#   'scénarios',
#   'élever',
#   'accélérer',
#   'joueurs',
#   'semmelweis',
#   'lituanie',
#   'tarf',
#   'eurasien',
#   'dure',
#   'catholique',
#   'exige',
#   'norvège',
#   'san',
#   'cite',
#   'réalisation',
#   'citoyenne',
#   'hongrois',
#   'ankara',
#   'espérer',
#   'administratifs',
#   'blessées',
#   'lula',
#   'internats',
#   'routes',
#   'salles',
#   'cercle',
#   'drame',
#   'émeutes',
#   'révisions',
#   'academia',
#   'statues',
#   'exceptionnelle',
#   'faciale',
#   'séance',
#   'réacteurs',
#   'vives',
#   'offshore',
#   'mt',
#   'commenter',
#   'roi',
#   'grèves',
#   'accordée',
#   'clandestines',
#   'violente',
#   'commenté',
#   'entrées',
#   'observer',
#   'navigation',
#   'communs',
#   'mohammed',
#   'écosystèmes',
#   'doha',
#   'sons',
#   'fleurs',
#   'franck',
#   'torre',
#   'appartenant',
#   'angle',
#   'finale',
#   'remédier',
#   'primaires',
#   'dictature',
#   'outrance',
#   'recep',
#   'remporté',
#   'islamistes',
#   'dialogue',
#   'arnaud',
#   'formule',
#   'plaisir',
#   'contraints',
#   'piliers',
#   'frères',
#   'mccarthy',
#   'provoquée',
#   'archéologique',
#   'dmitri',
#   'dinard',
#   'aéroports',
#   'gafam',
#   'mbs',
#   'intense',
#   'futurs',
#   'alerté',
#   'istanbul',
#   'féministe',
#   'vécu',
#   'panot',
#   'hypothèses',
#   'pakistan',
#   'pauvreté',
#   'antisémitisme',
#   'millionnaires',
#   'vendu',
#   'fier',
#   'vitesse',
#   'palme',
#   'ménages',
#   'préserver',
#   'arrêts',
#   'counsel',
#   'dégradé',
#   'redonner',
#   'assisté',
#   'inversion',
#   'tourisme',
#   'garros',
#   'missions',
#   'cadalen',
#   'piscine',
#   'créant',
#   'vatican',
#   'tournant',
#   'manqué',
#   'rapprocher',
#   'cryptomonnaie',
#   'pulli',
#   'ambitions',
#   'relever',
#   'contrainte',
#   'renvoyer',
#   'contradiction',
#   'mégalithiques',
#   'bangladesh',
#   'démocratiques',
#   'validé',
#   'prononcé',
#   'appelés',
#   'triste',
#   'tf',
#   'dissidents',
#   'indécence',
#   'attali',
#   'quotidienne',
#   'solidarité',
#   'bénéficient',
#   'jaune',
#   'damien',
#   'invoquant',
#   'propositions',
#   'shanghai',
#   'baltes',
#   'héritier',
#   'céder',
#   'prévues',
#   'particuliers',
#   'vannes',
#   'philosophe',
#   'östlund',
#   'légalité',
#   'développe',
#   'menhir',
#   'législateurs',
#   'agressive',
#   'milieux',
#   'inacceptable',
#   'alexa',
#   'progressistes',
#   'adversaire',
#   'quinquennat',
#   'connais',
#   'opposants',
#   'larmes',
#   'possibilités',
#   'insoumis',
#   'dominant',
#   'craindre',
#   'planification',
#   'représentation',
#   'udb',
#   'arts',
#   'écrivait',
#   'reportage',
#   'paradis',
#   'paradigme',
#   'flb',
#   'huelva',
#   'ambassadeur',
#   'idéologiques',
#   'interroge',
#   'utilisateur',
#   'prouvé',
#   'instauration',
#   'souveraine',
#   'vagues',
#   'dessin',
#   'mécanismes',
#   'janera',
#   'forza',
#   'minute',
#   'maroc',
#   'disciplinaire',
#   'prévient',
#   'sortant',
#   'défi',
#   'peskov',
#   'soutiens',
#   'impressionnant',
#   'problématique',
#   'bloque',
#   'télégramme',
#   'bloqué',
#   'délais',
#   'résolution',
#   'hexagone',
#   'détermination',
#   'sixième',
#   'martens',
#   'achats',
#   'nuire',
#   'résidences',
#   'pénal',
#   'dominants',
#   'qualifiés',
#   'réservé',
#   'détient',
#   'classique',
#   'quarante',
#   'impératif',
#   'influenceurs',
#   'anglo',
#   'menhirs',
#   'détracteurs',
#   'assurant',
#   'halloween',
#   'sortis',
#   'tweets',
#   'dolines',
#   'puissants',
#   'mettait',
#   'posteriori',
#   'sncf',
#   'supporter',
#   'littoral',
#   'instabilité',
#   'épidémiologistes',
#   'pâques',
#   'mathieu',
#   'tunisie',
#   'budgétaire',
#   'match',
#   'téléréalité',
#   'vingtaine',
#   'slogan',
#   'pyongyang',
#   'indemnisation',
#   'ciel',
#   'facture',
#   'arbres',
#   'province',
#   'bouche',
#   'satellite',
#   'satellites',
#   'satisfaire',
#   'démarche',
#   'librement',
#   'charlie',
#   'sapena',
#   'grève',
#   'chemise',
#   'sandrine',
#   'argentine',
#   'dignité',
#   'chauves',
#   'instrument',
#   'saoudien',
#   'durs',
#   'promesse',
#   'lgbt',
#   'duré',
#   'distinguer',
#   'mégalithique',
#   'promet',
#   'démissionné',
#   'accent',
#   'distribuer',
#   'fraction',
#   'noam',
#   'protestations',
#   'divertissement',
#   'bénévoles',
#   'proposent',
#   'jérôme',
#   'start',
#   'maux',
#   'mixité',
#   'kim',
#   'deuxièmement',
#   'finlandaise',
#   'penseur',
#   'prêtres',
#   'prêtre',
#   'alger',
#   'essentielles',
#   'uber',
#   'freedom',
#   'maurice',
#   'amazon',
#   'présentés',
#   'duquel',
#   'di',
#   'diabolisation',
#   'vivement',
#   'frappé',
#   'fiscal',
#   'déplore',
#   'bonheur',
#   'impossibilité',
#   'sainte',
#   'intervenir',
#   'devoirs',
#   'interventions',
#   'intermédiaires',
#   'notera',
#   'déportés',
#   'arrivant',
#   'municipales',
#   'misérables',
#   'détriment',
#   'coagulation',
#   'joie',
#   'douches',
#   'conviction',
#   'fenêtre',
#   'compatriotes',
#   'fer',
#   'veto',
#   'isère',
#   'défilé',
#   'occupée',
#   'jong',
#   'mairie',
#   'ouvrages',
#   'tormenen',
#   'complotisme',
#   'tardive',
#   'comploteurs',
#   'azovstahl',
#   'cardiovasculaires',
#   'oeufs',
#   'tombés',
#   'convaincu',
#   'rendue',
#   'occupent',
#   'écologie',
#   'commente',
#   'trabajos',
#   'rejet',
#   'reine',
#   'malo',
#   'costa',
#   'séquence',
#   'costume',
#   'autorise',
#   'maltraitance',
#   'plouégat',
#   'antivax',
#   'relancer',
#   'capteurs',
#   'virulent',
#   'communautaire',
#   'corde',
#   'humilité',
#   'dotée',
#   'méchants',
#   'relocalisation',
#   'signes',
#   'tourné',
#   'sûreté',
#   'capitulation',
#   'relate',
#   'sputnik',
#   'vi',
#   'refondation',
#   'consacré',
#   'opérationnel',
#   'imam',
#   'banlieues',
#   'souvient',
#   'bancaire',
#   'considération',
#   'honte',
#   'initiale',
#   'interpelle',
#   'légalisation',
#   'élaboration',
#   'serge',
#   'barrage',
#   'retraits',
#   'rica',
#   'planétaire',
#   'légitimité',
#   'opposant',
#   'prehistoria',
#   'brizé',
#   'reprend',
#   'contestation',
#   'jinping',
#   'contestée',
#   'morvan',
#   'huffington',
#   'roubles',
#   'enclave',
#   'extrêmes',
#   'composante',
#   'renvoie',
#   'reproché',
#   'lega',
#   'rescapée',
#   'maga',
#   'globalement',
#   'constitué',
#   'consultation',
#   'représentative',
#   'tragique',
#   'rapproche',
#   'rapportent',
#   'inquiétudes',
#   'donnera',
#   'moindres',
#   'familiale',
#   'secondes',
#   'attirer',
#   'envoyées',
#   'biodiversité',
#   'amener',
#   'acquérir',
#   'incontournable',
#   'rangs',
#   'moeurs',
#   'parité',
#   'âgée',
#   'pardon',
#   'piège',
#   'rationnement',
#   'souhaitent',
#   'croyons',
#   'coupables',
#   'bilongo',
#   'réformes',
#   'pixabay',
#   'négligeable',
#   'gérer',
#   'lanka',
#   'brûlés',
#   'sea',
#   'hélas',
#   'développée',
#   'figurent',
#   'surveillants',
#   'esa',
#   'célèbres',
#   'insiste',
#   'partielle',
#   'priver',
#   'réinsertion',
#   'politico',
#   'légalement',
#   'multinationales',
#   'cnom',
#   'radicalement',
#   'sri',
#   'radical',
#   'marne',
#   'suscitant',
#   'file',
#   'inquiètent',
#   'vilain',
#   'reconnus',
#   'reculer',
#   'gorge',
#   'systématique',
#   'colonie',
#   'observateurs',
#   'navigant',
#   'colonisé',
#   'reconnaissant',
#   'journalistique',
#   'galopante',
#   'goscinny',
#   'portuaire',
#   'navires',
#   'sébastien',
#   'brutale',
#   'gorce',
#   're',
#   'coupés',
#   'mans',
#   'envoi',
#   'trait',
#   'recruter',
#   'sillage',
#   'recommandation',
#   'andré',
#   'parasite',
#   'placée',
#   'illégaux',
#   'écarts',
#   'colonialisme',
#   'islamique',
#   'calvaire',
#   'sollicité',
#   'nez',
#   'lamballe',
#   'exportation',
#   'serbe',
#   'cap',
#   'leadership',
#   'lecourrier',
#   'lanta',
#   'exceptions',
#   'exclu',
#   'signifier',
#   'calme',
#   'fonctionnaire',
#   'session',
#   'navire',
#   'socialistes',
#   'laura',
#   'socialisme',
#   'méchant',
#   'métiers',
#   'celsius',
#   'sic',
#   'popularité',
#   'cents',
#   'exemptions',
#   'débarquer',
#   'bêtise',
#   'signalées',
#   'larsonneur',
#   'seuil',
#   'catastrophiques',
#   'expulsion',
#   'débuté',
#   'soft',
#   'signer',
#   'messe',
#   'caméra',
#   'lc',
#   'celera',
#   'cazeneuve',
#   'carney',
#   'socle',
#   'profité',
#   'guillaume',
#   'rattachement',
#   'croisade',
#   'critère',
#   'creuses',
#   'cresson',
#   'manquent',
#   'rechercher',
#   'craintes',
#   'reconditionné',
#   'croyances',
#   'reconditionnés',
#   'effondrer',
#   'coûteux',
#   'moments',
#   'reconnue',
#   'placer',
#   'records',
#   'féministes',
#   'mandats',
#   'pivot',
#   'quitte',
#   'dégradation',
#   'cède',
#   'quête',
#   'files',
#   'fur',
#   'radicale',
#   'rafle',
#   'edito',
#   'partagent',
#   'marines',
#   'ralentissement',
#   'ramener',
#   'marianne',
#   'paroles',
#   'cubes',
#   'rapidité',
#   'edf',
#   ...]}

# %%
df_words
# Out:
#              count_0  count_1  count  rare_1  rare_2  rare_3  rare_4  rare_5  \
# de             12631    19202  31833   False   False   False   False   False
# la              7376    10290  17666   False   False   False   False   False
# le              5421     8192  13613   False   False   False   False   False
# et              4748     8062  12810   False   False   False   False   False
# les             4669     8544  13213   False   False   False   False   False
# ...              ...      ...    ...     ...     ...     ...     ...     ...
# performante        0        2      2   False    True    True    True    True
# dépouillés         0        2      2   False    True    True    True    True
# perforé            0        1      1    True    True    True    True    True
# perfusions         0        1      1    True    True    True    True    True
# þórólfur           0        1      1    True    True    True    True    True
#
#              rare_6  rare_7  common_50  common_80  common_120  common_200  \
# de            False   False       True       True        True        True
# la            False   False       True       True        True        True
# le            False   False       True       True        True        True
# et            False   False       True       True        True        True
# les           False   False       True       True        True        True
# ...             ...     ...        ...        ...         ...         ...
# performante    True    True      False      False       False       False
# dépouillés     True    True      False      False       False       False
# perforé        True    True      False      False       False       False
# perfusions     True    True      False      False       False       False
# þórólfur       True    True      False      False       False       False
#
#              common_500
# de                 True
# la                 True
# le                 True
# et                 True
# les                True
# ...                 ...
# performante       False
# dépouillés        False
# perforé           False
# perfusions        False
# þórólfur          False
#
# [36752 rows x 15 columns]

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
df_texts = df_infox

# %%
tokenizer = lex.get_words

# %%
benches = {}
for key in ignore_words.keys():
    vectorizer = CountVectorizer(lowercase=True, preprocessor=preprocessor, tokenizer=tokenizer, stop_words=ignore_words[key])
    count_matrix = vectorizer.fit_transform(df_infox['text'])
    count_array = count_matrix.toarray()
    df_tf = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
    df_X = df_tf
    df_bench = bench.benchmark(df_X,df_texts['infox'],predictors=predictors,train_size=train_size,random_state=random_state)
    df_bench = df_bench.sort_values('roc_auc',ascending=False)
    benches[key] = df_bench
# Out:
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 2.285001039505005 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 9.693485260009766 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8037974683544304
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.40480995178222656 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 5.443416118621826 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8265427215189873
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.3380720615386963 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 5.01363730430603 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8235759493670887
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.147813081741333 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 3.04577374458313 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8318829113924051
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.11215996742248535 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 2.292487859725952 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8382120253164556

# %%
for key in benches:
    print(f'{key} : {benches[key].roc_auc.max()}')
# Out:
# None : 0.8037974683544304
# small : 0.8265427215189873
# medium : 0.8235759493670887
# large : 0.8318829113924051
# xlarge : 0.8382120253164556

# %%
df_bench=benches['None']
df_bench
# Out:
#                       roc_auc        f1  accuracy   recall   log_loss  \
# Neural Network       0.803797  0.711111  0.727273  0.75000   9.419795
# Logistic Regression  0.769383  0.686567  0.706294  0.71875  10.144390
#
#                      false_positive  false_negative  fit_time  proba_time
# Neural Network             0.160839        0.111888  9.693485    0.205480
# Logistic Regression        0.167832        0.125874  2.285001    0.172908

# %%
df_bench=benches['xlarge']
df_bench
# Out:
#                       roc_auc        f1  accuracy    recall  log_loss  \
# Neural Network       0.838212  0.748092  0.769231  0.765625  7.970588
# Logistic Regression  0.816258  0.703125  0.734266  0.703125  9.178243
#
#                      false_positive  false_negative  fit_time  proba_time
# Neural Network             0.125874        0.104895  2.292488    0.038522
# Logistic Regression        0.132867        0.132867  0.112160    0.035591

# %% [markdown]
# ## TF/IDF Words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
df_texts = df_infox

# %%
tokenizer = lex.get_words

# %%
benches = {}
for key in ignore_words.keys():
    vectorizer = TfidfVectorizer(lowercase=True, preprocessor=preprocessor, tokenizer=tokenizer, stop_words=ignore_words[key])
    count_matrix = vectorizer.fit_transform(df_infox['text'])
    count_array = count_matrix.toarray()
    df_tf = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
    df_X = df_tf
#    df_bench = bench.benchmark(df_X,df_texts['infox'],predictors=predictors,train_size=train_size,random_state=random_state)
    df_bench = bench.benchmark(df_X,df_texts['infox'],train_size=train_size,random_state=random_state)
    df_bench = df_bench.sort_values('roc_auc',ascending=False)
    benches[key] = df_bench
# Out:
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 1.066667079925537 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 14.454711198806763 s
# INFO:root:Training RBF SVM
# INFO:root:Training time : 10.524244785308838 s
# INFO:root:Training Gaussian Naive Bayes
# INFO:root:Training time : 0.39220404624938965 s
# INFO:root:Training Multinomial Naive Bayes
# INFO:root:Training time : 0.15006184577941895 s
# INFO:root:Training Nearest Neighbors
# INFO:root:Training time : 0.18019676208496094 s
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# INFO:root:Training Linear SVM
# INFO:root:Training time : 11.911415100097656 s
# INFO:root:Training Gaussian Process
# INFO:root:Training time : 16.86896800994873 s
# INFO:root:Training Decision Tree
# INFO:root:Training time : 0.6223208904266357 s
# INFO:root:Training Random Forest
# INFO:root:Training time : 0.15397024154663086 s
# INFO:root:Training AdaBoost
# INFO:root:Training time : 7.767518043518066 s
# INFO:root:Training QDA
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# INFO:root:Training time : 1.1355230808258057 s
# INFO:root:Training Gradient Boosting
# INFO:root:Training time : 73.53362774848938 s
# INFO:root:Training Dummy
# INFO:root:Training time : 0.000579833984375 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8686708860759493
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['
'approprier', 'approvisionnement', 'approximatif', 'appréhension', 'apprêter', 'appui', 'appétissant', 'apôtre', 'aqueux', 'arable', 'arborer', 'arbre', 'arbuste', 'arcane', 'archéologue', 'ardent', 'ardeur', 'arguer', 'arme', 'armement', 'arnaque', 'arnaqueur', 'arriver', 'arrière', 'arrondi', 'arroser', 'arrêt', 'arrêter', 'arsenal', 'art', 'arthropode', 'articulaire', 'artériel', 'as', 'ascendant', 'ashkénaze', 'asperger', 'asphyxier', 'aspirateur', 'aspirer', 'assassinat', 'assaut', 'assembler', 'assener', 'assermenter', 'asservi', 'assimilable', 'assister', 'assouplir', 'assourdir', 'assurance', 'assurer', 'astreindre', 'astronomique', 'astucieux', 'athénien', 'atlantique', 'atomiste', 'atrocité', 'attaquer', 'attarder', 'atteindre', 'atteler', 'attendre', 'attendrir', 'attente', 'attentif', 'attention', 'attestation', 'attiser', 'attitrer', 'attitude', 'attractif', 'attraire', 'attrister', 'audience', 'audit', 'augmentation', 'augmenter', 'aumône', 'auréoler', 'auspice', 'auteur', 'authentifier', 'autiste', 'autocensurer', 'autochtone', 'autographe', 'automatique', 'automatiser', 'automoteur', 'autonome', 'autorisation', 'autoriser', 'autorité', 'avancer', 'avanie', 'aventurier', 'avenu', 'averti', 'avertissement', 'aveugle', 'aveugler', 'avilir', 'aviner', 'aviser', 'axiome', 'azimut', 'aérer', 'aérien', 'aéroport', 'babouchka', 'bactérie', 'bafouer', 'bagage', 'bagagiste', 'baigneur', 'baisse', 'baisser', 'balader', 'baladeur', 'balai', 'balancer', 'balbutier', 'balise', 'baliverne', 'baller', 'ballotter', 'bancal', 'bande', 'bander', 'bandit', 'banlieusard', 'baptiser', 'barbelé', 'barge', 'baron', 'barr ...
#   warnings.warn(
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.15534305572509766 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 6.835160255432129 s
# INFO:root:Training RBF SVM
# INFO:root:Training time : 3.163151979446411 s
# INFO:root:Training Gaussian Naive Bayes
# INFO:root:Training time : 0.08667898178100586 s
# INFO:root:Training Multinomial Naive Bayes
# INFO:root:Training time : 0.03953695297241211 s
# INFO:root:Training Nearest Neighbors
# INFO:root:Training time : 0.042656660079956055 s
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# INFO:root:Training Linear SVM
# INFO:root:Training time : 2.059095859527588 s
# INFO:root:Training Gaussian Process
# INFO:root:Training time : 3.5989151000976562 s
# INFO:root:Training Decision Tree
# INFO:root:Training time : 0.12382292747497559 s
# INFO:root:Training Random Forest
# INFO:root:Training time : 0.051698923110961914 s
# INFO:root:Training AdaBoost
# INFO:root:Training time : 1.4268741607666016 s
# INFO:root:Training QDA
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# INFO:root:Training time : 0.16641712188720703 s
# INFO:root:Training Gradient Boosting
# INFO:root:Training time : 200.3978910446167 s
# INFO:root:Training Dummy
# INFO:root:Training time : 0.000396728515625 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8659018987341772

# %%
for key in benches:
    print(f'{key} : {benches[key].roc_auc.max()}')
# Out:
# None : 0.8609572784810127
# small : 0.8712420886075949
# medium : 0.8744066455696202
# large : 0.8809335443037974
# xlarge : 0.8837025316455696

# %%
df_bench=benches['small']
df_bench
# Out:
#                       roc_auc        f1  accuracy    recall  log_loss  \
# Logistic Regression  0.871242  0.791045  0.804196  0.828125  6.762932
# Neural Network       0.870055  0.776119  0.790210  0.812500  7.245998
#
#                      false_positive  false_negative   fit_time  proba_time
# Logistic Regression        0.118881        0.076923   0.392821    0.119973
# Neural Network             0.125874        0.083916  17.886209    0.133574

# %% [markdown]
# ## TF/IDF Lemmas

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
df_texts = df_infox

# %%
tokenizer = lex.get_lemmas_from_text

# %%
benches = {}
for key in ignore_lemmas.keys():
    vectorizer = TfidfVectorizer(lowercase=True, preprocessor=preprocessor, tokenizer=tokenizer, stop_words=ignore_lemmas[key])
    count_matrix = vectorizer.fit_transform(df_infox['text'])
    count_array = count_matrix.toarray()
    df_tf = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
    df_X = df_tf
    df_bench = bench.benchmark(df_X,df_texts['infox'],predictors=predictors,train_size=train_size,random_state=random_state)
    df_bench = df_bench.sort_values('roc_auc',ascending=False)
    benches[key] = df_bench
# Out:
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.7382159233093262 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 18.823505878448486 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8686708860759493
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aboutir', 'abrutir', 'affilier', 'agir', 'ambitieux', 'bouillir', 'bénir', 'climatiser', 'croire', 'décombrer', 'déplaire', 'florir', 'instruire', 'joindre', 'matcher', 'maudire', 'mol', 'muqueux', 'obéir', 'oxygéner', 'rugir', 'saisir', 'satisfaire', 'spécifier', 'subventionner', 'teindre', 'tracter', 'vieillir', 'vrombir', 'émerger'] not in stop_words.
#   warnings.warn(
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.4412679672241211 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 12.868823051452637 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8696598101265822
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aboutir', 'abrutir', 'affilier', 'agir', 'ambitieux', 'bouillir', 'bruire', 'climatiser', 'conjoindre', 'coordonner', 'croire', 'décombrer', 'déplaire', 'florir', 'joindre', 'matcher', 'maudire', 'menacer', 'mol', 'obéir', 'oxygéner', 'personnaliser', 'pil', 'presser', 'présumer', 'rouvrir', 'saisir', 'satisfaire', 'subventionner', 'suivre', 'teindre', 'tracter', 'vieillir', 'vrombir', 'émerger', 'équivaloir'] not in stop_words.
#   warnings.warn(
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.3612861633300781 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 8.683760166168213 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8694620253164557
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aboutir', 'abrutir', 'affilier', 'ambitieux', 'boire', 'bouillir', 'bruire', 'climatiser', 'commercer', 'conter', 'coordonner', 'croire', 'décombrer', 'florir', 'grandir', 'inclure', 'intégrer', 'joindre', 'lire', 'matcher', 'maudire', 'menacer', 'nuire', 'obéir', 'oxygéner', 'presser', 'précieux', 'présumer', 'saisir', 'satisfaire', 'standardiser', 'structurer', 'subventionner', 'suivre', 'taler', 'teindre', 'tracter', 'urger', 'vieillir', 'vrombir', 'émerger', 'énoncer', 'équivaloir'] not in stop_words.
#   warnings.warn(
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.1692061424255371 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 6.695515871047974 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8698575949367089
# /Users/fm/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abrutir', 'boire', 'bouillir', 'bruire', 'climatiser', 'commercer', 'conter', 'coordonner', 'décombrer', 'florir', 'grandir', 'inclure', 'intégrer', 'joindre', 'matcher', 'maudire', 'menacer', 'nuire', 'obéir', 'oxygéner', 'poster', 'presser', 'précieux', 'présumer', 'résider', 'saisir', 'saler', 'satisfaire', 'standardiser', 'teindre', 'tracter', 'traire', 'urger', 'vieillir', 'vrombir', 'émerger', 'énoncer', 'équivaloir'] not in stop_words.
#   warnings.warn(
# INFO:root:Training Logistic Regression
# INFO:root:Training time : 0.14871716499328613 s
# INFO:root:Training Neural Network
# INFO:root:Training time : 6.124490976333618 s
# INFO:root:Training Done !
# INFO:root:Best ROC AUC : 0.8591772151898734

# %%
for key in benches:
    print(f'{key} : {benches[key].roc_auc.max()}')
# Out:
# None : 0.8686708860759493
# small : 0.8696598101265822
# medium : 0.8694620253164557
# large : 0.8698575949367089
# xlarge : 0.8591772151898734

# %%
df_bench=benches['small']
df_bench
# Out:
#                       roc_auc        f1  accuracy  recall  log_loss  \
# Logistic Regression  0.869660  0.759124  0.769231  0.8125  7.970604
# Neural Network       0.866297  0.770370  0.783217  0.8125  7.487533
#
#                      false_positive  false_negative   fit_time  proba_time
# Logistic Regression        0.146853        0.083916   0.441268    0.098094
# Neural Network             0.132867        0.083916  12.868823    0.109170

# %% [markdown]
# ## Augmentation données entrainement avec AFP

# %%
df_texts_afp =  pd.read_csv('data/demo/221221-TextAfp.csv')

# %%
afp_size = 20
df_texts = pd.concat([df_infox,df_texts_afp.sample(afp_size,random_state=random_state)])

# %%
tokenizer = lex.get_lemmas_from_text
#tokenizer = lex.get_words

# %%
benches = {}
for key in ['None','small','large']:
    vectorizer = TfidfVectorizer(lowercase=True, preprocessor=preprocessor, tokenizer=tokenizer, stop_words=ignore_lemmas[key])
    count_matrix = vectorizer.fit_transform(df_texts['text'])
    count_array = count_matrix.toarray()
    df_tf = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
    df_X = df_tf
    df_bench = bench.benchmark(df_X,df_texts['infox'],predictors=predictors,train_size=train_size,random_state=random_state)
    df_bench = df_bench.sort_values('roc_auc',ascending=False)
    benches[key] = df_bench

# %%
for key in benches:
    print(f'{key} : {benches[key].roc_auc.max()}')

# %%
df_bench=benches['large']
df_bench

# %% [markdown]
# ## Utilisation Features linguistiques

# %%
df_pos_norm

# %%
tokenizer = lex.get_lemmas_from_text
#tokenizer = lex.get_words

# %%
df_texts=df_infox
pos_cols = ['nb_token','nb_exclam','SPACE','SCONJ','INTJ','ADJ']
benches = {}
#for key in ['None','small','medium','large','xlarge']:
for key in ['medium']:
    vectorizer = TfidfVectorizer(lowercase=True, preprocessor=preprocessor, tokenizer=tokenizer, stop_words=ignore_lemmas[key])
    count_matrix = vectorizer.fit_transform(df_texts['text'])
    count_array = count_matrix.toarray()
    df_tf = pd.DataFrame(data=count_array,columns = vectorizer.get_feature_names_out())
    df_X = pd.concat([df_tf,df_pos_norm[pos_cols]],axis=1)
#    df_bench = bench.benchmark(df_X,df_texts['infox'],predictors=predictors,train_size=train_size,random_state=random_state)
    df_bench = bench.benchmark(df_X,df_texts['infox'],train_size=train_size,random_state=random_state)
    df_bench = df_bench.sort_values('roc_auc',ascending=False)
    benches[key] = df_bench

# %%
for key in benches:
    print(f'{key} : {benches[key].roc_auc.max()}')

# %%
df_bench=benches['medium']
df_bench

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# # Bricolages
# ---
