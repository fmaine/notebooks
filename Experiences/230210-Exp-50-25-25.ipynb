# %% [markdown]
# # Plateforme Agnostique de Traitement et d'Analyse des Textes
# ### Carnet d'expérimentation
# ---
#
# ## Sujet : Construire un échntillon d'articles de test
# - 50% mainstream
# - 25% alt + predict infox
# - 25% alt + predict non infox
#
# ---

# %% [markdown]
# # Observations et environnement
# ---

# %%
random_state = 42

# %%
cd ../..
# Out:
# /Volumes/Geek/Work/Patat

# %%
import importlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Labels et Articles

# %%
import patat.db.label_db

# %%
importlib.reload(patat.db.label_db)
label_filename = ''

label_db = patat.db.label_db.LabelDb(label_filename)
label_db.df()
# Out:
#                                                       url               label  \
# 0       https://www.alnas.fr/actualite/communaute/lara...               infox
# 1       https://www.alnas.fr/actualite/communaute/lara...               signe
# 2       https://www.alnas.fr/actualite/communaute/lara...     entites_nommees
# 3       https://www.alnas.fr/actualite/communaute/lara...  entites_coherentes
# 4       https://www.alnas.fr/actualite/communaute/lara...    ouverture_esprit
# ...                                                   ...                 ...
# 266583  https://www.profession-gendarme.com/zelensky-e...               infox
# 266584  https://www.profession-gendarme.com/zelensky-l...               infox
# 266585  https://www.profession-gendarme.com/zelensky-m...               infox
# 266586  https://www.profession-gendarme.com/zero-mort-...               infox
# 266587  https://www.profession-gendarme.com/zoom-franc...               infox
#
#            value            owner  type  \
# 0       0.000000          recueil   obs
# 1       0.000000          recueil   obs
# 2       1.000000          recueil   obs
# 3       1.000000          recueil   obs
# 4       0.000000          recueil   obs
# ...          ...              ...   ...
# 266583  0.556761  220930-tf_lr.pp  pred
# 266584  0.164531  220930-tf_lr.pp  pred
# 266585  0.673791  220930-tf_lr.pp  pred
# 266586  0.103192  220930-tf_lr.pp  pred
# 266587  0.303205  220930-tf_lr.pp  pred
#
#                                            url_h
# 0       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 1       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 2       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 3       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# 4       ef05018ec0f5d637bceb4cef7004e8ee5fe48f6f
# ...                                          ...
# 266583  e346761c2a99d892b26c9388480e0ee6ad6b303b
# 266584  77525354644316eadab53960efa8f5fd028c7f67
# 266585  fc6a074da5c02032bc9fc3f35f1044bc4029042c
# 266586  e4f0a8961d79c9a5f66c80d7aa4196cb679af2b0
# 266587  36a0091795b15d56005a6b7b8963ada539f598eb
#
# [266588 rows x 6 columns]

# %%
import patat.db.article_db

# %%
importlib.reload(patat.db.article_db)
article_filename = ''

article_db = patat.db.article_db.ArticleDb(article_filename)
article_db.df()
# Out:
# /Volumes/Geek/Work/Patat/patat/db/article_db.py:37: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#                                                      url  \
# 0      https://www.alnas.fr/actualite/en-vrac/les-emi...
# 1      https://www.anguillesousroche.com/changement-c...
# 2      https://www.bvoltaire.fr/prediction-pour-2023-...
# 3      https://lesdeqodeurs.fr/le-premier-ministre-or...
# 4      https://lesobservateurs.ch/2022/12/18/herault-...
# ...                                                  ...
# 86822  https://www.lelibrepenseur.org/une-histoire-vi...
# 86823              https://www.lelibrepenseur.org/actus/
# 86824  https://www.lelibrepenseur.org/affiche-des-dec...
# 86825         https://www.lelibrepenseur.org/communaute/
# 86826  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Les Émirats arabes unis et l’Arabie saoudite f...
# 1      Article d’opinion du NY Times : « S’accoupler ...
# 2      Prédiction pour 2023 : ça va bien se passer… j...
# 3      Le Premier ministre Orbán affirme que le scand...
# 4      Hérault : 300 musulmans armés de kalachnikovs ...
# ...                                                  ...
# 86822              Une histoire vieille comme le monde !
# 86823                                              Actus
# 86824  Affiche des décès et malaises de sportifs de h...
# 86825                                         Communauté
# 86826             Utilisation des cookies sur notre site
#
#                                                  article            author  \
# 0      Plus des trois quarts des importations japonai...       Par Sarah -
# 1      « Nous serons plus nombreux à pouvoir monter d...               NaN
# 2      Le 31 décembre dernier, Emmanuel Macron était,...   Frédéric Lassez
# 3      Article original datant du 16/12/22 par RMX.ne...               NaN
# 4      « La horde sauvage » nouvelle version, sans la...  Francis Gruzelle
# ...                                                  ...               ...
# 86822  Certains veulent des preuves ! Ils ont raison....        Par\nAdmin
# 86823  Dernière vidéo !\nIl était temps, enfin ! Je v...         Par\nuser
# 86824  Un nombre inquiétant de sportifs de haut nivea...               NaN
# 86825  Notre Réseau Telegram et ses Groupes Secondair...               NaN
# 86826  Que sont les cookies ?\n\n\nLes cookies sont d...               NaN
#
#                                                      tag abstract  \
# 0                              ['Actualités', 'En vrac']      NaN
# 1                              ['Changement climatique']      NaN
# 2                  ['Articles\nPolitique\nVoeux Macron']      NaN
# 3      ['Andrea Cozzolino', 'Bruxelles', 'corruption'...      NaN
# 4                                                     []      NaN
# ...                                                  ...      ...
# 86822                                                NaN      NaN
# 86823                                                NaN      NaN
# 86824                                                NaN      NaN
# 86825                                                NaN      NaN
# 86826                                                NaN      NaN
#
#                             site             date_iso  \
# 0                   www.alnas.fr  2023-01-03T00:00:00
# 1      www.anguillesousroche.com  2023-01-04T00:00:00
# 2               www.bvoltaire.fr  2023-01-03T00:00:00
# 3                lesdeqodeurs.fr  2022-12-19T00:00:00
# 4             lesobservateurs.ch  2022-12-18T00:00:00
# ...                          ...                  ...
# 86822     www.lelibrepenseur.org  2010-05-04T00:00:00
# 86823     www.lelibrepenseur.org  2007-07-07T00:00:00
# 86824     www.lelibrepenseur.org                  NaN
# 86825     www.lelibrepenseur.org                  NaN
# 86826     www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0      d9726057bcbe0182c5bec27f5cc2e1c73594a361      NaN
# 1      7dce1f2479231f6e9606c69da67444b634c2d32d      NaN
# 2      b11055abd5b8f6c385a79096ae29d90f8a0348ff      NaN
# 3      790fa6da6e1d9151e0ad6ce08627f738ad1e864c      NaN
# 4      2b314df4e0710050ae0441d6423177362127c784      NaN
# ...                                         ...      ...
# 86822  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86823  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86824  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86825  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86826  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [86827 rows x 10 columns]

# %% [markdown]
# # Experience
# ---

# %%
df = article_db.df().copy()

# %%
df['site'].unique()
# Out:
# array(['www.alnas.fr', 'www.anguillesousroche.com', 'www.bvoltaire.fr',
#        'lesdeqodeurs.fr', 'lesobservateurs.ch',
#        'lezarceleurs.blogspot.com', 'www.profession-gendarme.com',
#        'reseauinternational.net', 'www.voltairenet.org',
#        'www.wikistrike.com', 'www.francesoir.fr', 'infodujour.fr',
#        'lalettrepatriote.com', 'lecourrier-du-soir.com',
#        'lemediaen442.fr', 'lesakerfrancophone.fr', 'www.polemia.com',
#        'www.breizh-info.com', 'www.lelibrepenseur.org',
#        'www.lesalonbeige.fr', 'ripostelaique.com',
#        'www.medias-presse.info', 'www.preuvesduparanormal.fr',
#        'www.dreuz.info', 'lesmoutonsrebelles.com',
#        'www.nouvelordremondial.cc', 'fr.sott.net', 'www.cnews.fr',
#        'actu.fr', 'www.francetvinfo.fr', 'www.legorafi.fr',
#        'theconversation.com', 'fr.novopress.info', 'www.les-crises.fr'],
#       dtype=object)

# %%
alt_sites=[
    'www.alnas.fr', 
    'www.anguillesousroche.com', 
    'www.bvoltaire.fr',
    'lesdeqodeurs.fr', 
    'lesobservateurs.ch',
    'lezarceleurs.blogspot.com', 
    'www.profession-gendarme.com',
    'reseauinternational.net', 
    'www.voltairenet.org',
    'www.wikistrike.com', 
    'www.francesoir.fr', 
    'infodujour.fr',
    'lalettrepatriote.com', 
    'lecourrier-du-soir.com',
    'lemediaen442.fr', 
    'lesakerfrancophone.fr', 
    'www.polemia.com',
    'www.breizh-info.com', 
    'www.lelibrepenseur.org',
    'www.lesalonbeige.fr', 
    'ripostelaique.com',
    'www.medias-presse.info', 
    'www.preuvesduparanormal.fr',
    'www.dreuz.info', 
    'lesmoutonsrebelles.com',
    'www.nouvelordremondial.cc', 
    'fr.sott.net', 
    'www.cnews.fr',
    'fr.novopress.info',
    'www.les-crises.fr',
]

# %%
main_sites=['actu.fr', 'www.francetvinfo.fr','theconversation.com', ]

# %%
df_main = df[df['site'].isin(main_sites)]

# %%
df_main
# Out:
#                                                      url  \
# 8942   https://actu.fr/economie/inflation-le-prix-du-...
# 8943   https://www.francetvinfo.fr/sports/cyclisme/cy...
# 8944   https://www.francetvinfo.fr/monde/russie/russi...
# 8946   https://www.francetvinfo.fr/economie/energie/e...
# 8947   https://www.francetvinfo.fr/politique/eelv/eel...
# ...                                                  ...
# 63168  https://actu.fr/societe/video-vacances-taxis-p...
# 63169  https://actu.fr/societe/violences-conjugales-d...
# 63170  https://actu.fr/societe/vous-avez-des-probleme...
# 63171  https://actu.fr/sports/en-club-seul-ou-a-l-eco...
# 80402  https://www.francetvinfo.fr/elections/sondages...
#
#                                                    title  \
# 8942   Inflation : le prix du paquet de cigarettes va...
# 8943   Cyclisme : Mathieu van der Poel condamné à ver...
# 8944   Russie : une fusillade dans une école dans le ...
# 8946   Économies d’énergies : les petites communes da...
# 8947             EELV : Julien Bayou annonce son retrait
# ...                                                  ...
# 63168  VIDEO. Vacances, taxis, police... Voici le Gra...
# 63169  Violences conjugales : davantage de moyens pou...
# 63170  Vous avez des problèmes d’humidité dans votre ...
# 63171  En club, seul ou à l'école... Faut-il un certi...
# 80402  Sondages présidentielle 2022 : explorez les te...
#
#                                                  article  \
# 8942   Le prix des paquets de cigarettes pourrait êtr...
# 8943   Deux jours après avoir été arrêté par la polic...
# 8944   Le suspect s'est suicidé, selon les autorités ...
# 8946   Les prix de l’énergie préoccupent les communes...
# 8947   Julien Bayou, accusé de harcèlement moral par ...
# ...                                                  ...
# 63168  Cyril Viguier est le présentateur du Grand JT ...
# 63169  Le budget consacré à la prise en charge des au...
# 63170  Lorsqu’une habitation connaît des problèmes d’...
# 63171  Le certificat médical n’est pas obligatoire po...
# 80402  Retrouvez l’évolution des estimations de score...
#
#                                                   author  tag abstract  \
# 8942     Par Maxime T'sjoen\nPublié le 26 Sep 22 à 10:44  NaN      NaN
# 8943                          franceinfo: sport avec AFP  NaN      NaN
# 8944                                 franceinfo avec AFP  NaN      NaN
# 8946   A. Brogat, E. Rivallain, D. Martin, P. Corne, ...  NaN      NaN
# 8947   M. Rousselin - \n\n                           ...  NaN      NaN
# ...                                                  ...  ...      ...
# 63168      Par Rédaction Actu\nPublié le 5 Fév 22 à 9:27  NaN      NaN
# 63169   Par Alexandra Segond\nPublié le 4 Fév 22 à 16:41  NaN      NaN
# 63170  Par Agence de presse APEI\nPublié le 6 Fév 22 ...  NaN      NaN
# 63171     Par Maxime T'sjoen\nPublié le 8 Sep 22 à 11:19  NaN      NaN
# 80402                                                NaN  NaN      NaN
#
#                       site             date_iso  \
# 8942               actu.fr  2022-09-26T10:44:00
# 8943   www.francetvinfo.fr  2022-09-26T10:30:00
# 8944   www.francetvinfo.fr  2022-09-26T10:28:00
# 8946   www.francetvinfo.fr  2022-09-26T10:26:00
# 8947   www.francetvinfo.fr  2022-09-26T10:19:00
# ...                    ...                  ...
# 63168              actu.fr                  NaN
# 63169              actu.fr                  NaN
# 63170              actu.fr                  NaN
# 63171              actu.fr                  NaN
# 80402  www.francetvinfo.fr                  NaN
#
#                                           url_h  c_count
# 8942   9c1b2bb43d1ea6d3b8e994c33939fdf1534fb8d7   2106.0
# 8943   33958177ee67226d99405dbc2b528c6b85548196   1443.0
# 8944   44213024a13ffdf9ea9b3d4b476b72ab2f51b123   1478.0
# 8946   2fb70d6fc5ad509d2abc1c64a491f350e0f13d17   1010.0
# 8947   d23f6b098986e8a202d4efe42598b84cb72f0918   1078.0
# ...                                         ...      ...
# 63168  7a29746e64d0452dc52dda25d9efd5b10f6d5995   1678.0
# 63169  cc29e526ece502248025fe1583c7af687d52f6d8   1923.0
# 63170  3e12a521f5f7ab2681caba8740c19dde69592500   3260.0
# 63171  a7f063102a4762424403a78a63fa87d8fc404db5   4044.0
# 80402  f1e8f949423804934e6d3ceb5e524b0ea1d7f662   2003.0
#
# [18520 rows x 10 columns]

# %%
df_alt=df[df['site'].isin(alt_sites)]
df_alt
# Out:
#                                                      url  \
# 0      https://www.alnas.fr/actualite/en-vrac/les-emi...
# 1      https://www.anguillesousroche.com/changement-c...
# 2      https://www.bvoltaire.fr/prediction-pour-2023-...
# 3      https://lesdeqodeurs.fr/le-premier-ministre-or...
# 4      https://lesobservateurs.ch/2022/12/18/herault-...
# ...                                                  ...
# 86822  https://www.lelibrepenseur.org/une-histoire-vi...
# 86823              https://www.lelibrepenseur.org/actus/
# 86824  https://www.lelibrepenseur.org/affiche-des-dec...
# 86825         https://www.lelibrepenseur.org/communaute/
# 86826  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0      Les Émirats arabes unis et l’Arabie saoudite f...
# 1      Article d’opinion du NY Times : « S’accoupler ...
# 2      Prédiction pour 2023 : ça va bien se passer… j...
# 3      Le Premier ministre Orbán affirme que le scand...
# 4      Hérault : 300 musulmans armés de kalachnikovs ...
# ...                                                  ...
# 86822              Une histoire vieille comme le monde !
# 86823                                              Actus
# 86824  Affiche des décès et malaises de sportifs de h...
# 86825                                         Communauté
# 86826             Utilisation des cookies sur notre site
#
#                                                  article            author  \
# 0      Plus des trois quarts des importations japonai...       Par Sarah -
# 1      « Nous serons plus nombreux à pouvoir monter d...               NaN
# 2      Le 31 décembre dernier, Emmanuel Macron était,...   Frédéric Lassez
# 3      Article original datant du 16/12/22 par RMX.ne...               NaN
# 4      « La horde sauvage » nouvelle version, sans la...  Francis Gruzelle
# ...                                                  ...               ...
# 86822  Certains veulent des preuves ! Ils ont raison....        Par\nAdmin
# 86823  Dernière vidéo !\nIl était temps, enfin ! Je v...         Par\nuser
# 86824  Un nombre inquiétant de sportifs de haut nivea...               NaN
# 86825  Notre Réseau Telegram et ses Groupes Secondair...               NaN
# 86826  Que sont les cookies ?\n\n\nLes cookies sont d...               NaN
#
#                                                      tag abstract  \
# 0                              ['Actualités', 'En vrac']      NaN
# 1                              ['Changement climatique']      NaN
# 2                  ['Articles\nPolitique\nVoeux Macron']      NaN
# 3      ['Andrea Cozzolino', 'Bruxelles', 'corruption'...      NaN
# 4                                                     []      NaN
# ...                                                  ...      ...
# 86822                                                NaN      NaN
# 86823                                                NaN      NaN
# 86824                                                NaN      NaN
# 86825                                                NaN      NaN
# 86826                                                NaN      NaN
#
#                             site             date_iso  \
# 0                   www.alnas.fr  2023-01-03T00:00:00
# 1      www.anguillesousroche.com  2023-01-04T00:00:00
# 2               www.bvoltaire.fr  2023-01-03T00:00:00
# 3                lesdeqodeurs.fr  2022-12-19T00:00:00
# 4             lesobservateurs.ch  2022-12-18T00:00:00
# ...                          ...                  ...
# 86822     www.lelibrepenseur.org  2010-05-04T00:00:00
# 86823     www.lelibrepenseur.org  2007-07-07T00:00:00
# 86824     www.lelibrepenseur.org                  NaN
# 86825     www.lelibrepenseur.org                  NaN
# 86826     www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count
# 0      d9726057bcbe0182c5bec27f5cc2e1c73594a361      NaN
# 1      7dce1f2479231f6e9606c69da67444b634c2d32d      NaN
# 2      b11055abd5b8f6c385a79096ae29d90f8a0348ff      NaN
# 3      790fa6da6e1d9151e0ad6ce08627f738ad1e864c      NaN
# 4      2b314df4e0710050ae0441d6423177362127c784      NaN
# ...                                         ...      ...
# 86822  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0
# 86823  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0
# 86824  a175027896cf79e76dfad6409694fafacf1919b3   2193.0
# 86825  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0
# 86826  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0
#
# [63819 rows x 10 columns]

# %%
df_label = label_db.df()

# %%
df_alt = df_alt.merge(df_label[df_label['owner']=='221028-InfoxPipe'])

# %%
df_alt
# Out:
#                                                      url  \
# 0      https://www.breizh-info.com/2022/09/30/208531/...
# 1      https://www.breizh-info.com/2022/10/02/208574/...
# 2      https://www.dreuz.info/2022/10/elections-de-mi...
# 3      https://www.dreuz.info/2022/10/lukraine-est-en...
# 4      https://www.dreuz.info/2022/10/la-fda-va-publi...
# ...                                                  ...
# 54937  https://www.lelibrepenseur.org/une-histoire-vi...
# 54938              https://www.lelibrepenseur.org/actus/
# 54939  https://www.lelibrepenseur.org/affiche-des-dec...
# 54940         https://www.lelibrepenseur.org/communaute/
# 54941  https://www.lelibrepenseur.org/utilisation-des...
#
#                                                    title  \
# 0        Réunification. Les six « insoumis » de Bretagne
# 1          Stonehenge, patrimoine africain ? Ben voyons…
# 2      Elections américaines de mi-mandat : suivi quo...
# 3             L’Ukraine est en train de gagner la guerre
# 4      La FDA va publier une étude sur les effets ind...
# ...                                                  ...
# 54937              Une histoire vieille comme le monde !
# 54938                                              Actus
# 54939  Affiche des décès et malaises de sportifs de h...
# 54940                                         Communauté
# 54941             Utilisation des cookies sur notre site
#
#                                                  article  \
# 0      Dans l’opération que prépare Bretagne réunie, ...
# 1      Ces dernières années, l’Histoire toute entière...
# 2      Voici le suivi quotidien des élections des mid...
# 3      On ne saura sans doute jamais exactement qui a...
# 4      Première réflexion : J’ai toujours été pro-cho...
# ...                                                  ...
# 54937  Certains veulent des preuves ! Ils ont raison....
# 54938  Dernière vidéo !\nIl était temps, enfin ! Je v...
# 54939  Un nombre inquiétant de sportifs de haut nivea...
# 54940  Notre Réseau Telegram et ses Groupes Secondair...
# 54941  Que sont les cookies ?\n\n\nLes cookies sont d...
#
#                                                   author  tag abstract  \
# 0                                                    NaN  NaN      NaN
# 1                                                    NaN  NaN      NaN
# 2           Publié par  Team 100 jours le 3 octobre 2022  NaN      NaN
# 3             Publié par  Guy Millière le 4 octobre 2022  NaN      NaN
# 4      Publié par  Jean-Patrick Grumberg le 6 octobre...  NaN      NaN
# ...                                                  ...  ...      ...
# 54937                                         Par\nAdmin  NaN      NaN
# 54938                                          Par\nuser  NaN      NaN
# 54939                                                NaN  NaN      NaN
# 54940                                                NaN  NaN      NaN
# 54941                                                NaN  NaN      NaN
#
#                          site             date_iso  \
# 0         www.breizh-info.com  2022-09-30T00:00:00
# 1         www.breizh-info.com  2022-10-02T00:00:00
# 2              www.dreuz.info  2022-10-03T00:00:00
# 3              www.dreuz.info  2022-10-04T00:00:00
# 4              www.dreuz.info  2022-10-06T00:00:00
# ...                       ...                  ...
# 54937  www.lelibrepenseur.org  2010-05-04T00:00:00
# 54938  www.lelibrepenseur.org  2007-07-07T00:00:00
# 54939  www.lelibrepenseur.org                  NaN
# 54940  www.lelibrepenseur.org                  NaN
# 54941  www.lelibrepenseur.org                  NaN
#
#                                           url_h  c_count  label     value  \
# 0      7a183e0e5a2d7643350d9cb3fe655cb8e05d2892   2244.0  infox  0.002348
# 1      242c9ea99be61b3e67d040b9a15423556b0a226c   5065.0  infox  0.024418
# 2      6294a8e958f020eb3d151176bdd437626d490b43   5847.0  infox  0.025664
# 3      3f2abdc980e4fc88f3b62503e4cfccf2923686f5   9555.0  infox  0.052985
# 4      1f3dc0cd32405aadd908368395533886a5e13fe2   4137.0  infox  0.055427
# ...                                         ...      ...    ...       ...
# 54937  8c7a6ecf46d47da1912884a0c0a2837c69f7ad19   7851.0  infox  0.974836
# 54938  d4d5a37a8ff545664bea75664c8d8695e70d0941   2173.0  infox  0.928591
# 54939  a175027896cf79e76dfad6409694fafacf1919b3   2193.0  infox  0.811909
# 54940  6ba257c7b15dd68cadf7dc5d6d8c584db0f1792e   2926.0  infox  0.887319
# 54941  7c725113f0c9a95c8269c8d7a271d253ae5ede99   7663.0  infox  0.451907
#
#                   owner  type
# 0      221028-InfoxPipe  pred
# 1      221028-InfoxPipe  pred
# 2      221028-InfoxPipe  pred
# 3      221028-InfoxPipe  pred
# 4      221028-InfoxPipe  pred
# ...                 ...   ...
# 54937  221028-InfoxPipe  pred
# 54938  221028-InfoxPipe  pred
# 54939  221028-InfoxPipe  pred
# 54940  221028-InfoxPipe  pred
# 54941  221028-InfoxPipe  pred
#
# [54942 rows x 14 columns]

# %%
sns.displot(df_alt,x='value')

# %%
df_alt[df_alt['value']<.2]
# Out:
#                                                      url  \
# 0      https://www.breizh-info.com/2022/09/30/208531/...
# 1      https://www.breizh-info.com/2022/10/02/208574/...
# 2      https://www.dreuz.info/2022/10/elections-de-mi...
# 3      https://www.dreuz.info/2022/10/lukraine-est-en...
# 4      https://www.dreuz.info/2022/10/la-fda-va-publi...
# ...                                                  ...
# 54881  https://www.lelibrepenseur.org/crediland-nous-...
# 54883   https://www.lelibrepenseur.org/nouveau-site-llp/
# 54911  https://www.lelibrepenseur.org/aux-dab-citoyen...
# 54924  https://www.lelibrepenseur.org/actus-et-reflex...
# 54930  https://www.lelibrepenseur.org/conference-avec...
#
#                                                    title  \
# 0        Réunification. Les six « insoumis » de Bretagne
# 1          Stonehenge, patrimoine africain ? Ben voyons…
# 2      Elections américaines de mi-mandat : suivi quo...
# 3             L’Ukraine est en train de gagner la guerre
# 4      La FDA va publier une étude sur les effets ind...
# ...                                                  ...
# 54881                       « Crédiland » nous sauvera !
# 54883                                   Nouveau site LLP
# 54911        Aux DAB citoyens : photos de vos retraits !
# 54924                       Actus et reflexions diverses
# 54930     Conférence avec Israël Adam Shamir à Marseille
#
#                                                  article  \
# 0      Dans l’opération que prépare Bretagne réunie, ...
# 1      Ces dernières années, l’Histoire toute entière...
# 2      Voici le suivi quotidien des élections des mid...
# 3      On ne saura sans doute jamais exactement qui a...
# 4      Première réflexion : J’ai toujours été pro-cho...
# ...                                                  ...
# 54881  J’ai eu une très bonne idée pour nous sortir d...
# 54883  Aujourd’hui est mis en ligne mon nouveau site ...
# 54911  Chers amis et antibanksters !\nComme il est im...
# 54924  Quelques réflexions sur les dernières actualit...
# 54930  La COBEMA organise pour la sortie du dernier l...
#
#                                                   author  tag abstract  \
# 0                                                    NaN  NaN      NaN
# 1                                                    NaN  NaN      NaN
# 2           Publié par  Team 100 jours le 3 octobre 2022  NaN      NaN
# 3             Publié par  Guy Millière le 4 octobre 2022  NaN      NaN
# 4      Publié par  Jean-Patrick Grumberg le 6 octobre...  NaN      NaN
# ...                                                  ...  ...      ...
# 54881                                          Par\nuser  NaN      NaN
# 54883                                          Par\nuser  NaN      NaN
# 54911                                         Par\nAdmin  NaN      NaN
# 54924                                         Par\nAdmin  NaN      NaN
# 54930                                         Par\nAdmin  NaN      NaN
#
#                          site             date_iso  \
# 0         www.breizh-info.com  2022-09-30T00:00:00
# 1         www.breizh-info.com  2022-10-02T00:00:00
# 2              www.dreuz.info  2022-10-03T00:00:00
# 3              www.dreuz.info  2022-10-04T00:00:00
# 4              www.dreuz.info  2022-10-06T00:00:00
# ...                       ...                  ...
# 54881  www.lelibrepenseur.org  2011-10-21T00:00:00
# 54883  www.lelibrepenseur.org  2011-10-09T00:00:00
# 54911  www.lelibrepenseur.org  2010-12-08T00:00:00
# 54924  www.lelibrepenseur.org  2010-08-01T00:00:00
# 54930  www.lelibrepenseur.org  2010-06-12T00:00:00
#
#                                           url_h  c_count  label     value  \
# 0      7a183e0e5a2d7643350d9cb3fe655cb8e05d2892   2244.0  infox  0.002348
# 1      242c9ea99be61b3e67d040b9a15423556b0a226c   5065.0  infox  0.024418
# 2      6294a8e958f020eb3d151176bdd437626d490b43   5847.0  infox  0.025664
# 3      3f2abdc980e4fc88f3b62503e4cfccf2923686f5   9555.0  infox  0.052985
# 4      1f3dc0cd32405aadd908368395533886a5e13fe2   4137.0  infox  0.055427
# ...                                         ...      ...    ...       ...
# 54881  b4923f8a4e5d6cabd956175d211a2a81791b7d37    786.0  infox  0.134168
# 54883  6f835d7577e86cb6e0e332b471b1770bb52a207c   1236.0  infox  0.194479
# 54911  baf4e65a92c76bdf1620e2192214ea5d8900a676   1175.0  infox  0.177625
# 54924  f90d46cf242cae3a3eb00402b6d5325994ad02df    933.0  infox  0.085308
# 54930  ca85203e7b6f52a98b741d71818926941e98d342   1431.0  infox  0.178434
#
#                   owner  type
# 0      221028-InfoxPipe  pred
# 1      221028-InfoxPipe  pred
# 2      221028-InfoxPipe  pred
# 3      221028-InfoxPipe  pred
# 4      221028-InfoxPipe  pred
# ...                 ...   ...
# 54881  221028-InfoxPipe  pred
# 54883  221028-InfoxPipe  pred
# 54911  221028-InfoxPipe  pred
# 54924  221028-InfoxPipe  pred
# 54930  221028-InfoxPipe  pred
#
# [22285 rows x 14 columns]

# %%
df_alt[df_alt['value']>.8].sample(2500)
# Out:
#                                                      url  \
# 35059  https://lesmoutonsrebelles.com/les-batailles-d...
# 33308  https://fr.sott.net/article/39997-L-empire-du-...
# 36026  https://lesmoutonsrebelles.com/video-yvan-le-b...
# 50674  https://www.profession-gendarme.com/le-dr-andr...
# 36994  https://lezarceleurs.blogspot.com/2021/09/covi...
# ...                                                  ...
# 38159  https://lezarceleurs.blogspot.com/2022/09/la-v...
# 886    https://www.breizh-info.com/2022/09/13/207858/...
# 33421  https://fr.sott.net/article/40114-Norman-Finke...
# 3565   https://www.wikistrike.com/2022/08/l-arn-du-bo...
# 50555  https://www.profession-gendarme.com/la-republi...
#
#                                                    title  \
# 35059  Les batailles du masque, du vaccin, des gestes...
# 33308         L'empire du mensonge des armes biologiques
# 36026  [VIDEO] Yvan Le Bolloc’h parle des black blocs...
# 50674  Le Dr Andreas Noack, chimiste autrichien renom...
# 36994  Covid/vaccin - Une lanceure d'alerte du monde ...
# ...                                                  ...
# 38159  La vascularite associée aux anticorps antineut...
# 886    Mamuka Mamulashvili : « La Géorgie a été le pr...
# 33421  Norman Finkelstein : la Russie a le droit hist...
# 3565   L’ARN du booster Omicron de Moderna est fabriq...
# 50555                la république en marche à la guerre
#
#                                                  article author  tag abstract  \
# 35059  par Robert BibeauCroyez-vous sérieusement que ...    NaN  NaN      NaN
# 33308  Un programme américain d'armes biologiques en ...    NaN  NaN      NaN
# 36026  Yvan Le Bolloc’h était l’invité d’Eric Morillo...    NaN  NaN      NaN
# 50674  Le lanceur d’alerte Dr. Andreas Noack, chimist...    NaN  NaN      NaN
# 36994  De : https://www.projectveritas.com/news/feder...    NaN  NaN      NaN
# ...                                                  ...    ...  ...      ...
# 38159  Traduction automatique  non relue Une vasculit...    NaN  NaN      NaN
# 886    Entretien avec Mamuka Mamulashvili, fondateur ...    NaN  NaN      NaN
# 33421  Transcription de la vidéo :\n\nAuditeur : Dans...    NaN  NaN      NaN
# 3565   Depuis la fin de l’année dernière, l’ARN messa...    NaN  NaN      NaN
# 50555  Le gouvernement mène la France à la guerre tot...    NaN  NaN      NaN
#
#                               site             date_iso  \
# 35059       lesmoutonsrebelles.com                  NaN
# 33308                  fr.sott.net                  NaN
# 36026       lesmoutonsrebelles.com                  NaN
# 50674  www.profession-gendarme.com                  NaN
# 36994    lezarceleurs.blogspot.com                  NaN
# ...                            ...                  ...
# 38159    lezarceleurs.blogspot.com                  NaN
# 886            www.breizh-info.com  2022-09-13T00:00:00
# 33421                  fr.sott.net                  NaN
# 3565            www.wikistrike.com  2022-08-19T00:00:00
# 50555  www.profession-gendarme.com                  NaN
#
#                                           url_h  c_count  label     value  \
# 35059  895df9091c4b8734eed580ec3fc8d71fb9c10fd8   7953.0  infox  0.926036
# 33308  5814563813d5f6608318c4cfcc3547befb0d775a   9580.0  infox  0.979116
# 36026  9afeb0592745a16be8bdf39a50af90e33fe036c2    903.0  infox  0.811203
# 50674  0cf2538129ee8098cb5d0104fb1a85bedc7690af   3840.0  infox  0.992080
# 36994  4c12eaf13e86cdf00a2a2395916f0445794c261c  11105.0  infox  0.985494
# ...                                         ...      ...    ...       ...
# 38159  4daebafbe58f98cfbf20d780c1165e8584c772b8  57978.0  infox  0.859679
# 886    2237b483a8319316cd374f4b974a18bd96854072  10131.0  infox  0.810166
# 33421  3c1d2730be61bdf162666ad8626e26bf2d06835a  26772.0  infox  0.980679
# 3565   05686ab1c8c79ed3fabcb38ffdb841bf7348e9f8  21857.0  infox  0.911408
# 50555  8f2541f24ddcc2ef22e9e25ce4f5fe1777ac7e68  21787.0  infox  0.973244
#
#                   owner  type
# 35059  221028-InfoxPipe  pred
# 33308  221028-InfoxPipe  pred
# 36026  221028-InfoxPipe  pred
# 50674  221028-InfoxPipe  pred
# 36994  221028-InfoxPipe  pred
# ...                 ...   ...
# 38159  221028-InfoxPipe  pred
# 886    221028-InfoxPipe  pred
# 33421  221028-InfoxPipe  pred
# 3565   221028-InfoxPipe  pred
# 50555  221028-InfoxPipe  pred
#
# [2500 rows x 14 columns]

# %%
size = 100
df_test = pd.concat([
    df_main.sample(int(size/2),random_state=random_state),
    df_alt[df_alt['value']<.2].sample(int(size/4),random_state=random_state), 
    df_alt[df_alt['value']>.8].sample(int(size/4),random_state=random_state), 
])

# %%
df_test['value'].fillna(0,inplace=True)

# %%
df_test = df_test.sample(frac=1,random_state=random_state)

# %%
df_test['url']
# Out:
# 33004    https://fr.sott.net/article/39277-Les-embaumeu...
# 51381    https://www.profession-gendarme.com/paris-lavo...
# 18204    https://www.breizh-info.com/2021/03/15/160688/...
# 49819    https://www.francetvinfo.fr/replay-radio/franc...
# 11322    https://www.francetvinfo.fr/culture/patrimoine...
#                                ...
# 39684    https://www.francesoir.fr/actualites-societe/l...
# 22640    https://www.francesoir.fr/culture-medias/infid...
# 48106    https://actu.fr/politique/alexandre-benalla-de...
# 50576    https://www.profession-gendarme.com/la-vaccina...
# 29815    https://www.wikistrike.com/article-le-vice-pre...
# Name: url, Length: 100, dtype: object

# %%
with open('test_url_hs.txt','w') as file:
    file.write('\n'.join(df_test['url_h'].values))

# %%
len(url_list)
# Out:
# 10000

# %% [markdown]
# # Mesure et observation des résultats
# ---

# %% [markdown]
# # Sauvegarde des résultats
# ---

# %% [markdown]
# # Conclusions
# ---

# %% [markdown]
# - ...

# %% [markdown]
# # Bricolages
# ---
